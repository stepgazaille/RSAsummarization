# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
# cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
# generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
# cmd = cmd.split()

vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
max_len = 250
stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query


def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_tfidf_score_func(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        v2s = [vectorizer.transform([r]) for r in ref]
        return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func()

# %%
class Summary:
    def __init__(self, texts, abstracts, query):
        
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def most_similar(self, sent, text):
        return max([(count_score(s, sent), s) for s in text])[1]

    def add_sum(self, summ):
        text = self.texts.pop(0).split(' . ')
        if len(self.texts) == 0: return True
        found_sents = []
        for sent in summ:
            ms = self.most_similar(sent, text)
            if ms in found_sents:
                continue
            found_sents.append(sent)
            splitted = pp(sent).split()
            length = len(splitted) 
            splitted = set(splitted)       
            if self.length+length > max_len: return True
            if len(splitted - self.words) < int(len(splitted)*0.5): return False
            self.words |= splitted     
            self.summary.append(sent)
            self.length +=length
        return False

    def get(self):
        text = self.texts[0]
        sents = text.split(' . ')
        #score_per_sent = [(count_score(sent, self.query), sent) for sent in sents]
        score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
for i in [5]:
    duc_num = i
    done_summaries = []
    summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(i)]
    while summaries:
        with open('test/temp_file', 'wb') as writer:
            for summ in summaries:
                article, abstract, scores = summ.get()
                write_to_file(article, abstracts, scores, writer)
        call(['rm', '-r', generated_path])     
        call(cmd)
        generated_summaries = get_summaries(generated_path)
        should_remove = []
        for i in range(len(summaries)):
            if summaries[i].add_sum(generated_summaries[i]):
                should_remove.append(i)
        for i in should_remove[::-1]: 
            done_summaries.append(summaries.pop(i))
    evaluate(done_summaries)
    print duc_num
# Out:
# 2019-02-05 13:46:52,379 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-05 13:46:52,382 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpyhfhxI/system and model files to /tmp/tmpyhfhxI/model.
# 2019-02-05 13:46:52,383 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-05 13:46:52,384 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-05 13:46:52,386 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-05 13:46:52,388 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-05 13:46:52,389 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-05 13:46:52,390 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-05 13:46:52,392 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-05 13:46:52,393 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-05 13:46:52,395 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-05 13:46:52,396 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-05 13:46:52,398 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-05 13:46:52,399 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-05 13:46:52,401 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-05 13:46:52,402 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-05 13:46:52,404 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-05 13:46:52,405 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-05 13:46:52,407 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-05 13:46:52,408 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-05 13:46:52,409 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-05 13:46:52,411 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-05 13:46:52,412 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-05 13:46:52,414 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-05 13:46:52,415 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-05 13:46:52,417 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-05 13:46:52,418 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-05 13:46:52,419 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-05 13:46:52,421 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-05 13:46:52,422 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-05 13:46:52,424 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-05 13:46:52,425 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-05 13:46:52,427 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-05 13:46:52,428 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-05 13:46:52,430 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-05 13:46:52,431 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-05 13:46:52,433 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-05 13:46:52,434 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-05 13:46:52,436 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-05 13:46:52,437 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-05 13:46:52,438 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-05 13:46:52,440 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-05 13:46:52,441 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-05 13:46:52,443 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-05 13:46:52,444 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-05 13:46:52,446 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-05 13:46:52,447 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-05 13:46:52,448 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-05 13:46:52,450 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-05 13:46:52,451 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-05 13:46:52,453 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-05 13:46:52,454 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-05 13:46:52,456 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-05 13:46:52,457 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpyhfhxI/system.
# 2019-02-05 13:46:52,459 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-05 13:46:52,460 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-05 13:46:52,461 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-05 13:46:52,463 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-05 13:46:52,464 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-05 13:46:52,466 [MainThread  ] [INFO ]  Processing 0_reference_4.txt.
# 2019-02-05 13:46:52,467 [MainThread  ] [INFO ]  Processing 0_reference_5.txt.
# 2019-02-05 13:46:52,469 [MainThread  ] [INFO ]  Processing 0_reference_6.txt.
# 2019-02-05 13:46:52,470 [MainThread  ] [INFO ]  Processing 0_reference_7.txt.
# 2019-02-05 13:46:52,472 [MainThread  ] [INFO ]  Processing 0_reference_8.txt.
# 2019-02-05 13:46:52,473 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02
[MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-05 13:46:52,836 [MainThread  ] [INFO ]  Processing 42_reference_4.txt.
# 2019-02-05 13:46:52,838 [MainThread  ] [INFO ]  Processing 42_reference_5.txt.
# 2019-02-05 13:46:52,839 [MainThread  ] [INFO ]  Processing 42_reference_6.txt.
# 2019-02-05 13:46:52,840 [MainThread  ] [INFO ]  Processing 42_reference_7.txt.
# 2019-02-05 13:46:52,842 [MainThread  ] [INFO ]  Processing 42_reference_8.txt.
# 2019-02-05 13:46:52,844 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-05 13:46:52,845 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-05 13:46:52,847 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-05 13:46:52,848 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-05 13:46:52,850 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-05 13:46:52,851 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-05 13:46:52,852 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-05 13:46:52,854 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-05 13:46:52,856 [MainThread  ] [INFO ]  Processing 44_reference_4.txt.
# 2019-02-05 13:46:52,857 [MainThread  ] [INFO ]  Processing 44_reference_5.txt.
# 2019-02-05 13:46:52,859 [MainThread  ] [INFO ]  Processing 44_reference_6.txt.
# 2019-02-05 13:46:52,860 [MainThread  ] [INFO ]  Processing 44_reference_7.txt.
# 2019-02-05 13:46:52,862 [MainThread  ] [INFO ]  Processing 44_reference_8.txt.
# 2019-02-05 13:46:52,863 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-05 13:46:52,865 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-05 13:46:52,866 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-05 13:46:52,868 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-05 13:46:52,870 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-05 13:46:52,871 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-05 13:46:52,873 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-05 13:46:52,875 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-05 13:46:52,876 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-05 13:46:52,878 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-05 13:46:52,879 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-05 13:46:52,881 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-05 13:46:52,883 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-05 13:46:52,884 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-05 13:46:52,886 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-05 13:46:52,888 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-05 13:46:52,889 [MainThread  ] [INFO ]  Processing 48_reference_4.txt.
# 2019-02-05 13:46:52,891 [MainThread  ] [INFO ]  Processing 48_reference_5.txt.
# 2019-02-05 13:46:52,892 [MainThread  ] [INFO ]  Processing 48_reference_6.txt.
# 2019-02-05 13:46:52,894 [MainThread  ] [INFO ]  Processing 48_reference_7.txt.
# 2019-02-05 13:46:52,896 [MainThread  ] [INFO ]  Processing 48_reference_8.txt.
# 2019-02-05 13:46:52,897 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-05 13:46:52,899 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-05 13:46:52,901 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-05 13:46:52,902 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-05 13:46:52,904 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpyhfhxI/model.
# 2019-02-05 13:46:52,931 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpJVgww6/rouge_conf.xml
# 2019-02-05 13:46:52,932 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpJVgww6/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.43150 (95%-conf.int. 0.41866 - 0.44496)
# 1 ROUGE-1 Average_P: 0.34558 (95%-conf.int. 0.33494 - 0.35554)
# 1 ROUGE-1 Average_F: 0.38325 (95%-conf.int. 0.37252 - 0.39404)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.08634 (95%-conf.int. 0.07921 - 0.09444)
# 1 ROUGE-2 Average_P: 0.06915 (95%-conf.int. 0.06312 - 0.07538)
# 1 ROUGE-2 Average_F: 0.07669 (95%-conf.int. 0.07015 - 0.08391)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.02647 (95%-conf.int. 0.02297 - 0.03068)
# 1 ROUGE-3 Average_P: 0.02121 (95%-conf.int. 0.01832 - 0.02465)
# 1 ROUGE-3 Average_F: 0.02352 (95%-conf.int. 0.02032 - 0.02719)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.01307 (95%-conf.int. 0.01073 - 0.01574)
# 1 ROUGE-4 Average_P: 0.01046 (95%-conf.int. 0.00856 - 0.01261)
# 1 ROUGE-4 Average_F: 0.01160 (95%-conf.int. 0.00951 - 0.01398)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.39920 (95%-conf.int. 0.38622 - 0.41232)
# 1 ROUGE-L Average_P: 0.31971 (95%-conf.int. 0.30966 - 0.32924)
# 1 ROUGE-L Average_F: 0.35456 (95%-conf.int. 0.34435 - 0.36481)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.11493 (95%-conf.int. 0.11110 - 0.11893)
# 1 ROUGE-W-1.2 Average_P: 0.17068 (95%-conf.int. 0.16533 - 0.17594)
# 1 ROUGE-W-1.2 Average_F: 0.13714 (95%-conf.int. 0.13299 - 0.14134)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.17353 (95%-conf.int. 0.16378 - 0.18433)
# 1 ROUGE-S* Average_P: 0.11121 (95%-conf.int. 0.10516 - 0.11715)
# 1 ROUGE-S* Average_F: 0.13485 (95%-conf.int. 0.12825 - 0.14169)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.17557 (95%-conf.int. 0.16578 - 0.18641)
# 1 ROUGE-SU* Average_P: 0.11271 (95%-conf.int. 0.10664 - 0.11867)
# 1 ROUGE-SU* Average_F: 0.13657 (95%-conf.int. 0.12995 - 0.14343)
#
# 5
