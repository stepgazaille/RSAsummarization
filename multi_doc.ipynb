# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
# cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
# generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
# cmd = cmd.split()

vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
max_len = 250
stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query


def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_tfidf_score_func(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        v2s = [vectorizer.transform([r]) for r in ref]
        return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func()

# %%
class Summary:
    def __init__(self, texts, abstracts, query):
        
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def most_similar(self, sent, text):
        return max([(count_score(s, sent), s) for s in text])[1]

    def add_sum(self, summ):
        text = self.texts.pop(0).split(' . ')
        if len(self.texts) == 0: return True
        found_sents = []
        for sent in summ:
            ms = self.most_similar(sent, text)
            if ms in found_sents:
                continue
            found_sents.append(sent)
            splitted = pp(sent).split()
            length = len(splitted) 
            splitted = set(splitted)       
            if self.length+length > max_len: return True
            if len(splitted - self.words) < int(len(splitted)*0.5): return False
            self.words |= splitted     
            self.summary.append(sent)
            self.length +=length
        return False

    def get(self):
        text = self.texts[0]
        sents = text.split(' . ')
        #score_per_sent = [(count_score(sent, self.query), sent) for sent in sents]
        score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
for i in [5]:
    duc_num = i
    done_summaries = []
    summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(i)]
    while summaries:
        with open('test/temp_file', 'wb') as writer:
            for summ in summaries:
                article, abstract, scores = summ.get()
                write_to_file(article, abstracts, scores, writer)
        call(['rm', '-r', generated_path])     
        call(cmd)
        generated_summaries = get_summaries(generated_path)
        should_remove = []
        for i in range(len(summaries)):
            if summaries[i].add_sum(generated_summaries[i]):
                should_remove.append(i)
        for i in should_remove[::-1]: 
            done_summaries.append(summaries.pop(i))
    evaluate(done_summaries)
    print duc_num
# Out:
# 2019-02-14 14:19:28,409 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 14:19:28,412 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpnK6QHu/system and model files to /tmp/tmpnK6QHu/model.
# 2019-02-14 14:19:28,414 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 14:19:28,415 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 14:19:28,417 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 14:19:28,420 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 14:19:28,422 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 14:19:28,425 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 14:19:28,427 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 14:19:28,429 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 14:19:28,431 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 14:19:28,434 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 14:19:28,436 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 14:19:28,439 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 14:19:28,441 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 14:19:28,443 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 14:19:28,445 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 14:19:28,447 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 14:19:28,450 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 14:19:28,452 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 14:19:28,454 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 14:19:28,457 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 14:19:28,459 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 14:19:28,461 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 14:19:28,463 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 14:19:28,466 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 14:19:28,468 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 14:19:28,470 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 14:19:28,472 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 14:19:28,475 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 14:19:28,477 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 14:19:28,479 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 14:19:28,481 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 14:19:28,483 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 14:19:28,486 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 14:19:28,488 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 14:19:28,490 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 14:19:28,492 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 14:19:28,495 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 14:19:28,497 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 14:19:28,499 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 14:19:28,501 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 14:19:28,504 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 14:19:28,506 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 14:19:28,509 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 14:19:28,511 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 14:19:28,513 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 14:19:28,515 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 14:19:28,517 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-14 14:19:28,519 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-14 14:19:28,522 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-14 14:19:28,524 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-14 14:19:28,526 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-14 14:19:28,528 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpnK6QHu/system.
# 2019-02-14 14:19:28,529 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 14:19:28,530 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 14:19:28,533 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 14:19:28,535 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 14:19:28,537 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02
[MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-14 14:19:29,142 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-14 14:19:29,144 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-14 14:19:29,146 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-14 14:19:29,148 [MainThread  ] [INFO ]  Processing 45_reference_4.txt.
# 2019-02-14 14:19:29,150 [MainThread  ] [INFO ]  Processing 45_reference_5.txt.
# 2019-02-14 14:19:29,153 [MainThread  ] [INFO ]  Processing 45_reference_6.txt.
# 2019-02-14 14:19:29,155 [MainThread  ] [INFO ]  Processing 45_reference_7.txt.
# 2019-02-14 14:19:29,157 [MainThread  ] [INFO ]  Processing 45_reference_8.txt.
# 2019-02-14 14:19:29,159 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-14 14:19:29,162 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-14 14:19:29,164 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-14 14:19:29,166 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-14 14:19:29,168 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-14 14:19:29,171 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-14 14:19:29,173 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-14 14:19:29,175 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-14 14:19:29,177 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-14 14:19:29,180 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-14 14:19:29,182 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-14 14:19:29,184 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-14 14:19:29,186 [MainThread  ] [INFO ]  Processing 48_reference_4.txt.
# 2019-02-14 14:19:29,188 [MainThread  ] [INFO ]  Processing 48_reference_5.txt.
# 2019-02-14 14:19:29,191 [MainThread  ] [INFO ]  Processing 48_reference_6.txt.
# 2019-02-14 14:19:29,193 [MainThread  ] [INFO ]  Processing 48_reference_7.txt.
# 2019-02-14 14:19:29,195 [MainThread  ] [INFO ]  Processing 48_reference_8.txt.
# 2019-02-14 14:19:29,198 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-14 14:19:29,200 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-14 14:19:29,202 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-14 14:19:29,204 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-14 14:19:29,207 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpnK6QHu/model.
# 2019-02-14 14:19:29,231 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpZxIJGv/rouge_conf.xml
# 2019-02-14 14:19:29,232 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpZxIJGv/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.42865 (95%-conf.int. 0.41692 - 0.44146)
# 1 ROUGE-1 Average_P: 0.34781 (95%-conf.int. 0.33747 - 0.35740)
# 1 ROUGE-1 Average_F: 0.38351 (95%-conf.int. 0.37339 - 0.39352)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.08820 (95%-conf.int. 0.08014 - 0.09677)
# 1 ROUGE-2 Average_P: 0.07152 (95%-conf.int. 0.06498 - 0.07832)
# 1 ROUGE-2 Average_F: 0.07887 (95%-conf.int. 0.07166 - 0.08641)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.02899 (95%-conf.int. 0.02441 - 0.03410)
# 1 ROUGE-3 Average_P: 0.02346 (95%-conf.int. 0.01971 - 0.02748)
# 1 ROUGE-3 Average_F: 0.02589 (95%-conf.int. 0.02178 - 0.03036)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.01487 (95%-conf.int. 0.01177 - 0.01854)
# 1 ROUGE-4 Average_P: 0.01199 (95%-conf.int. 0.00943 - 0.01495)
# 1 ROUGE-4 Average_F: 0.01325 (95%-conf.int. 0.01047 - 0.01651)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.39716 (95%-conf.int. 0.38564 - 0.40991)
# 1 ROUGE-L Average_P: 0.32227 (95%-conf.int. 0.31252 - 0.33175)
# 1 ROUGE-L Average_F: 0.35534 (95%-conf.int. 0.34543 - 0.36535)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.11474 (95%-conf.int. 0.11093 - 0.11866)
# 1 ROUGE-W-1.2 Average_P: 0.17255 (95%-conf.int. 0.16690 - 0.17779)
# 1 ROUGE-W-1.2 Average_F: 0.13761 (95%-conf.int. 0.13343 - 0.14193)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.17098 (95%-conf.int. 0.16202 - 0.18073)
# 1 ROUGE-S* Average_P: 0.11272 (95%-conf.int. 0.10669 - 0.11847)
# 1 ROUGE-S* Average_F: 0.13517 (95%-conf.int. 0.12875 - 0.14171)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.17302 (95%-conf.int. 0.16405 - 0.18281)
# 1 ROUGE-SU* Average_P: 0.11423 (95%-conf.int. 0.10817 - 0.11999)
# 1 ROUGE-SU* Average_F: 0.13692 (95%-conf.int. 0.13046 - 0.14348)
#
# 5
