# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 5
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func_glob()

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
#count_score
#score_func = ones#get_w2v_score_func()#get_tfidf_score_func()#count_score
score_func = get_tfidf_score_func()

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-14 10:34:17,043 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 10:34:17,047 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpw8Z1cl/system and model files to /tmp/tmpw8Z1cl/model.
# 2019-02-14 10:34:17,048 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 10:34:17,049 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 10:34:17,052 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 10:34:17,054 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 10:34:17,056 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 10:34:17,059 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 10:34:17,061 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 10:34:17,063 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 10:34:17,065 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 10:34:17,067 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 10:34:17,069 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 10:34:17,071 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 10:34:17,073 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 10:34:17,075 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 10:34:17,077 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 10:34:17,079 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 10:34:17,081 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 10:34:17,083 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 10:34:17,085 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 10:34:17,087 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 10:34:17,090 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 10:34:17,092 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 10:34:17,094 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 10:34:17,096 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 10:34:17,098 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 10:34:17,100 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 10:34:17,102 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 10:34:17,104 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 10:34:17,106 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 10:34:17,108 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 10:34:17,110 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 10:34:17,112 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 10:34:17,114 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 10:34:17,116 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 10:34:17,118 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 10:34:17,120 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 10:34:17,122 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 10:34:17,124 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 10:34:17,126 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 10:34:17,128 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 10:34:17,131 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 10:34:17,133 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 10:34:17,135 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 10:34:17,137 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 10:34:17,139 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 10:34:17,141 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 10:34:17,143 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-14 10:34:17,145 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-14 10:34:17,147 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-14 10:34:17,149 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-14 10:34:17,151 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-14 10:34:17,153 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpw8Z1cl/system.
# 2019-02-14 10:34:17,154 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 10:34:17,155 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 10:34:17,157 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 10:34:17,159 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 10:34:17,162 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 10:34:17,164 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 10:34:17,166 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 10:34:17,168 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 10:34:17,170 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 10:34:17,172 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 10:34:17,174 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 10:34:17,176 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 10:34:17,178 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 10:34:17,181 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 10:34:17,183 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 10:34:17,185 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 10:34:17,187 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 10:34:17,189 [MainThread  ] [INFO ]  Processing 3_reference_4.txt.
# 2019-02-14 10:34:17,191 [MainThread  ] [INFO ]  Processing 3_reference_5.txt.
# 2019-02-14 10:34:17,193 [MainThread  ] [INFO ]  Processing 3_reference_6.txt.
# 2019-02-14 10:34:17,196 [MainThread  ] [INFO ]  Processing 3_reference_7.txt.
# 2019-02-14 10:34:17,198 [MainThread  ] [INFO ]  Processing 3_reference_8.txt.
# 2019-02-14 10:34:17,200 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 10:34:17,202 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 10:34:17,204 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 10:34:17,207 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 10:34:17,209 [MainThread  ] [INFO ]  Processing 4_reference_4.txt.
# 2019-02-14 10:34:17,211 [MainThread  ] [INFO ]  Processing 4_reference_5.txt.
# 2019-02-14 10:34:17,213 [MainThread  ] [INFO ]  Processing 4_reference_6.txt.
# 2019-02-14 10:34:17,215 [MainThread  ] [INFO ]  Processing 4_reference_7.txt.
# 2019-02-14 10:34:17,218 [MainThread  ] [INFO ]  Processing 4_reference_8.txt.
# 2019-02-14 10:34:17,220 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 10:34:17,222 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 10:34:17,225 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 10:34:17,227 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 10:34:17,229 [MainThread  ] [INFO ]  Processing 5_reference_4.txt.
# 2019-02-14 10:34:17,232 [MainThread  ] [INFO ]  Processing 5_reference_5.txt.
# 2019-02-14 10:34:17,234 [MainThread  ] [INFO ]  Processing 5_reference_6.txt.
# 2019-02-14 10:34:17,236 [MainThread  ] [INFO ]  Processing 5_reference_7.txt.
# 2019-02-14 10:34:17,238 [MainThread  ] [INFO ]  Processing 5_reference_8.txt.
# 2019-02-14 10:34:17,240 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 10:34:17,242 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 10:34:17,245 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 10:34:17,247 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 10:34:17,249 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 10:34:17,251 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 10:34:17,253 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 10:34:17,255 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 10:34:17,257 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 10:34:17,260 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 10:34:17,262 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 10:34:17,264 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 10:34:17,266 [MainThread  ] [INFO ]  Processing 8_reference_4.txt.
# 2019-02-14 10:34:17,269 [MainThread  ] [INFO ]  Processing 8_reference_5.txt.
# 2019-02-14 10:34:17,271 [MainThread  ] [INFO ]  Processing 8_reference_6.txt.
# 2019-02-14 10:34:17,273 [MainThread  ] [INFO ]  Processing 8_reference_7.txt.
# 2019-02-14 10:34:17,275 [MainThread  ] [INFO ]  Processing 8_reference_8.txt.
# 2019-02-14 10:34:17,277 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 10:34:17,279 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 10:34:17,282 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 10:34:17,284 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 10:34:17,286 [MainThread  ] [INFO ]  Processing 9_reference_4.txt.
# 2019-02-14 10:34:17,288 [MainThread  ] [INFO ]  Processing 9_reference_5.txt.
# 2019-02-14 10:34:17,290 [MainThread  ] [INFO ]  Processing 9_reference_6.txt.
# 2019-02-14 10:34:17,292 [MainThread  ] [INFO ]  Processing 9_reference_7.txt.
# 2019-02-14 10:34:17,295 [MainThread  ] [INFO ]  Processing 9_reference_8.txt.
# 2019-02-14 10:34:17,297 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 10:34:17,299 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 10:34:17,301 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 10:34:17,303 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 10:34:17,305 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 10:34:17,307 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 10:34:17,310 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 10:34:17,312 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 10:34:17,314 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 10:34:17,317 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 10:34:17,319 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 10:34:17,322 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 10:34:17,324 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 10:34:17,326 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 10:34:17,328 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 10:34:17,330 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 10:34:17,333 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 10:34:17,335 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 10:34:17,337 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 10:34:17,339 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 10:34:17,341 [MainThread  ] [INFO ]  Processing 14_reference_4.txt.
# 2019-02-14 10:34:17,343 [MainThread  ] [INFO ]  Processing 14_reference_5.txt.
# 2019-02-14 10:34:17,345 [MainThread  ] [INFO ]  Processing 14_reference_6.txt.
# 2019-02-14 10:34:17,347 [MainThread  ] [INFO ]  Processing 14_reference_7.txt.
# 2019-02-14 10:34:17,349 [MainThread  ] [INFO ]  Processing 14_reference_8.txt.
# 2019-02-14 10:34:17,352 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 10:34:17,354 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 10:34:17,356 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 10:34:17,359 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 10:34:17,361 [MainThread  ] [INFO ]  Processing 15_reference_4.txt.
# 2019-02-14 10:34:17,364 [MainThread  ] [INFO ]  Processing 15_reference_5.txt.
# 2019-02-14 10:34:17,366 [MainThread  ] [INFO ]  Processing 15_reference_6.txt.
# 2019-02-14 10:34:17,368 [MainThread  ] [INFO ]  Processing 15_reference_7.txt.
# 2019-02-14 10:34:17,371 [MainThread  ] [INFO ]  Processing 15_reference_8.txt.
# 2019-02-14 10:34:17,373 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 10:34:17,375 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 10:34:17,377 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 10:34:17,380 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 10:34:17,382 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 10:34:17,384 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 10:34:17,386 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 10:34:17,389 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 10:34:17,391 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 10:34:17,393 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 10:34:17,395 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 10:34:17,397 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 10:34:17,399 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 10:34:17,401 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 10:34:17,404 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 10:34:17,406 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 10:34:17,408 [MainThread  ] [INFO ]  Processing 19_reference_4.txt.
# 2019-02-14 10:34:17,410 [MainThread  ] [INFO ]  Processing 19_reference_5.txt.
# 2019-02-14 10:34:17,411 [MainThread  ] [INFO ]  Processing 19_reference_6.txt.
# 2019-02-14 10:34:17,414 [MainThread  ] [INFO ]  Processing 19_reference_7.txt.
# 2019-02-14 10:34:17,416 [MainThread  ] [INFO ]  Processing 19_reference_8.txt.
# 2019-02-14 10:34:17,418 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 10:34:17,420 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 10:34:17,422 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 10:34:17,425 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 10:34:17,427 [MainThread  ] [INFO ]  Processing 20_reference_4.txt.
# 2019-02-14 10:34:17,429 [MainThread  ] [INFO ]  Processing 20_reference_5.txt.
# 2019-02-14 10:34:17,431 [MainThread  ] [INFO ]  Processing 20_reference_6.txt.
# 2019-02-14 10:34:17,434 [MainThread  ] [INFO ]  Processing 20_reference_7.txt.
# 2019-02-14 10:34:17,436 [MainThread  ] [INFO ]  Processing 20_reference_8.txt.
# 2019-02-14 10:34:17,438 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 10:34:17,441 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 10:34:17,443 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 10:34:17,445 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 10:34:17,447 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 10:34:17,449 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 10:34:17,451 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 10:34:17,453 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 10:34:17,456 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 10:34:17,458 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 10:34:17,460 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 10:34:17,462 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 10:34:17,464 [MainThread  ] [INFO ]  Processing 23_reference_4.txt.
# 2019-02-14 10:34:17,467 [MainThread  ] [INFO ]  Processing 23_reference_5.txt.
# 2019-02-14 10:34:17,469 [MainThread  ] [INFO ]  Processing 23_reference_6.txt.
# 2019-02-14 10:34:17,471 [MainThread  ] [INFO ]  Processing 23_reference_7.txt.
# 2019-02-14 10:34:17,473 [MainThread  ] [INFO ]  Processing 23_reference_8.txt.
# 2019-02-14 10:34:17,475 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 10:34:17,477 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 10:34:17,479 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 10:34:17,482 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 10:34:17,484 [MainThread  ] [INFO ]  Processing 24_reference_4.txt.
# 2019-02-14 10:34:17,486 [MainThread  ] [INFO ]  Processing 24_reference_5.txt.
# 2019-02-14 10:34:17,488 [MainThread  ] [INFO ]  Processing 24_reference_6.txt.
# 2019-02-14 10:34:17,490 [MainThread  ] [INFO ]  Processing 24_reference_7.txt.
# 2019-02-14 10:34:17,493 [MainThread  ] [INFO ]  Processing 24_reference_8.txt.
# 2019-02-14 10:34:17,495 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 10:34:17,497 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 10:34:17,499 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 10:34:17,501 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 10:34:17,503 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 10:34:17,506 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 10:34:17,508 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 10:34:17,510 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 10:34:17,512 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 10:34:17,514 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 10:34:17,516 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 10:34:17,519 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 10:34:17,521 [MainThread  ] [INFO ]  Processing 27_reference_4.txt.
# 2019-02-14 10:34:17,523 [MainThread  ] [INFO ]  Processing 27_reference_5.txt.
# 2019-02-14 10:34:17,525 [MainThread  ] [INFO ]  Processing 27_reference_6.txt.
# 2019-02-14 10:34:17,527 [MainThread  ] [INFO ]  Processing 27_reference_7.txt.
# 2019-02-14 10:34:17,530 [MainThread  ] [INFO ]  Processing 27_reference_8.txt.
# 2019-02-14 10:34:17,532 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 10:34:17,534 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 10:34:17,536 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 10:34:17,538 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 10:34:17,540 [MainThread  ] [INFO ]  Processing 28_reference_4.txt.
# 2019-02-14 10:34:17,542 [MainThread  ] [INFO ]  Processing 28_reference_5.txt.
# 2019-02-14 10:34:17,544 [MainThread  ] [INFO ]  Processing 28_reference_6.txt.
# 2019-02-14 10:34:17,547 [MainThread  ] [INFO ]  Processing 28_reference_7.txt.
# 2019-02-14 10:34:17,549 [MainThread  ] [INFO ]  Processing 28_reference_8.txt.
# 2019-02-14 10:34:17,551 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 10:34:17,554 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 10:34:17,556 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 10:34:17,558 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 10:34:17,560 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 10:34:17,562 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 10:34:17,565 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 10:34:17,567 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 10:34:17,569 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 10:34:17,571 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 10:34:17,573 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 10:34:17,575 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 10:34:17,577 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 10:34:17,580 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 10:34:17,582 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 10:34:17,584 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 10:34:17,586 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 10:34:17,588 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 10:34:17,591 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 10:34:17,594 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 10:34:17,596 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 10:34:17,598 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 10:34:17,600 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 10:34:17,603 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 10:34:17,605 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 10:34:17,607 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 10:34:17,609 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 10:34:17,611 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 10:34:17,614 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 10:34:17,616 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 10:34:17,618 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 10:34:17,620 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 10:34:17,622 [MainThread  ] [INFO ]  Processing 36_reference_4.txt.
# 2019-02-14 10:34:17,624 [MainThread  ] [INFO ]  Processing 36_reference_5.txt.
# 2019-02-14 10:34:17,626 [MainThread  ] [INFO ]  Processing 36_reference_6.txt.
# 2019-02-14 10:34:17,628 [MainThread  ] [INFO ]  Processing 36_reference_7.txt.
# 2019-02-14 10:34:17,631 [MainThread  ] [INFO ]  Processing 36_reference_8.txt.
# 2019-02-14 10:34:17,633 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 10:34:17,635 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 10:34:17,637 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 10:34:17,639 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 10:34:17,642 [MainThread  ] [INFO ]  Processing 37_reference_4.txt.
# 2019-02-14 10:34:17,644 [MainThread  ] [INFO ]  Processing 37_reference_5.txt.
# 2019-02-14 10:34:17,646 [MainThread  ] [INFO ]  Processing 37_reference_6.txt.
# 2019-02-14 10:34:17,648 [MainThread  ] [INFO ]  Processing 37_reference_7.txt.
# 2019-02-14 10:34:17,650 [MainThread  ] [INFO ]  Processing 37_reference_8.txt.
# 2019-02-14 10:34:17,653 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 10:34:17,655 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 10:34:17,657 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 10:34:17,659 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 10:34:17,661 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 10:34:17,663 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 10:34:17,666 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 10:34:17,668 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 10:34:17,670 [MainThread  ] [INFO ]  Processing 39_reference_4.txt.
# 2019-02-14 10:34:17,673 [MainThread  ] [INFO ]  Processing 39_reference_5.txt.
# 2019-02-14 10:34:17,675 [MainThread  ] [INFO ]  Processing 39_reference_6.txt.
# 2019-02-14 10:34:17,677 [MainThread  ] [INFO ]  Processing 39_reference_7.txt.
# 2019-02-14 10:34:17,679 [MainThread  ] [INFO ]  Processing 39_reference_8.txt.
# 2019-02-14 10:34:17,681 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 10:34:17,683 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 10:34:17,686 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 10:34:17,688 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 10:34:17,690 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 10:34:17,692 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 10:34:17,694 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 10:34:17,696 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 10:34:17,699 [MainThread  ] [INFO ]  Processing 41_reference_4.txt.
# 2019-02-14 10:34:17,701 [MainThread  ] [INFO ]  Processing 41_reference_5.txt.
# 2019-02-14 10:34:17,703 [MainThread  ] [INFO ]  Processing 41_reference_6.txt.
# 2019-02-14 10:34:17,706 [MainThread  ] [INFO ]  Processing 41_reference_7.txt.
# 2019-02-14 10:34:17,709 [MainThread  ] [INFO ]  Processing 41_reference_8.txt.
# 2019-02-14 10:34:17,711 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 10:34:17,713 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 10:34:17,715 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 10:34:17,717 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 10:34:17,720 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 10:34:17,722 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 10:34:17,724 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 10:34:17,726 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 10:34:17,728 [MainThread  ] [INFO ]  Processing 43_reference_4.txt.
# 2019-02-14 10:34:17,731 [MainThread  ] [INFO ]  Processing 43_reference_5.txt.
# 2019-02-14 10:34:17,733 [MainThread  ] [INFO ]  Processing 43_reference_6.txt.
# 2019-02-14 10:34:17,735 [MainThread  ] [INFO ]  Processing 43_reference_7.txt.
# 2019-02-14 10:34:17,737 [MainThread  ] [INFO ]  Processing 43_reference_8.txt.
# 2019-02-14 10:34:17,739 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 10:34:17,741 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 10:34:17,743 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 10:34:17,745 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 10:34:17,748 [MainThread  ] [INFO ]  Processing 44_reference_4.txt.
# 2019-02-14 10:34:17,750 [MainThread  ] [INFO ]  Processing 44_reference_5.txt.
# 2019-02-14 10:34:17,752 [MainThread  ] [INFO ]  Processing 44_reference_6.txt.
# 2019-02-14 10:34:17,754 [MainThread  ] [INFO ]  Processing 44_reference_7.txt.
# 2019-02-14 10:34:17,756 [MainThread  ] [INFO ]  Processing 44_reference_8.txt.
# 2019-02-14 10:34:17,759 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-14 10:34:17,761 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-14 10:34:17,763 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-14 10:34:17,765 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-14 10:34:17,767 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-14 10:34:17,769 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-14 10:34:17,772 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-14 10:34:17,774 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-14 10:34:17,776 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-14 10:34:17,778 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-14 10:34:17,780 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-14 10:34:17,782 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-14 10:34:17,785 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-14 10:34:17,787 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-14 10:34:17,789 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-14 10:34:17,791 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-14 10:34:17,793 [MainThread  ] [INFO ]  Processing 48_reference_4.txt.
# 2019-02-14 10:34:17,796 [MainThread  ] [INFO ]  Processing 48_reference_5.txt.
# 2019-02-14 10:34:17,798 [MainThread  ] [INFO ]  Processing 48_reference_6.txt.
# 2019-02-14 10:34:17,800 [MainThread  ] [INFO ]  Processing 48_reference_7.txt.
# 2019-02-14 10:34:17,802 [MainThread  ] [INFO ]  Processing 48_reference_8.txt.
# 2019-02-14 10:34:17,804 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-14 10:34:17,806 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-14 10:34:17,808 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-14 10:34:17,811 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-14 10:34:17,813 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpw8Z1cl/model.
# 2019-02-14 10:34:17,839 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpZ36wf0/rouge_conf.xml
# 2019-02-14 10:34:17,840 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpZ36wf0/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.08110 (95%-conf.int. 0.07289 - 0.08875)
# 1 ROUGE-1 Average_P: 0.36696 (95%-conf.int. 0.33830 - 0.39341)
# 1 ROUGE-1 Average_F: 0.13171 (95%-conf.int. 0.11914 - 0.14315)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01159 (95%-conf.int. 0.00901 - 0.01427)
# 1 ROUGE-2 Average_P: 0.05479 (95%-conf.int. 0.04315 - 0.06625)
# 1 ROUGE-2 Average_F: 0.01897 (95%-conf.int. 0.01482 - 0.02326)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00281 (95%-conf.int. 0.00165 - 0.00414)
# 1 ROUGE-3 Average_P: 0.01340 (95%-conf.int. 0.00794 - 0.01907)
# 1 ROUGE-3 Average_F: 0.00460 (95%-conf.int. 0.00275 - 0.00674)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00104 (95%-conf.int. 0.00034 - 0.00195)
# 1 ROUGE-4 Average_P: 0.00482 (95%-conf.int. 0.00178 - 0.00851)
# 1 ROUGE-4 Average_F: 0.00170 (95%-conf.int. 0.00057 - 0.00315)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.07488 (95%-conf.int. 0.06744 - 0.08197)
# 1 ROUGE-L Average_P: 0.33934 (95%-conf.int. 0.31330 - 0.36352)
# 1 ROUGE-L Average_F: 0.12166 (95%-conf.int. 0.11028 - 0.13249)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.02498 (95%-conf.int. 0.02273 - 0.02703)
# 1 ROUGE-W-1.2 Average_P: 0.21170 (95%-conf.int. 0.19727 - 0.22529)
# 1 ROUGE-W-1.2 Average_F: 0.04444 (95%-conf.int. 0.04059 - 0.04794)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.00735 (95%-conf.int. 0.00604 - 0.00868)
# 1 ROUGE-S* Average_P: 0.14544 (95%-conf.int. 0.12708 - 0.16348)
# 1 ROUGE-S* Average_F: 0.01385 (95%-conf.int. 0.01144 - 0.01623)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.00792 (95%-conf.int. 0.00657 - 0.00931)
# 1 ROUGE-SU* Average_P: 0.15369 (95%-conf.int. 0.13524 - 0.17204)
# 1 ROUGE-SU* Average_F: 0.01492 (95%-conf.int. 0.01243 - 0.01739)
#
# 5
# <function tfidf_score_func at 0x7ff0a01e8050>
