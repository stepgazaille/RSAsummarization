# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 5
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func_glob()

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
#count_score
#score_func = ones#get_w2v_score_func()#get_tfidf_score_func()#count_score
score_func = get_tfidf_score_func()

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-12 08:00:10,282 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 08:00:10,285 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpElB7Vt/system and model files to /tmp/tmpElB7Vt/model.
# 2019-02-12 08:00:10,286 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 08:00:10,288 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 08:00:10,290 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 08:00:10,292 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 08:00:10,294 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 08:00:10,296 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 08:00:10,298 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 08:00:10,300 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 08:00:10,302 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 08:00:10,304 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 08:00:10,306 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 08:00:10,308 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 08:00:10,310 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 08:00:10,312 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 08:00:10,314 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 08:00:10,316 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 08:00:10,318 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 08:00:10,320 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 08:00:10,322 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 08:00:10,324 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 08:00:10,327 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 08:00:10,329 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 08:00:10,331 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 08:00:10,333 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 08:00:10,335 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 08:00:10,337 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 08:00:10,339 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 08:00:10,341 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 08:00:10,343 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 08:00:10,345 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 08:00:10,347 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 08:00:10,349 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 08:00:10,351 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 08:00:10,353 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 08:00:10,355 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 08:00:10,357 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 08:00:10,359 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 08:00:10,361 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 08:00:10,363 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 08:00:10,365 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 08:00:10,368 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 08:00:10,370 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 08:00:10,372 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 08:00:10,374 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 08:00:10,376 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 08:00:10,378 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 08:00:10,380 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-12 08:00:10,382 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-12 08:00:10,384 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-12 08:00:10,386 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-12 08:00:10,388 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-12 08:00:10,390 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpElB7Vt/system.
# 2019-02-12 08:00:10,391 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 08:00:10,392 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 08:00:10,395 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 08:00:10,397 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 08:00:10,399 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 08:00:10,401 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 08:00:10,403 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 08:00:10,405 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 08:00:10,408 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 08:00:10,410 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 08:00:10,412 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 08:00:10,414 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 08:00:10,416 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 08:00:10,419 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 08:00:10,421 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 08:00:10,423 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 08:00:10,425 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 08:00:10,427 [MainThread  ] [INFO ]  Processing 3_reference_4.txt.
# 2019-02-12 08:00:10,429 [MainThread  ] [INFO ]  Processing 3_reference_5.txt.
# 2019-02-12 08:00:10,432 [MainThread  ] [INFO ]  Processing 3_reference_6.txt.
# 2019-02-12 08:00:10,434 [MainThread  ] [INFO ]  Processing 3_reference_7.txt.
# 2019-02-12 08:00:10,436 [MainThread  ] [INFO ]  Processing 3_reference_8.txt.
# 2019-02-12 08:00:10,438 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 08:00:10,441 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 08:00:10,443 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 08:00:10,445 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 08:00:10,447 [MainThread  ] [INFO ]  Processing 4_reference_4.txt.
# 2019-02-12 08:00:10,450 [MainThread  ] [INFO ]  Processing 4_reference_5.txt.
# 2019-02-12 08:00:10,452 [MainThread  ] [INFO ]  Processing 4_reference_6.txt.
# 2019-02-12 08:00:10,454 [MainThread  ] [INFO ]  Processing 4_reference_7.txt.
# 2019-02-12 08:00:10,456 [MainThread  ] [INFO ]  Processing 4_reference_8.txt.
# 2019-02-12 08:00:10,459 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 08:00:10,461 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 08:00:10,463 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 08:00:10,466 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 08:00:10,468 [MainThread  ] [INFO ]  Processing 5_reference_4.txt.
# 2019-02-12 08:00:10,470 [MainThread  ] [INFO ]  Processing 5_reference_5.txt.
# 2019-02-12 08:00:10,472 [MainThread  ] [INFO ]  Processing 5_reference_6.txt.
# 2019-02-12 08:00:10,475 [MainThread  ] [INFO ]  Processing 5_reference_7.txt.
# 2019-02-12 08:00:10,477 [MainThread  ] [INFO ]  Processing 5_reference_8.txt.
# 2019-02-12 08:00:10,479 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 08:00:10,481 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 08:00:10,484 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 08:00:10,486 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 08:00:10,488 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 08:00:10,490 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 08:00:10,493 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 08:00:10,495 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 08:00:10,497 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 08:00:10,499 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 08:00:10,502 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 08:00:10,504 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 08:00:10,506 [MainThread  ] [INFO ]  Processing 8_reference_4.txt.
# 2019-02-12 08:00:10,509 [MainThread  ] [INFO ]  Processing 8_reference_5.txt.
# 2019-02-12 08:00:10,511 [MainThread  ] [INFO ]  Processing 8_reference_6.txt.
# 2019-02-12 08:00:10,513 [MainThread  ] [INFO ]  Processing 8_reference_7.txt.
# 2019-02-12 08:00:10,515 [MainThread  ] [INFO ]  Processing 8_reference_8.txt.
# 2019-02-12 08:00:10,517 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 08:00:10,520 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 08:00:10,522 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 08:00:10,524 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 08:00:10,526 [MainThread  ] [INFO ]  Processing 9_reference_4.txt.
# 2019-02-12 08:00:10,528 [MainThread  ] [INFO ]  Processing 9_reference_5.txt.
# 2019-02-12 08:00:10,531 [MainThread  ] [INFO ]  Processing 9_reference_6.txt.
# 2019-02-12 08:00:10,533 [MainThread  ] [INFO ]  Processing 9_reference_7.txt.
# 2019-02-12 08:00:10,535 [MainThread  ] [INFO ]  Processing 9_reference_8.txt.
# 2019-02-12 08:00:10,537 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 08:00:10,539 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 08:00:10,541 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 08:00:10,543 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 08:00:10,545 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 08:00:10,548 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 08:00:10,550 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 08:00:10,552 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 08:00:10,554 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 08:00:10,556 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 08:00:10,559 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 08:00:10,561 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 08:00:10,563 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 08:00:10,566 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 08:00:10,568 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 08:00:10,570 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 08:00:10,572 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 08:00:10,575 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 08:00:10,577 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 08:00:10,579 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 08:00:10,581 [MainThread  ] [INFO ]  Processing 14_reference_4.txt.
# 2019-02-12 08:00:10,583 [MainThread  ] [INFO ]  Processing 14_reference_5.txt.
# 2019-02-12 08:00:10,585 [MainThread  ] [INFO ]  Processing 14_reference_6.txt.
# 2019-02-12 08:00:10,587 [MainThread  ] [INFO ]  Processing 14_reference_7.txt.
# 2019-02-12 08:00:10,590 [MainThread  ] [INFO ]  Processing 14_reference_8.txt.
# 2019-02-12 08:00:10,592 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 08:00:10,594 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 08:00:10,596 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 08:00:10,599 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 08:00:10,601 [MainThread  ] [INFO ]  Processing 15_reference_4.txt.
# 2019-02-12 08:00:10,603 [MainThread  ] [INFO ]  Processing 15_reference_5.txt.
# 2019-02-12 08:00:10,605 [MainThread  ] [INFO ]  Processing 15_reference_6.txt.
# 2019-02-12 08:00:10,607 [MainThread  ] [INFO ]  Processing 15_reference_7.txt.
# 2019-02-12 08:00:10,609 [MainThread  ] [INFO ]  Processing 15_reference_8.txt.
# 2019-02-12 08:00:10,612 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 08:00:10,614 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 08:00:10,617 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 08:00:10,619 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 08:00:10,621 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 08:00:10,624 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 08:00:10,626 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 08:00:10,628 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 08:00:10,630 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 08:00:10,632 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 08:00:10,634 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 08:00:10,637 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 08:00:10,639 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 08:00:10,641 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 08:00:10,643 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 08:00:10,646 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 08:00:10,648 [MainThread  ] [INFO ]  Processing 19_reference_4.txt.
# 2019-02-12 08:00:10,650 [MainThread  ] [INFO ]  Processing 19_reference_5.txt.
# 2019-02-12 08:00:10,652 [MainThread  ] [INFO ]  Processing 19_reference_6.txt.
# 2019-02-12 08:00:10,654 [MainThread  ] [INFO ]  Processing 19_reference_7.txt.
# 2019-02-12 08:00:10,656 [MainThread  ] [INFO ]  Processing 19_reference_8.txt.
# 2019-02-12 08:00:10,659 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 08:00:10,661 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 08:00:10,663 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 08:00:10,665 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 08:00:10,667 [MainThread  ] [INFO ]  Processing 20_reference_4.txt.
# 2019-02-12 08:00:10,670 [MainThread  ] [INFO ]  Processing 20_reference_5.txt.
# 2019-02-12 08:00:10,672 [MainThread  ] [INFO ]  Processing 20_reference_6.txt.
# 2019-02-12 08:00:10,674 [MainThread  ] [INFO ]  Processing 20_reference_7.txt.
# 2019-02-12 08:00:10,677 [MainThread  ] [INFO ]  Processing 20_reference_8.txt.
# 2019-02-12 08:00:10,679 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 08:00:10,681 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 08:00:10,683 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 08:00:10,686 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 08:00:10,688 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 08:00:10,690 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 08:00:10,692 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 08:00:10,694 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 08:00:10,696 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 08:00:10,698 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 08:00:10,701 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 08:00:10,703 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 08:00:10,705 [MainThread  ] [INFO ]  Processing 23_reference_4.txt.
# 2019-02-12 08:00:10,707 [MainThread  ] [INFO ]  Processing 23_reference_5.txt.
# 2019-02-12 08:00:10,709 [MainThread  ] [INFO ]  Processing 23_reference_6.txt.
# 2019-02-12 08:00:10,712 [MainThread  ] [INFO ]  Processing 23_reference_7.txt.
# 2019-02-12 08:00:10,714 [MainThread  ] [INFO ]  Processing 23_reference_8.txt.
# 2019-02-12 08:00:10,716 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 08:00:10,719 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 08:00:10,721 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 08:00:10,723 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 08:00:10,725 [MainThread  ] [INFO ]  Processing 24_reference_4.txt.
# 2019-02-12 08:00:10,727 [MainThread  ] [INFO ]  Processing 24_reference_5.txt.
# 2019-02-12 08:00:10,730 [MainThread  ] [INFO ]  Processing 24_reference_6.txt.
# 2019-02-12 08:00:10,732 [MainThread  ] [INFO ]  Processing 24_reference_7.txt.
# 2019-02-12 08:00:10,734 [MainThread  ] [INFO ]  Processing 24_reference_8.txt.
# 2019-02-12 08:00:10,736 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 08:00:10,738 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 08:00:10,741 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 08:00:10,743 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 08:00:10,745 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 08:00:10,747 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 08:00:10,749 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 08:00:10,751 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 08:00:10,753 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 08:00:10,756 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 08:00:10,758 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 08:00:10,761 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 08:00:10,763 [MainThread  ] [INFO ]  Processing 27_reference_4.txt.
# 2019-02-12 08:00:10,765 [MainThread  ] [INFO ]  Processing 27_reference_5.txt.
# 2019-02-12 08:00:10,767 [MainThread  ] [INFO ]  Processing 27_reference_6.txt.
# 2019-02-12 08:00:10,770 [MainThread  ] [INFO ]  Processing 27_reference_7.txt.
# 2019-02-12 08:00:10,772 [MainThread  ] [INFO ]  Processing 27_reference_8.txt.
# 2019-02-12 08:00:10,774 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 08:00:10,776 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 08:00:10,778 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 08:00:10,780 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 08:00:10,782 [MainThread  ] [INFO ]  Processing 28_reference_4.txt.
# 2019-02-12 08:00:10,785 [MainThread  ] [INFO ]  Processing 28_reference_5.txt.
# 2019-02-12 08:00:10,787 [MainThread  ] [INFO ]  Processing 28_reference_6.txt.
# 2019-02-12 08:00:10,789 [MainThread  ] [INFO ]  Processing 28_reference_7.txt.
# 2019-02-12 08:00:10,791 [MainThread  ] [INFO ]  Processing 28_reference_8.txt.
# 2019-02-12 08:00:10,793 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 08:00:10,795 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 08:00:10,797 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 08:00:10,800 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 08:00:10,802 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 08:00:10,804 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 08:00:10,806 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 08:00:10,808 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 08:00:10,810 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 08:00:10,813 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 08:00:10,815 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 08:00:10,817 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 08:00:10,819 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 08:00:10,822 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 08:00:10,824 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 08:00:10,826 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 08:00:10,828 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 08:00:10,830 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 08:00:10,832 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 08:00:10,834 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 08:00:10,837 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 08:00:10,839 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 08:00:10,841 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 08:00:10,843 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 08:00:10,846 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 08:00:10,848 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 08:00:10,850 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 08:00:10,852 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 08:00:10,854 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 08:00:10,857 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 08:00:10,859 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 08:00:10,861 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 08:00:10,863 [MainThread  ] [INFO ]  Processing 36_reference_4.txt.
# 2019-02-12 08:00:10,865 [MainThread  ] [INFO ]  Processing 36_reference_5.txt.
# 2019-02-12 08:00:10,868 [MainThread  ] [INFO ]  Processing 36_reference_6.txt.
# 2019-02-12 08:00:10,870 [MainThread  ] [INFO ]  Processing 36_reference_7.txt.
# 2019-02-12 08:00:10,872 [MainThread  ] [INFO ]  Processing 36_reference_8.txt.
# 2019-02-12 08:00:10,875 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 08:00:10,877 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 08:00:10,879 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 08:00:10,881 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 08:00:10,883 [MainThread  ] [INFO ]  Processing 37_reference_4.txt.
# 2019-02-12 08:00:10,886 [MainThread  ] [INFO ]  Processing 37_reference_5.txt.
# 2019-02-12 08:00:10,888 [MainThread  ] [INFO ]  Processing 37_reference_6.txt.
# 2019-02-12 08:00:10,890 [MainThread  ] [INFO ]  Processing 37_reference_7.txt.
# 2019-02-12 08:00:10,892 [MainThread  ] [INFO ]  Processing 37_reference_8.txt.
# 2019-02-12 08:00:10,894 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 08:00:10,896 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 08:00:10,899 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 08:00:10,901 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 08:00:10,903 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 08:00:10,905 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 08:00:10,907 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 08:00:10,909 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 08:00:10,912 [MainThread  ] [INFO ]  Processing 39_reference_4.txt.
# 2019-02-12 08:00:10,914 [MainThread  ] [INFO ]  Processing 39_reference_5.txt.
# 2019-02-12 08:00:10,916 [MainThread  ] [INFO ]  Processing 39_reference_6.txt.
# 2019-02-12 08:00:10,919 [MainThread  ] [INFO ]  Processing 39_reference_7.txt.
# 2019-02-12 08:00:10,921 [MainThread  ] [INFO ]  Processing 39_reference_8.txt.
# 2019-02-12 08:00:10,923 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 08:00:10,925 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 08:00:10,928 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 08:00:10,930 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 08:00:10,932 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 08:00:10,934 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 08:00:10,936 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 08:00:10,939 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 08:00:10,942 [MainThread  ] [INFO ]  Processing 41_reference_4.txt.
# 2019-02-12 08:00:10,944 [MainThread  ] [INFO ]  Processing 41_reference_5.txt.
# 2019-02-12 08:00:10,946 [MainThread  ] [INFO ]  Processing 41_reference_6.txt.
# 2019-02-12 08:00:10,948 [MainThread  ] [INFO ]  Processing 41_reference_7.txt.
# 2019-02-12 08:00:10,950 [MainThread  ] [INFO ]  Processing 41_reference_8.txt.
# 2019-02-12 08:00:10,953 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 08:00:10,955 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 08:00:10,957 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 08:00:10,959 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 08:00:10,961 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 08:00:10,963 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 08:00:10,965 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 08:00:10,968 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 08:00:10,970 [MainThread  ] [INFO ]  Processing 43_reference_4.txt.
# 2019-02-12 08:00:10,972 [MainThread  ] [INFO ]  Processing 43_reference_5.txt.
# 2019-02-12 08:00:10,974 [MainThread  ] [INFO ]  Processing 43_reference_6.txt.
# 2019-02-12 08:00:10,976 [MainThread  ] [INFO ]  Processing 43_reference_7.txt.
# 2019-02-12 08:00:10,979 [MainThread  ] [INFO ]  Processing 43_reference_8.txt.
# 2019-02-12 08:00:10,981 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 08:00:10,983 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 08:00:10,985 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 08:00:10,987 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 08:00:10,989 [MainThread  ] [INFO ]  Processing 44_reference_4.txt.
# 2019-02-12 08:00:10,991 [MainThread  ] [INFO ]  Processing 44_reference_5.txt.
# 2019-02-12 08:00:10,994 [MainThread  ] [INFO ]  Processing 44_reference_6.txt.
# 2019-02-12 08:00:10,996 [MainThread  ] [INFO ]  Processing 44_reference_7.txt.
# 2019-02-12 08:00:10,998 [MainThread  ] [INFO ]  Processing 44_reference_8.txt.
# 2019-02-12 08:00:11,000 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-12 08:00:11,002 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-12 08:00:11,005 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-12 08:00:11,007 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-12 08:00:11,010 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-12 08:00:11,012 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-12 08:00:11,014 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-12 08:00:11,017 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-12 08:00:11,019 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-12 08:00:11,021 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-12 08:00:11,023 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-12 08:00:11,025 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-12 08:00:11,027 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-12 08:00:11,030 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-12 08:00:11,032 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-12 08:00:11,035 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-12 08:00:11,037 [MainThread  ] [INFO ]  Processing 48_reference_4.txt.
# 2019-02-12 08:00:11,039 [MainThread  ] [INFO ]  Processing 48_reference_5.txt.
# 2019-02-12 08:00:11,041 [MainThread  ] [INFO ]  Processing 48_reference_6.txt.
# 2019-02-12 08:00:11,043 [MainThread  ] [INFO ]  Processing 48_reference_7.txt.
# 2019-02-12 08:00:11,046 [MainThread  ] [INFO ]  Processing 48_reference_8.txt.
# 2019-02-12 08:00:11,048 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-12 08:00:11,050 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-12 08:00:11,053 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-12 08:00:11,055 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-12 08:00:11,057 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpElB7Vt/model.
# 2019-02-12 08:00:11,083 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpvPydp4/rouge_conf.xml
# 2019-02-12 08:00:11,084 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpvPydp4/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.07374 (95%-conf.int. 0.06623 - 0.08103)
# 1 ROUGE-1 Average_P: 0.37283 (95%-conf.int. 0.34603 - 0.39877)
# 1 ROUGE-1 Average_F: 0.12228 (95%-conf.int. 0.11071 - 0.13356)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01022 (95%-conf.int. 0.00780 - 0.01278)
# 1 ROUGE-2 Average_P: 0.05141 (95%-conf.int. 0.04119 - 0.06170)
# 1 ROUGE-2 Average_F: 0.01693 (95%-conf.int. 0.01308 - 0.02088)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00213 (95%-conf.int. 0.00117 - 0.00328)
# 1 ROUGE-3 Average_P: 0.01049 (95%-conf.int. 0.00627 - 0.01537)
# 1 ROUGE-3 Average_F: 0.00351 (95%-conf.int. 0.00196 - 0.00536)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00076 (95%-conf.int. 0.00022 - 0.00145)
# 1 ROUGE-4 Average_P: 0.00333 (95%-conf.int. 0.00107 - 0.00614)
# 1 ROUGE-4 Average_F: 0.00123 (95%-conf.int. 0.00036 - 0.00234)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.06804 (95%-conf.int. 0.06101 - 0.07469)
# 1 ROUGE-L Average_P: 0.34460 (95%-conf.int. 0.31877 - 0.36938)
# 1 ROUGE-L Average_F: 0.11285 (95%-conf.int. 0.10202 - 0.12332)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.02286 (95%-conf.int. 0.02077 - 0.02482)
# 1 ROUGE-W-1.2 Average_P: 0.21641 (95%-conf.int. 0.20227 - 0.23025)
# 1 ROUGE-W-1.2 Average_F: 0.04117 (95%-conf.int. 0.03764 - 0.04444)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.00612 (95%-conf.int. 0.00494 - 0.00739)
# 1 ROUGE-S* Average_P: 0.14872 (95%-conf.int. 0.13084 - 0.16772)
# 1 ROUGE-S* Average_F: 0.01167 (95%-conf.int. 0.00947 - 0.01401)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.00665 (95%-conf.int. 0.00542 - 0.00798)
# 1 ROUGE-SU* Average_P: 0.15798 (95%-conf.int. 0.14004 - 0.17702)
# 1 ROUGE-SU* Average_F: 0.01266 (95%-conf.int. 0.01038 - 0.01511)
#
# 5
# <function tfidf_score_func at 0x7fdea6465140>
