# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 6
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func_glob()

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
#count_score
#score_func = ones#get_w2v_score_func()#get_tfidf_score_func()#count_score
score_func = get_tfidf_score_func()

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-12 08:06:30,830 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 08:06:30,834 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmp7M7Axr/system and model files to /tmp/tmp7M7Axr/model.
# 2019-02-12 08:06:30,835 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 08:06:30,836 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 08:06:30,838 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 08:06:30,841 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 08:06:30,843 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 08:06:30,845 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 08:06:30,847 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 08:06:30,849 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 08:06:30,851 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 08:06:30,853 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 08:06:30,856 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 08:06:30,858 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 08:06:30,860 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 08:06:30,862 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 08:06:30,864 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 08:06:30,866 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 08:06:30,868 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 08:06:30,870 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 08:06:30,872 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 08:06:30,874 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 08:06:30,876 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 08:06:30,878 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 08:06:30,880 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 08:06:30,882 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 08:06:30,884 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 08:06:30,886 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 08:06:30,889 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 08:06:30,891 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 08:06:30,893 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 08:06:30,895 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 08:06:30,897 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 08:06:30,899 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 08:06:30,901 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 08:06:30,903 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 08:06:30,906 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 08:06:30,908 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 08:06:30,910 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 08:06:30,912 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 08:06:30,914 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 08:06:30,916 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 08:06:30,918 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 08:06:30,920 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 08:06:30,922 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 08:06:30,925 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 08:06:30,927 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 08:06:30,929 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 08:06:30,931 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-12 08:06:30,933 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-12 08:06:30,935 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-12 08:06:30,937 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-12 08:06:30,939 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-12 08:06:30,941 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmp7M7Axr/system.
# 2019-02-12 08:06:30,942 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 08:06:30,944 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 08:06:30,946 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 08:06:30,948 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 08:06:30,950 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 08:06:30,953 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 08:06:30,955 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 08:06:30,957 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 08:06:30,959 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 08:06:30,961 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 08:06:30,964 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 08:06:30,966 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 08:06:30,968 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 08:06:30,970 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 08:06:30,973 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 08:06:30,975 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 08:06:30,978 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 08:06:30,980 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 08:06:30,982 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 08:06:30,984 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 08:06:30,987 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 08:06:30,989 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 08:06:30,991 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 08:06:30,993 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 08:06:30,996 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 08:06:30,998 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 08:06:31,000 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 08:06:31,002 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 08:06:31,005 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 08:06:31,007 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 08:06:31,009 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 08:06:31,011 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 08:06:31,014 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 08:06:31,017 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 08:06:31,019 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 08:06:31,021 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 08:06:31,024 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 08:06:31,026 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 08:06:31,028 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 08:06:31,030 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 08:06:31,032 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 08:06:31,035 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 08:06:31,037 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 08:06:31,040 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 08:06:31,042 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 08:06:31,045 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 08:06:31,047 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 08:06:31,050 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 08:06:31,052 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 08:06:31,054 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 08:06:31,057 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 08:06:31,059 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 08:06:31,061 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 08:06:31,064 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 08:06:31,066 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 08:06:31,068 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 08:06:31,070 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 08:06:31,073 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 08:06:31,075 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 08:06:31,077 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 08:06:31,079 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 08:06:31,082 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 08:06:31,084 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 08:06:31,086 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 08:06:31,088 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 08:06:31,091 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 08:06:31,093 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 08:06:31,095 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 08:06:31,097 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 08:06:31,100 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 08:06:31,102 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 08:06:31,104 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 08:06:31,107 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 08:06:31,109 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 08:06:31,111 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 08:06:31,113 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 08:06:31,116 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 08:06:31,118 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 08:06:31,120 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 08:06:31,122 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 08:06:31,125 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 08:06:31,127 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 08:06:31,129 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 08:06:31,131 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 08:06:31,133 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 08:06:31,136 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 08:06:31,138 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 08:06:31,140 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 08:06:31,143 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 08:06:31,145 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 08:06:31,147 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 08:06:31,150 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 08:06:31,152 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 08:06:31,155 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 08:06:31,157 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 08:06:31,159 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 08:06:31,161 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 08:06:31,164 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 08:06:31,166 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 08:06:31,168 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 08:06:31,170 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 08:06:31,172 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 08:06:31,175 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 08:06:31,177 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 08:06:31,179 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 08:06:31,181 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 08:06:31,184 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 08:06:31,186 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 08:06:31,188 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 08:06:31,191 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 08:06:31,193 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 08:06:31,195 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 08:06:31,198 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 08:06:31,200 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 08:06:31,202 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 08:06:31,204 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 08:06:31,207 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 08:06:31,209 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 08:06:31,211 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 08:06:31,214 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 08:06:31,216 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 08:06:31,218 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 08:06:31,221 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 08:06:31,223 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 08:06:31,225 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 08:06:31,228 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 08:06:31,230 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 08:06:31,232 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 08:06:31,234 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 08:06:31,237 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 08:06:31,239 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 08:06:31,241 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 08:06:31,244 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 08:06:31,246 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 08:06:31,248 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 08:06:31,251 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 08:06:31,253 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 08:06:31,255 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 08:06:31,257 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 08:06:31,260 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 08:06:31,262 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 08:06:31,264 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 08:06:31,266 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 08:06:31,268 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 08:06:31,270 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 08:06:31,273 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 08:06:31,275 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 08:06:31,277 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 08:06:31,280 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 08:06:31,282 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 08:06:31,284 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 08:06:31,287 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 08:06:31,289 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 08:06:31,291 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 08:06:31,293 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 08:06:31,296 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 08:06:31,298 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 08:06:31,300 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 08:06:31,302 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 08:06:31,305 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 08:06:31,307 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 08:06:31,309 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 08:06:31,311 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 08:06:31,313 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 08:06:31,316 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 08:06:31,318 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 08:06:31,320 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 08:06:31,323 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 08:06:31,325 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 08:06:31,327 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 08:06:31,329 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 08:06:31,331 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 08:06:31,333 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 08:06:31,335 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 08:06:31,337 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 08:06:31,339 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 08:06:31,341 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 08:06:31,344 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 08:06:31,346 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 08:06:31,348 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 08:06:31,350 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 08:06:31,353 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-12 08:06:31,355 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-12 08:06:31,357 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-12 08:06:31,359 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-12 08:06:31,362 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-12 08:06:31,364 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-12 08:06:31,366 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-12 08:06:31,368 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-12 08:06:31,370 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-12 08:06:31,373 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-12 08:06:31,375 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-12 08:06:31,377 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-12 08:06:31,379 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-12 08:06:31,381 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-12 08:06:31,384 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-12 08:06:31,386 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-12 08:06:31,388 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-12 08:06:31,390 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-12 08:06:31,392 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-12 08:06:31,394 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-12 08:06:31,396 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmp7M7Axr/model.
# 2019-02-12 08:06:31,415 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpC79uTw/rouge_conf.xml
# 2019-02-12 08:06:31,417 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpC79uTw/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.08350 (95%-conf.int. 0.07446 - 0.09271)
# 1 ROUGE-1 Average_P: 0.42984 (95%-conf.int. 0.40162 - 0.45670)
# 1 ROUGE-1 Average_F: 0.13844 (95%-conf.int. 0.12483 - 0.15164)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01394 (95%-conf.int. 0.01119 - 0.01663)
# 1 ROUGE-2 Average_P: 0.07265 (95%-conf.int. 0.05995 - 0.08532)
# 1 ROUGE-2 Average_F: 0.02315 (95%-conf.int. 0.01870 - 0.02747)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00290 (95%-conf.int. 0.00191 - 0.00402)
# 1 ROUGE-3 Average_P: 0.01556 (95%-conf.int. 0.01016 - 0.02216)
# 1 ROUGE-3 Average_F: 0.00484 (95%-conf.int. 0.00317 - 0.00672)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00096 (95%-conf.int. 0.00044 - 0.00162)
# 1 ROUGE-4 Average_P: 0.00548 (95%-conf.int. 0.00238 - 0.00992)
# 1 ROUGE-4 Average_F: 0.00161 (95%-conf.int. 0.00075 - 0.00276)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.07668 (95%-conf.int. 0.06865 - 0.08489)
# 1 ROUGE-L Average_P: 0.39630 (95%-conf.int. 0.36966 - 0.42189)
# 1 ROUGE-L Average_F: 0.12723 (95%-conf.int. 0.11481 - 0.13916)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.02547 (95%-conf.int. 0.02317 - 0.02780)
# 1 ROUGE-W-1.2 Average_P: 0.24328 (95%-conf.int. 0.22892 - 0.25673)
# 1 ROUGE-W-1.2 Average_F: 0.04581 (95%-conf.int. 0.04187 - 0.04970)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.00769 (95%-conf.int. 0.00607 - 0.00965)
# 1 ROUGE-S* Average_P: 0.18565 (95%-conf.int. 0.16344 - 0.20651)
# 1 ROUGE-S* Average_F: 0.01456 (95%-conf.int. 0.01163 - 0.01815)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.00827 (95%-conf.int. 0.00661 - 0.01028)
# 1 ROUGE-SU* Average_P: 0.19595 (95%-conf.int. 0.17351 - 0.21712)
# 1 ROUGE-SU* Average_F: 0.01566 (95%-conf.int. 0.01263 - 0.01929)
#
# 6
# <function tfidf_score_func at 0x7f2dabce7c08>
