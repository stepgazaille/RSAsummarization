# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 6
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func_glob()

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
#count_score
#score_func = ones#get_w2v_score_func()#get_tfidf_score_func()#count_score
score_func = get_tfidf_score_func()

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-14 10:41:28,765 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 10:41:28,769 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpZRn5eK/system and model files to /tmp/tmpZRn5eK/model.
# 2019-02-14 10:41:28,770 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 10:41:28,772 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 10:41:28,774 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 10:41:28,776 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 10:41:28,779 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 10:41:28,781 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 10:41:28,783 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 10:41:28,785 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 10:41:28,788 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 10:41:28,790 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 10:41:28,792 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 10:41:28,794 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 10:41:28,796 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 10:41:28,798 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 10:41:28,800 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 10:41:28,802 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 10:41:28,805 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 10:41:28,807 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 10:41:28,809 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 10:41:28,811 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 10:41:28,813 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 10:41:28,815 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 10:41:28,817 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 10:41:28,819 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 10:41:28,822 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 10:41:28,824 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 10:41:28,826 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 10:41:28,828 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 10:41:28,830 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 10:41:28,832 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 10:41:28,834 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 10:41:28,837 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 10:41:28,839 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 10:41:28,841 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 10:41:28,843 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 10:41:28,845 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 10:41:28,847 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 10:41:28,849 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 10:41:28,851 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 10:41:28,854 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 10:41:28,856 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 10:41:28,858 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 10:41:28,860 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 10:41:28,862 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 10:41:28,864 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 10:41:28,866 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 10:41:28,868 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-14 10:41:28,870 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-14 10:41:28,872 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-14 10:41:28,874 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-14 10:41:28,876 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-14 10:41:28,878 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpZRn5eK/system.
# 2019-02-14 10:41:28,880 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 10:41:28,881 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 10:41:28,884 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 10:41:28,886 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 10:41:28,888 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 10:41:28,890 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 10:41:28,893 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 10:41:28,895 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 10:41:28,897 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 10:41:28,899 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 10:41:28,902 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 10:41:28,905 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 10:41:28,907 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 10:41:28,909 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 10:41:28,912 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 10:41:28,914 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 10:41:28,915 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 10:41:28,918 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 10:41:28,920 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 10:41:28,923 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 10:41:28,925 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 10:41:28,927 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 10:41:28,929 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 10:41:28,932 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 10:41:28,934 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 10:41:28,936 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 10:41:28,939 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 10:41:28,941 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 10:41:28,943 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 10:41:28,945 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 10:41:28,947 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 10:41:28,950 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 10:41:28,952 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 10:41:28,954 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 10:41:28,956 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 10:41:28,958 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 10:41:28,960 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 10:41:28,962 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 10:41:28,965 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 10:41:28,967 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 10:41:28,969 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 10:41:28,971 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 10:41:28,974 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 10:41:28,976 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 10:41:28,978 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 10:41:28,980 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 10:41:28,982 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 10:41:28,985 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 10:41:28,987 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 10:41:28,989 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 10:41:28,991 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 10:41:28,993 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 10:41:28,996 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 10:41:28,998 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 10:41:29,000 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 10:41:29,002 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 10:41:29,004 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 10:41:29,007 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 10:41:29,009 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 10:41:29,011 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 10:41:29,013 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 10:41:29,016 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 10:41:29,018 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 10:41:29,020 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 10:41:29,022 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 10:41:29,024 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 10:41:29,026 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 10:41:29,029 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 10:41:29,031 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 10:41:29,033 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 10:41:29,035 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 10:41:29,037 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 10:41:29,039 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 10:41:29,041 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 10:41:29,044 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 10:41:29,046 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 10:41:29,048 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 10:41:29,050 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 10:41:29,052 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 10:41:29,055 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 10:41:29,057 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 10:41:29,059 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 10:41:29,061 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 10:41:29,063 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 10:41:29,065 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 10:41:29,067 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 10:41:29,069 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 10:41:29,072 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 10:41:29,074 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 10:41:29,076 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 10:41:29,079 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 10:41:29,081 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 10:41:29,083 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 10:41:29,085 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 10:41:29,087 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 10:41:29,089 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 10:41:29,091 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 10:41:29,094 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 10:41:29,096 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 10:41:29,098 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 10:41:29,100 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 10:41:29,103 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 10:41:29,105 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 10:41:29,107 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 10:41:29,110 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 10:41:29,112 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 10:41:29,114 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 10:41:29,117 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 10:41:29,119 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 10:41:29,121 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 10:41:29,123 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 10:41:29,126 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 10:41:29,128 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 10:41:29,130 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 10:41:29,132 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 10:41:29,134 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 10:41:29,137 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 10:41:29,139 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 10:41:29,141 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 10:41:29,143 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 10:41:29,145 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 10:41:29,148 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 10:41:29,150 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 10:41:29,152 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 10:41:29,154 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 10:41:29,156 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 10:41:29,159 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 10:41:29,161 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 10:41:29,163 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 10:41:29,165 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 10:41:29,167 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 10:41:29,170 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 10:41:29,172 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 10:41:29,174 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 10:41:29,176 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 10:41:29,178 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 10:41:29,181 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 10:41:29,183 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 10:41:29,185 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 10:41:29,187 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 10:41:29,190 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 10:41:29,192 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 10:41:29,194 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 10:41:29,196 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 10:41:29,198 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 10:41:29,200 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 10:41:29,202 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 10:41:29,205 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 10:41:29,207 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 10:41:29,209 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 10:41:29,211 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 10:41:29,213 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 10:41:29,216 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 10:41:29,218 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 10:41:29,220 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 10:41:29,223 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 10:41:29,225 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 10:41:29,227 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 10:41:29,229 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 10:41:29,231 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 10:41:29,234 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 10:41:29,236 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 10:41:29,238 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 10:41:29,240 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 10:41:29,242 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 10:41:29,244 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 10:41:29,247 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 10:41:29,249 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 10:41:29,251 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 10:41:29,253 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 10:41:29,256 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 10:41:29,258 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 10:41:29,261 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 10:41:29,263 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 10:41:29,265 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 10:41:29,268 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 10:41:29,270 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 10:41:29,272 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 10:41:29,274 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 10:41:29,276 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 10:41:29,278 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 10:41:29,281 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-14 10:41:29,283 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-14 10:41:29,285 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-14 10:41:29,287 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-14 10:41:29,290 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-14 10:41:29,292 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-14 10:41:29,294 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-14 10:41:29,296 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-14 10:41:29,299 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-14 10:41:29,301 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-14 10:41:29,303 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-14 10:41:29,305 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-14 10:41:29,308 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-14 10:41:29,310 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-14 10:41:29,312 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-14 10:41:29,314 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-14 10:41:29,317 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-14 10:41:29,319 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-14 10:41:29,321 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-14 10:41:29,323 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-14 10:41:29,326 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpZRn5eK/model.
# 2019-02-14 10:41:29,346 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpp3l1IM/rouge_conf.xml
# 2019-02-14 10:41:29,347 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpp3l1IM/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.08489 (95%-conf.int. 0.07539 - 0.09452)
# 1 ROUGE-1 Average_P: 0.42607 (95%-conf.int. 0.39158 - 0.45957)
# 1 ROUGE-1 Average_F: 0.13985 (95%-conf.int. 0.12571 - 0.15385)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01504 (95%-conf.int. 0.01199 - 0.01838)
# 1 ROUGE-2 Average_P: 0.07504 (95%-conf.int. 0.06053 - 0.08965)
# 1 ROUGE-2 Average_F: 0.02477 (95%-conf.int. 0.01983 - 0.03020)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00362 (95%-conf.int. 0.00230 - 0.00534)
# 1 ROUGE-3 Average_P: 0.01722 (95%-conf.int. 0.01106 - 0.02531)
# 1 ROUGE-3 Average_F: 0.00592 (95%-conf.int. 0.00379 - 0.00875)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00128 (95%-conf.int. 0.00052 - 0.00239)
# 1 ROUGE-4 Average_P: 0.00591 (95%-conf.int. 0.00239 - 0.01120)
# 1 ROUGE-4 Average_F: 0.00209 (95%-conf.int. 0.00085 - 0.00395)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.07817 (95%-conf.int. 0.06976 - 0.08633)
# 1 ROUGE-L Average_P: 0.39396 (95%-conf.int. 0.36218 - 0.42406)
# 1 ROUGE-L Average_F: 0.12890 (95%-conf.int. 0.11629 - 0.14147)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.02595 (95%-conf.int. 0.02342 - 0.02837)
# 1 ROUGE-W-1.2 Average_P: 0.24167 (95%-conf.int. 0.22360 - 0.25868)
# 1 ROUGE-W-1.2 Average_F: 0.04650 (95%-conf.int. 0.04222 - 0.05064)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.00808 (95%-conf.int. 0.00637 - 0.01002)
# 1 ROUGE-S* Average_P: 0.19019 (95%-conf.int. 0.16457 - 0.21741)
# 1 ROUGE-S* Average_F: 0.01523 (95%-conf.int. 0.01215 - 0.01862)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.00867 (95%-conf.int. 0.00691 - 0.01066)
# 1 ROUGE-SU* Average_P: 0.19984 (95%-conf.int. 0.17408 - 0.22707)
# 1 ROUGE-SU* Average_F: 0.01633 (95%-conf.int. 0.01313 - 0.01980)
#
# 6
# <function tfidf_score_func at 0x7f46054a8050>
