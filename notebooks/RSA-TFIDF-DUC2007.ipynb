# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 7
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func_glob()

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
#count_score
#score_func = ones#get_w2v_score_func()#get_tfidf_score_func()#count_score
score_func = get_tfidf_score_func()

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-12 08:12:49,817 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 08:12:49,820 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpUetG2P/system and model files to /tmp/tmpUetG2P/model.
# 2019-02-12 08:12:49,821 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 08:12:49,823 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 08:12:49,825 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 08:12:49,827 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 08:12:49,829 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 08:12:49,831 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 08:12:49,833 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 08:12:49,835 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 08:12:49,837 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 08:12:49,839 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 08:12:49,841 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 08:12:49,843 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 08:12:49,846 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 08:12:49,848 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 08:12:49,850 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 08:12:49,852 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 08:12:49,854 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 08:12:49,856 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 08:12:49,858 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 08:12:49,860 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 08:12:49,862 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 08:12:49,864 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 08:12:49,866 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 08:12:49,868 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 08:12:49,870 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 08:12:49,873 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 08:12:49,875 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 08:12:49,877 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 08:12:49,879 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 08:12:49,881 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 08:12:49,883 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 08:12:49,885 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 08:12:49,887 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 08:12:49,889 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 08:12:49,891 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 08:12:49,893 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 08:12:49,895 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 08:12:49,897 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 08:12:49,899 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 08:12:49,901 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 08:12:49,903 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 08:12:49,905 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 08:12:49,907 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 08:12:49,909 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 08:12:49,911 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 08:12:49,913 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 08:12:49,915 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpUetG2P/system.
# 2019-02-12 08:12:49,917 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 08:12:49,918 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 08:12:49,920 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 08:12:49,922 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 08:12:49,924 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 08:12:49,927 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 08:12:49,929 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 08:12:49,931 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 08:12:49,933 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 08:12:49,935 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 08:12:49,937 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 08:12:49,939 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 08:12:49,942 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 08:12:49,944 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 08:12:49,946 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 08:12:49,948 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 08:12:49,950 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 08:12:49,952 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 08:12:49,954 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 08:12:49,956 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 08:12:49,958 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 08:12:49,961 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 08:12:49,963 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 08:12:49,965 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 08:12:49,967 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 08:12:49,969 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 08:12:49,972 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 08:12:49,974 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 08:12:49,976 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 08:12:49,978 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 08:12:49,980 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 08:12:49,982 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 08:12:49,985 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 08:12:49,987 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 08:12:49,989 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 08:12:49,991 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 08:12:49,993 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 08:12:49,995 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 08:12:49,997 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 08:12:50,000 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 08:12:50,002 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 08:12:50,004 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 08:12:50,006 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 08:12:50,008 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 08:12:50,010 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 08:12:50,012 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 08:12:50,015 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 08:12:50,017 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 08:12:50,019 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 08:12:50,021 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 08:12:50,023 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 08:12:50,025 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 08:12:50,027 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 08:12:50,030 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 08:12:50,032 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 08:12:50,034 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 08:12:50,036 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 08:12:50,039 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 08:12:50,041 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 08:12:50,043 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 08:12:50,045 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 08:12:50,048 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 08:12:50,050 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 08:12:50,052 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 08:12:50,054 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 08:12:50,056 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 08:12:50,058 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 08:12:50,060 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 08:12:50,062 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 08:12:50,065 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 08:12:50,067 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 08:12:50,069 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 08:12:50,071 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 08:12:50,073 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 08:12:50,075 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 08:12:50,077 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 08:12:50,079 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 08:12:50,081 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 08:12:50,084 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 08:12:50,086 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 08:12:50,088 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 08:12:50,090 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 08:12:50,092 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 08:12:50,094 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 08:12:50,096 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 08:12:50,098 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 08:12:50,100 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 08:12:50,103 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 08:12:50,105 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 08:12:50,107 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 08:12:50,109 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 08:12:50,112 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 08:12:50,114 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 08:12:50,116 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 08:12:50,118 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 08:12:50,120 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 08:12:50,122 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 08:12:50,125 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 08:12:50,127 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 08:12:50,129 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 08:12:50,131 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 08:12:50,134 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 08:12:50,136 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 08:12:50,138 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 08:12:50,140 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 08:12:50,142 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 08:12:50,145 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 08:12:50,147 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 08:12:50,149 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 08:12:50,151 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 08:12:50,153 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 08:12:50,156 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 08:12:50,158 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 08:12:50,160 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 08:12:50,162 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 08:12:50,164 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 08:12:50,167 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 08:12:50,169 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 08:12:50,171 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 08:12:50,173 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 08:12:50,175 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 08:12:50,177 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 08:12:50,180 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 08:12:50,182 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 08:12:50,184 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 08:12:50,186 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 08:12:50,188 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 08:12:50,190 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 08:12:50,192 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 08:12:50,194 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 08:12:50,196 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 08:12:50,199 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 08:12:50,201 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 08:12:50,203 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 08:12:50,205 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 08:12:50,207 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 08:12:50,209 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 08:12:50,211 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 08:12:50,213 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 08:12:50,215 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 08:12:50,218 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 08:12:50,220 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 08:12:50,222 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 08:12:50,224 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 08:12:50,226 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 08:12:50,228 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 08:12:50,230 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 08:12:50,233 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 08:12:50,236 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 08:12:50,238 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 08:12:50,240 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 08:12:50,242 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 08:12:50,244 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 08:12:50,247 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 08:12:50,249 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 08:12:50,251 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 08:12:50,253 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 08:12:50,256 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 08:12:50,257 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 08:12:50,260 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 08:12:50,262 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 08:12:50,264 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 08:12:50,266 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 08:12:50,269 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 08:12:50,271 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 08:12:50,273 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 08:12:50,275 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 08:12:50,277 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 08:12:50,280 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 08:12:50,282 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 08:12:50,284 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 08:12:50,287 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 08:12:50,289 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 08:12:50,291 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 08:12:50,293 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 08:12:50,296 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 08:12:50,298 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 08:12:50,300 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 08:12:50,302 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 08:12:50,304 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 08:12:50,306 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 08:12:50,308 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpUetG2P/model.
# 2019-02-12 08:12:50,324 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpp1mx4c/rouge_conf.xml
# 2019-02-12 08:12:50,326 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpp1mx4c/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.08585 (95%-conf.int. 0.07777 - 0.09397)
# 1 ROUGE-1 Average_P: 0.41245 (95%-conf.int. 0.38417 - 0.43946)
# 1 ROUGE-1 Average_F: 0.14067 (95%-conf.int. 0.12826 - 0.15300)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01675 (95%-conf.int. 0.01334 - 0.02040)
# 1 ROUGE-2 Average_P: 0.07883 (95%-conf.int. 0.06393 - 0.09397)
# 1 ROUGE-2 Average_F: 0.02737 (95%-conf.int. 0.02178 - 0.03293)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00491 (95%-conf.int. 0.00283 - 0.00721)
# 1 ROUGE-3 Average_P: 0.02226 (95%-conf.int. 0.01353 - 0.03223)
# 1 ROUGE-3 Average_F: 0.00796 (95%-conf.int. 0.00465 - 0.01157)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00221 (95%-conf.int. 0.00085 - 0.00379)
# 1 ROUGE-4 Average_P: 0.00985 (95%-conf.int. 0.00354 - 0.01632)
# 1 ROUGE-4 Average_F: 0.00356 (95%-conf.int. 0.00134 - 0.00607)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.07927 (95%-conf.int. 0.07186 - 0.08708)
# 1 ROUGE-L Average_P: 0.38212 (95%-conf.int. 0.35487 - 0.40884)
# 1 ROUGE-L Average_F: 0.12996 (95%-conf.int. 0.11859 - 0.14131)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.02639 (95%-conf.int. 0.02420 - 0.02864)
# 1 ROUGE-W-1.2 Average_P: 0.23880 (95%-conf.int. 0.22153 - 0.25456)
# 1 ROUGE-W-1.2 Average_F: 0.04722 (95%-conf.int. 0.04354 - 0.05097)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.00798 (95%-conf.int. 0.00647 - 0.00960)
# 1 ROUGE-S* Average_P: 0.17388 (95%-conf.int. 0.15272 - 0.19365)
# 1 ROUGE-S* Average_F: 0.01507 (95%-conf.int. 0.01231 - 0.01801)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.00858 (95%-conf.int. 0.00700 - 0.01025)
# 1 ROUGE-SU* Average_P: 0.18330 (95%-conf.int. 0.16147 - 0.20353)
# 1 ROUGE-SU* Average_F: 0.01619 (95%-conf.int. 0.01335 - 0.01920)
#
# 7
# <function tfidf_score_func at 0x7fa2df9a51b8>
