# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 5
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = count_score

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-14 12:40:51,814 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 12:40:51,817 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmp0dPKEv/system and model files to /tmp/tmp0dPKEv/model.
# 2019-02-14 12:40:51,818 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 12:40:51,819 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 12:40:51,822 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 12:40:51,824 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 12:40:51,826 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 12:40:51,828 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 12:40:51,830 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 12:40:51,832 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 12:40:51,834 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 12:40:51,836 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 12:40:51,839 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 12:40:51,841 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 12:40:51,843 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 12:40:51,846 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 12:40:51,848 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 12:40:51,850 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 12:40:51,852 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 12:40:51,854 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 12:40:51,856 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 12:40:51,858 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 12:40:51,860 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 12:40:51,862 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 12:40:51,864 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 12:40:51,866 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 12:40:51,868 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 12:40:51,870 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 12:40:51,872 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 12:40:51,874 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 12:40:51,876 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 12:40:51,878 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 12:40:51,880 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 12:40:51,882 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 12:40:51,884 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 12:40:51,886 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 12:40:51,888 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 12:40:51,890 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 12:40:51,892 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 12:40:51,894 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 12:40:51,896 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 12:40:51,899 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 12:40:51,901 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 12:40:51,903 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 12:40:51,905 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 12:40:51,907 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 12:40:51,909 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 12:40:51,911 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 12:40:51,913 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-14 12:40:51,915 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-14 12:40:51,917 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-14 12:40:51,919 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-14 12:40:51,921 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-14 12:40:51,923 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmp0dPKEv/system.
# 2019-02-14 12:40:51,924 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 12:40:51,925 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 12:40:51,928 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 12:40:51,930 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 12:40:51,932 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 12:40:51,934 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 12:40:51,936 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 12:40:51,938 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 12:40:51,940 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 12:40:51,943 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 12:40:51,945 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 12:40:51,947 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 12:40:51,949 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 12:40:51,951 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 12:40:51,953 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 12:40:51,955 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 12:40:51,957 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 12:40:51,960 [MainThread  ] [INFO ]  Processing 3_reference_4.txt.
# 2019-02-14 12:40:51,962 [MainThread  ] [INFO ]  Processing 3_reference_5.txt.
# 2019-02-14 12:40:51,964 [MainThread  ] [INFO ]  Processing 3_reference_6.txt.
# 2019-02-14 12:40:51,966 [MainThread  ] [INFO ]  Processing 3_reference_7.txt.
# 2019-02-14 12:40:51,968 [MainThread  ] [INFO ]  Processing 3_reference_8.txt.
# 2019-02-14 12:40:51,970 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 12:40:51,973 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 12:40:51,975 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 12:40:51,977 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 12:40:51,979 [MainThread  ] [INFO ]  Processing 4_reference_4.txt.
# 2019-02-14 12:40:51,981 [MainThread  ] [INFO ]  Processing 4_reference_5.txt.
# 2019-02-14 12:40:51,983 [MainThread  ] [INFO ]  Processing 4_reference_6.txt.
# 2019-02-14 12:40:51,985 [MainThread  ] [INFO ]  Processing 4_reference_7.txt.
# 2019-02-14 12:40:51,987 [MainThread  ] [INFO ]  Processing 4_reference_8.txt.
# 2019-02-14 12:40:51,990 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 12:40:51,992 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 12:40:51,994 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 12:40:51,996 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 12:40:51,998 [MainThread  ] [INFO ]  Processing 5_reference_4.txt.
# 2019-02-14 12:40:52,000 [MainThread  ] [INFO ]  Processing 5_reference_5.txt.
# 2019-02-14 12:40:52,003 [MainThread  ] [INFO ]  Processing 5_reference_6.txt.
# 2019-02-14 12:40:52,005 [MainThread  ] [INFO ]  Processing 5_reference_7.txt.
# 2019-02-14 12:40:52,008 [MainThread  ] [INFO ]  Processing 5_reference_8.txt.
# 2019-02-14 12:40:52,010 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 12:40:52,012 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 12:40:52,015 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 12:40:52,017 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 12:40:52,019 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 12:40:52,022 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 12:40:52,024 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 12:40:52,026 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 12:40:52,028 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 12:40:52,031 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 12:40:52,033 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 12:40:52,035 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 12:40:52,037 [MainThread  ] [INFO ]  Processing 8_reference_4.txt.
# 2019-02-14 12:40:52,040 [MainThread  ] [INFO ]  Processing 8_reference_5.txt.
# 2019-02-14 12:40:52,042 [MainThread  ] [INFO ]  Processing 8_reference_6.txt.
# 2019-02-14 12:40:52,044 [MainThread  ] [INFO ]  Processing 8_reference_7.txt.
# 2019-02-14 12:40:52,046 [MainThread  ] [INFO ]  Processing 8_reference_8.txt.
# 2019-02-14 12:40:52,048 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 12:40:52,050 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 12:40:52,052 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 12:40:52,055 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 12:40:52,057 [MainThread  ] [INFO ]  Processing 9_reference_4.txt.
# 2019-02-14 12:40:52,059 [MainThread  ] [INFO ]  Processing 9_reference_5.txt.
# 2019-02-14 12:40:52,061 [MainThread  ] [INFO ]  Processing 9_reference_6.txt.
# 2019-02-14 12:40:52,063 [MainThread  ] [INFO ]  Processing 9_reference_7.txt.
# 2019-02-14 12:40:52,065 [MainThread  ] [INFO ]  Processing 9_reference_8.txt.
# 2019-02-14 12:40:52,067 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 12:40:52,069 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 12:40:52,071 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 12:40:52,074 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 12:40:52,076 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 12:40:52,078 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 12:40:52,080 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 12:40:52,083 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 12:40:52,085 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 12:40:52,087 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 12:40:52,089 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 12:40:52,091 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 12:40:52,094 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 12:40:52,096 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 12:40:52,099 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 12:40:52,101 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 12:40:52,103 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 12:40:52,105 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 12:40:52,108 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 12:40:52,110 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 12:40:52,112 [MainThread  ] [INFO ]  Processing 14_reference_4.txt.
# 2019-02-14 12:40:52,114 [MainThread  ] [INFO ]  Processing 14_reference_5.txt.
# 2019-02-14 12:40:52,116 [MainThread  ] [INFO ]  Processing 14_reference_6.txt.
# 2019-02-14 12:40:52,118 [MainThread  ] [INFO ]  Processing 14_reference_7.txt.
# 2019-02-14 12:40:52,121 [MainThread  ] [INFO ]  Processing 14_reference_8.txt.
# 2019-02-14 12:40:52,123 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 12:40:52,125 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 12:40:52,127 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 12:40:52,130 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 12:40:52,132 [MainThread  ] [INFO ]  Processing 15_reference_4.txt.
# 2019-02-14 12:40:52,134 [MainThread  ] [INFO ]  Processing 15_reference_5.txt.
# 2019-02-14 12:40:52,136 [MainThread  ] [INFO ]  Processing 15_reference_6.txt.
# 2019-02-14 12:40:52,139 [MainThread  ] [INFO ]  Processing 15_reference_7.txt.
# 2019-02-14 12:40:52,141 [MainThread  ] [INFO ]  Processing 15_reference_8.txt.
# 2019-02-14 12:40:52,143 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 12:40:52,145 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 12:40:52,147 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 12:40:52,150 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 12:40:52,152 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 12:40:52,154 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 12:40:52,156 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 12:40:52,158 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 12:40:52,160 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 12:40:52,162 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 12:40:52,164 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 12:40:52,167 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 12:40:52,169 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 12:40:52,171 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 12:40:52,173 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 12:40:52,175 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 12:40:52,177 [MainThread  ] [INFO ]  Processing 19_reference_4.txt.
# 2019-02-14 12:40:52,179 [MainThread  ] [INFO ]  Processing 19_reference_5.txt.
# 2019-02-14 12:40:52,182 [MainThread  ] [INFO ]  Processing 19_reference_6.txt.
# 2019-02-14 12:40:52,184 [MainThread  ] [INFO ]  Processing 19_reference_7.txt.
# 2019-02-14 12:40:52,186 [MainThread  ] [INFO ]  Processing 19_reference_8.txt.
# 2019-02-14 12:40:52,188 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 12:40:52,190 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 12:40:52,193 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 12:40:52,195 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 12:40:52,197 [MainThread  ] [INFO ]  Processing 20_reference_4.txt.
# 2019-02-14 12:40:52,199 [MainThread  ] [INFO ]  Processing 20_reference_5.txt.
# 2019-02-14 12:40:52,201 [MainThread  ] [INFO ]  Processing 20_reference_6.txt.
# 2019-02-14 12:40:52,203 [MainThread  ] [INFO ]  Processing 20_reference_7.txt.
# 2019-02-14 12:40:52,205 [MainThread  ] [INFO ]  Processing 20_reference_8.txt.
# 2019-02-14 12:40:52,208 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 12:40:52,210 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 12:40:52,212 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 12:40:52,214 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 12:40:52,216 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 12:40:52,219 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 12:40:52,221 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 12:40:52,223 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 12:40:52,225 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 12:40:52,227 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 12:40:52,229 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 12:40:52,232 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 12:40:52,234 [MainThread  ] [INFO ]  Processing 23_reference_4.txt.
# 2019-02-14 12:40:52,236 [MainThread  ] [INFO ]  Processing 23_reference_5.txt.
# 2019-02-14 12:40:52,238 [MainThread  ] [INFO ]  Processing 23_reference_6.txt.
# 2019-02-14 12:40:52,240 [MainThread  ] [INFO ]  Processing 23_reference_7.txt.
# 2019-02-14 12:40:52,242 [MainThread  ] [INFO ]  Processing 23_reference_8.txt.
# 2019-02-14 12:40:52,245 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 12:40:52,247 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 12:40:52,249 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 12:40:52,251 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 12:40:52,253 [MainThread  ] [INFO ]  Processing 24_reference_4.txt.
# 2019-02-14 12:40:52,255 [MainThread  ] [INFO ]  Processing 24_reference_5.txt.
# 2019-02-14 12:40:52,257 [MainThread  ] [INFO ]  Processing 24_reference_6.txt.
# 2019-02-14 12:40:52,259 [MainThread  ] [INFO ]  Processing 24_reference_7.txt.
# 2019-02-14 12:40:52,261 [MainThread  ] [INFO ]  Processing 24_reference_8.txt.
# 2019-02-14 12:40:52,264 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 12:40:52,266 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 12:40:52,268 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 12:40:52,271 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 12:40:52,273 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 12:40:52,275 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 12:40:52,277 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 12:40:52,279 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 12:40:52,281 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 12:40:52,284 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 12:40:52,286 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 12:40:52,288 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 12:40:52,290 [MainThread  ] [INFO ]  Processing 27_reference_4.txt.
# 2019-02-14 12:40:52,292 [MainThread  ] [INFO ]  Processing 27_reference_5.txt.
# 2019-02-14 12:40:52,294 [MainThread  ] [INFO ]  Processing 27_reference_6.txt.
# 2019-02-14 12:40:52,296 [MainThread  ] [INFO ]  Processing 27_reference_7.txt.
# 2019-02-14 12:40:52,299 [MainThread  ] [INFO ]  Processing 27_reference_8.txt.
# 2019-02-14 12:40:52,301 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 12:40:52,303 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 12:40:52,305 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 12:40:52,307 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 12:40:52,309 [MainThread  ] [INFO ]  Processing 28_reference_4.txt.
# 2019-02-14 12:40:52,312 [MainThread  ] [INFO ]  Processing 28_reference_5.txt.
# 2019-02-14 12:40:52,314 [MainThread  ] [INFO ]  Processing 28_reference_6.txt.
# 2019-02-14 12:40:52,316 [MainThread  ] [INFO ]  Processing 28_reference_7.txt.
# 2019-02-14 12:40:52,318 [MainThread  ] [INFO ]  Processing 28_reference_8.txt.
# 2019-02-14 12:40:52,320 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 12:40:52,323 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 12:40:52,325 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 12:40:52,327 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 12:40:52,329 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 12:40:52,331 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 12:40:52,333 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 12:40:52,335 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 12:40:52,337 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 12:40:52,339 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 12:40:52,342 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 12:40:52,344 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 12:40:52,346 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 12:40:52,348 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 12:40:52,350 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 12:40:52,352 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 12:40:52,354 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 12:40:52,357 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 12:40:52,360 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 12:40:52,362 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 12:40:52,364 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 12:40:52,366 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 12:40:52,369 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 12:40:52,371 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 12:40:52,373 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 12:40:52,375 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 12:40:52,377 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 12:40:52,379 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 12:40:52,382 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 12:40:52,384 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 12:40:52,386 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 12:40:52,388 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 12:40:52,390 [MainThread  ] [INFO ]  Processing 36_reference_4.txt.
# 2019-02-14 12:40:52,392 [MainThread  ] [INFO ]  Processing 36_reference_5.txt.
# 2019-02-14 12:40:52,394 [MainThread  ] [INFO ]  Processing 36_reference_6.txt.
# 2019-02-14 12:40:52,396 [MainThread  ] [INFO ]  Processing 36_reference_7.txt.
# 2019-02-14 12:40:52,398 [MainThread  ] [INFO ]  Processing 36_reference_8.txt.
# 2019-02-14 12:40:52,401 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 12:40:52,403 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 12:40:52,405 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 12:40:52,407 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 12:40:52,409 [MainThread  ] [INFO ]  Processing 37_reference_4.txt.
# 2019-02-14 12:40:52,411 [MainThread  ] [INFO ]  Processing 37_reference_5.txt.
# 2019-02-14 12:40:52,414 [MainThread  ] [INFO ]  Processing 37_reference_6.txt.
# 2019-02-14 12:40:52,416 [MainThread  ] [INFO ]  Processing 37_reference_7.txt.
# 2019-02-14 12:40:52,418 [MainThread  ] [INFO ]  Processing 37_reference_8.txt.
# 2019-02-14 12:40:52,420 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 12:40:52,422 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 12:40:52,425 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 12:40:52,427 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 12:40:52,429 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 12:40:52,431 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 12:40:52,434 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 12:40:52,436 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 12:40:52,438 [MainThread  ] [INFO ]  Processing 39_reference_4.txt.
# 2019-02-14 12:40:52,440 [MainThread  ] [INFO ]  Processing 39_reference_5.txt.
# 2019-02-14 12:40:52,442 [MainThread  ] [INFO ]  Processing 39_reference_6.txt.
# 2019-02-14 12:40:52,445 [MainThread  ] [INFO ]  Processing 39_reference_7.txt.
# 2019-02-14 12:40:52,447 [MainThread  ] [INFO ]  Processing 39_reference_8.txt.
# 2019-02-14 12:40:52,449 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 12:40:52,451 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 12:40:52,453 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 12:40:52,455 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 12:40:52,458 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 12:40:52,460 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 12:40:52,462 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 12:40:52,464 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 12:40:52,467 [MainThread  ] [INFO ]  Processing 41_reference_4.txt.
# 2019-02-14 12:40:52,469 [MainThread  ] [INFO ]  Processing 41_reference_5.txt.
# 2019-02-14 12:40:52,471 [MainThread  ] [INFO ]  Processing 41_reference_6.txt.
# 2019-02-14 12:40:52,473 [MainThread  ] [INFO ]  Processing 41_reference_7.txt.
# 2019-02-14 12:40:52,475 [MainThread  ] [INFO ]  Processing 41_reference_8.txt.
# 2019-02-14 12:40:52,477 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 12:40:52,479 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 12:40:52,482 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 12:40:52,484 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 12:40:52,486 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 12:40:52,488 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 12:40:52,490 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 12:40:52,492 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 12:40:52,495 [MainThread  ] [INFO ]  Processing 43_reference_4.txt.
# 2019-02-14 12:40:52,497 [MainThread  ] [INFO ]  Processing 43_reference_5.txt.
# 2019-02-14 12:40:52,499 [MainThread  ] [INFO ]  Processing 43_reference_6.txt.
# 2019-02-14 12:40:52,501 [MainThread  ] [INFO ]  Processing 43_reference_7.txt.
# 2019-02-14 12:40:52,503 [MainThread  ] [INFO ]  Processing 43_reference_8.txt.
# 2019-02-14 12:40:52,505 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 12:40:52,508 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 12:40:52,510 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 12:40:52,512 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 12:40:52,514 [MainThread  ] [INFO ]  Processing 44_reference_4.txt.
# 2019-02-14 12:40:52,516 [MainThread  ] [INFO ]  Processing 44_reference_5.txt.
# 2019-02-14 12:40:52,519 [MainThread  ] [INFO ]  Processing 44_reference_6.txt.
# 2019-02-14 12:40:52,521 [MainThread  ] [INFO ]  Processing 44_reference_7.txt.
# 2019-02-14 12:40:52,523 [MainThread  ] [INFO ]  Processing 44_reference_8.txt.
# 2019-02-14 12:40:52,525 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-14 12:40:52,527 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-14 12:40:52,530 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-14 12:40:52,532 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-14 12:40:52,534 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-14 12:40:52,536 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-14 12:40:52,539 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-14 12:40:52,541 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-14 12:40:52,543 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-14 12:40:52,545 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-14 12:40:52,547 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-14 12:40:52,550 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-14 12:40:52,552 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-14 12:40:52,554 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-14 12:40:52,556 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-14 12:40:52,558 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-14 12:40:52,561 [MainThread  ] [INFO ]  Processing 48_reference_4.txt.
# 2019-02-14 12:40:52,563 [MainThread  ] [INFO ]  Processing 48_reference_5.txt.
# 2019-02-14 12:40:52,566 [MainThread  ] [INFO ]  Processing 48_reference_6.txt.
# 2019-02-14 12:40:52,568 [MainThread  ] [INFO ]  Processing 48_reference_7.txt.
# 2019-02-14 12:40:52,570 [MainThread  ] [INFO ]  Processing 48_reference_8.txt.
# 2019-02-14 12:40:52,573 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-14 12:40:52,575 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-14 12:40:52,577 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-14 12:40:52,579 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-14 12:40:52,581 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmp0dPKEv/model.
# 2019-02-14 12:40:52,606 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpL3I9Ke/rouge_conf.xml
# 2019-02-14 12:40:52,608 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpL3I9Ke/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.08589 (95%-conf.int. 0.07761 - 0.09577)
# 1 ROUGE-1 Average_P: 0.36370 (95%-conf.int. 0.33358 - 0.39368)
# 1 ROUGE-1 Average_F: 0.13765 (95%-conf.int. 0.12505 - 0.15147)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01162 (95%-conf.int. 0.00911 - 0.01427)
# 1 ROUGE-2 Average_P: 0.05047 (95%-conf.int. 0.04029 - 0.06155)
# 1 ROUGE-2 Average_F: 0.01873 (95%-conf.int. 0.01475 - 0.02283)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00198 (95%-conf.int. 0.00109 - 0.00310)
# 1 ROUGE-3 Average_P: 0.00871 (95%-conf.int. 0.00511 - 0.01303)
# 1 ROUGE-3 Average_F: 0.00320 (95%-conf.int. 0.00178 - 0.00497)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00053 (95%-conf.int. 0.00016 - 0.00107)
# 1 ROUGE-4 Average_P: 0.00222 (95%-conf.int. 0.00078 - 0.00430)
# 1 ROUGE-4 Average_F: 0.00085 (95%-conf.int. 0.00026 - 0.00171)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.07918 (95%-conf.int. 0.07191 - 0.08758)
# 1 ROUGE-L Average_P: 0.33574 (95%-conf.int. 0.30847 - 0.36284)
# 1 ROUGE-L Average_F: 0.12691 (95%-conf.int. 0.11571 - 0.13921)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.02606 (95%-conf.int. 0.02387 - 0.02854)
# 1 ROUGE-W-1.2 Average_P: 0.20664 (95%-conf.int. 0.19199 - 0.22138)
# 1 ROUGE-W-1.2 Average_F: 0.04600 (95%-conf.int. 0.04224 - 0.05022)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.00812 (95%-conf.int. 0.00659 - 0.01001)
# 1 ROUGE-S* Average_P: 0.13937 (95%-conf.int. 0.11972 - 0.16235)
# 1 ROUGE-S* Average_F: 0.01517 (95%-conf.int. 0.01239 - 0.01858)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.00873 (95%-conf.int. 0.00714 - 0.01068)
# 1 ROUGE-SU* Average_P: 0.14728 (95%-conf.int. 0.12706 - 0.17020)
# 1 ROUGE-SU* Average_F: 0.01629 (95%-conf.int. 0.01343 - 0.01985)
#
# 5
# <function count_score at 0x7efcf9ba7410>
