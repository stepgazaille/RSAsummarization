# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 5
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = count_score

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-12 08:22:59,029 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 08:22:59,033 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpun9cPb/system and model files to /tmp/tmpun9cPb/model.
# 2019-02-12 08:22:59,034 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 08:22:59,035 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 08:22:59,037 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 08:22:59,040 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 08:22:59,042 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 08:22:59,044 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 08:22:59,046 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 08:22:59,048 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 08:22:59,050 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 08:22:59,052 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 08:22:59,055 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 08:22:59,057 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 08:22:59,059 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 08:22:59,061 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 08:22:59,063 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 08:22:59,065 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 08:22:59,067 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 08:22:59,069 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 08:22:59,071 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 08:22:59,074 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 08:22:59,076 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 08:22:59,078 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 08:22:59,080 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 08:22:59,082 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 08:22:59,084 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 08:22:59,086 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 08:22:59,089 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 08:22:59,091 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 08:22:59,093 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 08:22:59,095 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 08:22:59,097 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 08:22:59,099 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 08:22:59,101 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 08:22:59,103 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 08:22:59,105 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 08:22:59,108 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 08:22:59,110 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 08:22:59,112 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 08:22:59,114 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 08:22:59,116 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 08:22:59,118 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 08:22:59,120 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 08:22:59,122 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 08:22:59,124 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 08:22:59,127 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 08:22:59,129 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 08:22:59,131 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-12 08:22:59,133 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-12 08:22:59,135 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-12 08:22:59,137 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-12 08:22:59,139 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-12 08:22:59,141 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpun9cPb/system.
# 2019-02-12 08:22:59,142 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 08:22:59,144 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 08:22:59,146 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 08:22:59,148 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 08:22:59,150 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 08:22:59,152 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 08:22:59,155 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 08:22:59,157 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 08:22:59,159 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 08:22:59,161 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 08:22:59,163 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 08:22:59,165 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 08:22:59,168 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 08:22:59,170 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 08:22:59,172 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 08:22:59,174 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 08:22:59,177 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 08:22:59,179 [MainThread  ] [INFO ]  Processing 3_reference_4.txt.
# 2019-02-12 08:22:59,181 [MainThread  ] [INFO ]  Processing 3_reference_5.txt.
# 2019-02-12 08:22:59,183 [MainThread  ] [INFO ]  Processing 3_reference_6.txt.
# 2019-02-12 08:22:59,185 [MainThread  ] [INFO ]  Processing 3_reference_7.txt.
# 2019-02-12 08:22:59,188 [MainThread  ] [INFO ]  Processing 3_reference_8.txt.
# 2019-02-12 08:22:59,190 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 08:22:59,192 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 08:22:59,194 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 08:22:59,196 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 08:22:59,199 [MainThread  ] [INFO ]  Processing 4_reference_4.txt.
# 2019-02-12 08:22:59,201 [MainThread  ] [INFO ]  Processing 4_reference_5.txt.
# 2019-02-12 08:22:59,203 [MainThread  ] [INFO ]  Processing 4_reference_6.txt.
# 2019-02-12 08:22:59,205 [MainThread  ] [INFO ]  Processing 4_reference_7.txt.
# 2019-02-12 08:22:59,207 [MainThread  ] [INFO ]  Processing 4_reference_8.txt.
# 2019-02-12 08:22:59,210 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 08:22:59,212 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 08:22:59,214 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 08:22:59,216 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 08:22:59,218 [MainThread  ] [INFO ]  Processing 5_reference_4.txt.
# 2019-02-12 08:22:59,221 [MainThread  ] [INFO ]  Processing 5_reference_5.txt.
# 2019-02-12 08:22:59,223 [MainThread  ] [INFO ]  Processing 5_reference_6.txt.
# 2019-02-12 08:22:59,225 [MainThread  ] [INFO ]  Processing 5_reference_7.txt.
# 2019-02-12 08:22:59,227 [MainThread  ] [INFO ]  Processing 5_reference_8.txt.
# 2019-02-12 08:22:59,230 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 08:22:59,232 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 08:22:59,234 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 08:22:59,236 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 08:22:59,238 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 08:22:59,241 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 08:22:59,243 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 08:22:59,245 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 08:22:59,247 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 08:22:59,249 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 08:22:59,251 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 08:22:59,253 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 08:22:59,256 [MainThread  ] [INFO ]  Processing 8_reference_4.txt.
# 2019-02-12 08:22:59,258 [MainThread  ] [INFO ]  Processing 8_reference_5.txt.
# 2019-02-12 08:22:59,260 [MainThread  ] [INFO ]  Processing 8_reference_6.txt.
# 2019-02-12 08:22:59,263 [MainThread  ] [INFO ]  Processing 8_reference_7.txt.
# 2019-02-12 08:22:59,265 [MainThread  ] [INFO ]  Processing 8_reference_8.txt.
# 2019-02-12 08:22:59,268 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 08:22:59,270 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 08:22:59,272 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 08:22:59,274 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 08:22:59,276 [MainThread  ] [INFO ]  Processing 9_reference_4.txt.
# 2019-02-12 08:22:59,278 [MainThread  ] [INFO ]  Processing 9_reference_5.txt.
# 2019-02-12 08:22:59,281 [MainThread  ] [INFO ]  Processing 9_reference_6.txt.
# 2019-02-12 08:22:59,283 [MainThread  ] [INFO ]  Processing 9_reference_7.txt.
# 2019-02-12 08:22:59,285 [MainThread  ] [INFO ]  Processing 9_reference_8.txt.
# 2019-02-12 08:22:59,287 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 08:22:59,289 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 08:22:59,292 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 08:22:59,294 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 08:22:59,296 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 08:22:59,298 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 08:22:59,300 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 08:22:59,303 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 08:22:59,305 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 08:22:59,307 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 08:22:59,309 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 08:22:59,311 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 08:22:59,314 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 08:22:59,316 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 08:22:59,318 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 08:22:59,320 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 08:22:59,323 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 08:22:59,325 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 08:22:59,328 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 08:22:59,330 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 08:22:59,332 [MainThread  ] [INFO ]  Processing 14_reference_4.txt.
# 2019-02-12 08:22:59,334 [MainThread  ] [INFO ]  Processing 14_reference_5.txt.
# 2019-02-12 08:22:59,337 [MainThread  ] [INFO ]  Processing 14_reference_6.txt.
# 2019-02-12 08:22:59,339 [MainThread  ] [INFO ]  Processing 14_reference_7.txt.
# 2019-02-12 08:22:59,341 [MainThread  ] [INFO ]  Processing 14_reference_8.txt.
# 2019-02-12 08:22:59,344 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 08:22:59,346 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 08:22:59,348 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 08:22:59,350 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 08:22:59,353 [MainThread  ] [INFO ]  Processing 15_reference_4.txt.
# 2019-02-12 08:22:59,355 [MainThread  ] [INFO ]  Processing 15_reference_5.txt.
# 2019-02-12 08:22:59,357 [MainThread  ] [INFO ]  Processing 15_reference_6.txt.
# 2019-02-12 08:22:59,359 [MainThread  ] [INFO ]  Processing 15_reference_7.txt.
# 2019-02-12 08:22:59,362 [MainThread  ] [INFO ]  Processing 15_reference_8.txt.
# 2019-02-12 08:22:59,364 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 08:22:59,366 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 08:22:59,368 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 08:22:59,371 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 08:22:59,373 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 08:22:59,375 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 08:22:59,377 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 08:22:59,379 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 08:22:59,382 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 08:22:59,384 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 08:22:59,386 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 08:22:59,388 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 08:22:59,391 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 08:22:59,393 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 08:22:59,395 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 08:22:59,397 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 08:22:59,400 [MainThread  ] [INFO ]  Processing 19_reference_4.txt.
# 2019-02-12 08:22:59,402 [MainThread  ] [INFO ]  Processing 19_reference_5.txt.
# 2019-02-12 08:22:59,404 [MainThread  ] [INFO ]  Processing 19_reference_6.txt.
# 2019-02-12 08:22:59,406 [MainThread  ] [INFO ]  Processing 19_reference_7.txt.
# 2019-02-12 08:22:59,408 [MainThread  ] [INFO ]  Processing 19_reference_8.txt.
# 2019-02-12 08:22:59,411 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 08:22:59,413 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 08:22:59,415 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 08:22:59,417 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 08:22:59,420 [MainThread  ] [INFO ]  Processing 20_reference_4.txt.
# 2019-02-12 08:22:59,422 [MainThread  ] [INFO ]  Processing 20_reference_5.txt.
# 2019-02-12 08:22:59,424 [MainThread  ] [INFO ]  Processing 20_reference_6.txt.
# 2019-02-12 08:22:59,427 [MainThread  ] [INFO ]  Processing 20_reference_7.txt.
# 2019-02-12 08:22:59,429 [MainThread  ] [INFO ]  Processing 20_reference_8.txt.
# 2019-02-12 08:22:59,431 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 08:22:59,433 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 08:22:59,435 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 08:22:59,438 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 08:22:59,440 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 08:22:59,442 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 08:22:59,444 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 08:22:59,446 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 08:22:59,448 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 08:22:59,450 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 08:22:59,453 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 08:22:59,455 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 08:22:59,457 [MainThread  ] [INFO ]  Processing 23_reference_4.txt.
# 2019-02-12 08:22:59,459 [MainThread  ] [INFO ]  Processing 23_reference_5.txt.
# 2019-02-12 08:22:59,462 [MainThread  ] [INFO ]  Processing 23_reference_6.txt.
# 2019-02-12 08:22:59,464 [MainThread  ] [INFO ]  Processing 23_reference_7.txt.
# 2019-02-12 08:22:59,466 [MainThread  ] [INFO ]  Processing 23_reference_8.txt.
# 2019-02-12 08:22:59,468 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 08:22:59,471 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 08:22:59,473 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 08:22:59,475 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 08:22:59,477 [MainThread  ] [INFO ]  Processing 24_reference_4.txt.
# 2019-02-12 08:22:59,480 [MainThread  ] [INFO ]  Processing 24_reference_5.txt.
# 2019-02-12 08:22:59,482 [MainThread  ] [INFO ]  Processing 24_reference_6.txt.
# 2019-02-12 08:22:59,484 [MainThread  ] [INFO ]  Processing 24_reference_7.txt.
# 2019-02-12 08:22:59,486 [MainThread  ] [INFO ]  Processing 24_reference_8.txt.
# 2019-02-12 08:22:59,488 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 08:22:59,491 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 08:22:59,493 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 08:22:59,496 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 08:22:59,498 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 08:22:59,500 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 08:22:59,503 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 08:22:59,505 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 08:22:59,508 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 08:22:59,510 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 08:22:59,512 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 08:22:59,514 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 08:22:59,516 [MainThread  ] [INFO ]  Processing 27_reference_4.txt.
# 2019-02-12 08:22:59,518 [MainThread  ] [INFO ]  Processing 27_reference_5.txt.
# 2019-02-12 08:22:59,521 [MainThread  ] [INFO ]  Processing 27_reference_6.txt.
# 2019-02-12 08:22:59,523 [MainThread  ] [INFO ]  Processing 27_reference_7.txt.
# 2019-02-12 08:22:59,525 [MainThread  ] [INFO ]  Processing 27_reference_8.txt.
# 2019-02-12 08:22:59,528 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 08:22:59,530 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 08:22:59,532 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 08:22:59,534 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 08:22:59,537 [MainThread  ] [INFO ]  Processing 28_reference_4.txt.
# 2019-02-12 08:22:59,539 [MainThread  ] [INFO ]  Processing 28_reference_5.txt.
# 2019-02-12 08:22:59,541 [MainThread  ] [INFO ]  Processing 28_reference_6.txt.
# 2019-02-12 08:22:59,543 [MainThread  ] [INFO ]  Processing 28_reference_7.txt.
# 2019-02-12 08:22:59,546 [MainThread  ] [INFO ]  Processing 28_reference_8.txt.
# 2019-02-12 08:22:59,548 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 08:22:59,550 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 08:22:59,553 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 08:22:59,555 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 08:22:59,557 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 08:22:59,560 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 08:22:59,562 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 08:22:59,564 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 08:22:59,566 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 08:22:59,568 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 08:22:59,571 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 08:22:59,573 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 08:22:59,575 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 08:22:59,578 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 08:22:59,580 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 08:22:59,582 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 08:22:59,584 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 08:22:59,587 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 08:22:59,589 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 08:22:59,591 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 08:22:59,593 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 08:22:59,595 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 08:22:59,597 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 08:22:59,600 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 08:22:59,602 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 08:22:59,604 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 08:22:59,606 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 08:22:59,609 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 08:22:59,611 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 08:22:59,613 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 08:22:59,615 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 08:22:59,618 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 08:22:59,620 [MainThread  ] [INFO ]  Processing 36_reference_4.txt.
# 2019-02-12 08:22:59,622 [MainThread  ] [INFO ]  Processing 36_reference_5.txt.
# 2019-02-12 08:22:59,624 [MainThread  ] [INFO ]  Processing 36_reference_6.txt.
# 2019-02-12 08:22:59,627 [MainThread  ] [INFO ]  Processing 36_reference_7.txt.
# 2019-02-12 08:22:59,629 [MainThread  ] [INFO ]  Processing 36_reference_8.txt.
# 2019-02-12 08:22:59,631 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 08:22:59,633 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 08:22:59,636 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 08:22:59,638 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 08:22:59,640 [MainThread  ] [INFO ]  Processing 37_reference_4.txt.
# 2019-02-12 08:22:59,642 [MainThread  ] [INFO ]  Processing 37_reference_5.txt.
# 2019-02-12 08:22:59,644 [MainThread  ] [INFO ]  Processing 37_reference_6.txt.
# 2019-02-12 08:22:59,647 [MainThread  ] [INFO ]  Processing 37_reference_7.txt.
# 2019-02-12 08:22:59,649 [MainThread  ] [INFO ]  Processing 37_reference_8.txt.
# 2019-02-12 08:22:59,651 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 08:22:59,653 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 08:22:59,655 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 08:22:59,657 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 08:22:59,660 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 08:22:59,662 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 08:22:59,664 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 08:22:59,666 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 08:22:59,668 [MainThread  ] [INFO ]  Processing 39_reference_4.txt.
# 2019-02-12 08:22:59,671 [MainThread  ] [INFO ]  Processing 39_reference_5.txt.
# 2019-02-12 08:22:59,673 [MainThread  ] [INFO ]  Processing 39_reference_6.txt.
# 2019-02-12 08:22:59,675 [MainThread  ] [INFO ]  Processing 39_reference_7.txt.
# 2019-02-12 08:22:59,678 [MainThread  ] [INFO ]  Processing 39_reference_8.txt.
# 2019-02-12 08:22:59,680 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 08:22:59,682 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 08:22:59,685 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 08:22:59,687 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 08:22:59,689 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 08:22:59,691 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 08:22:59,693 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 08:22:59,696 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 08:22:59,698 [MainThread  ] [INFO ]  Processing 41_reference_4.txt.
# 2019-02-12 08:22:59,700 [MainThread  ] [INFO ]  Processing 41_reference_5.txt.
# 2019-02-12 08:22:59,702 [MainThread  ] [INFO ]  Processing 41_reference_6.txt.
# 2019-02-12 08:22:59,705 [MainThread  ] [INFO ]  Processing 41_reference_7.txt.
# 2019-02-12 08:22:59,707 [MainThread  ] [INFO ]  Processing 41_reference_8.txt.
# 2019-02-12 08:22:59,709 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 08:22:59,711 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 08:22:59,714 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 08:22:59,716 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 08:22:59,718 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 08:22:59,721 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 08:22:59,723 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 08:22:59,725 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 08:22:59,728 [MainThread  ] [INFO ]  Processing 43_reference_4.txt.
# 2019-02-12 08:22:59,730 [MainThread  ] [INFO ]  Processing 43_reference_5.txt.
# 2019-02-12 08:22:59,732 [MainThread  ] [INFO ]  Processing 43_reference_6.txt.
# 2019-02-12 08:22:59,734 [MainThread  ] [INFO ]  Processing 43_reference_7.txt.
# 2019-02-12 08:22:59,737 [MainThread  ] [INFO ]  Processing 43_reference_8.txt.
# 2019-02-12 08:22:59,739 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 08:22:59,741 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 08:22:59,743 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 08:22:59,745 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 08:22:59,747 [MainThread  ] [INFO ]  Processing 44_reference_4.txt.
# 2019-02-12 08:22:59,750 [MainThread  ] [INFO ]  Processing 44_reference_5.txt.
# 2019-02-12 08:22:59,752 [MainThread  ] [INFO ]  Processing 44_reference_6.txt.
# 2019-02-12 08:22:59,754 [MainThread  ] [INFO ]  Processing 44_reference_7.txt.
# 2019-02-12 08:22:59,757 [MainThread  ] [INFO ]  Processing 44_reference_8.txt.
# 2019-02-12 08:22:59,759 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-12 08:22:59,761 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-12 08:22:59,763 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-12 08:22:59,766 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-12 08:22:59,768 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-12 08:22:59,770 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-12 08:22:59,772 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-12 08:22:59,775 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-12 08:22:59,777 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-12 08:22:59,779 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-12 08:22:59,781 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-12 08:22:59,783 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-12 08:22:59,785 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-12 08:22:59,788 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-12 08:22:59,790 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-12 08:22:59,792 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-12 08:22:59,794 [MainThread  ] [INFO ]  Processing 48_reference_4.txt.
# 2019-02-12 08:22:59,796 [MainThread  ] [INFO ]  Processing 48_reference_5.txt.
# 2019-02-12 08:22:59,798 [MainThread  ] [INFO ]  Processing 48_reference_6.txt.
# 2019-02-12 08:22:59,801 [MainThread  ] [INFO ]  Processing 48_reference_7.txt.
# 2019-02-12 08:22:59,803 [MainThread  ] [INFO ]  Processing 48_reference_8.txt.
# 2019-02-12 08:22:59,805 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-12 08:22:59,807 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-12 08:22:59,809 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-12 08:22:59,812 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-12 08:22:59,814 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpun9cPb/model.
# 2019-02-12 08:22:59,838 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpbbo3Br/rouge_conf.xml
# 2019-02-12 08:22:59,839 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpbbo3Br/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.08574 (95%-conf.int. 0.07752 - 0.09382)
# 1 ROUGE-1 Average_P: 0.36997 (95%-conf.int. 0.33649 - 0.40510)
# 1 ROUGE-1 Average_F: 0.13795 (95%-conf.int. 0.12545 - 0.15048)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01143 (95%-conf.int. 0.00894 - 0.01422)
# 1 ROUGE-2 Average_P: 0.05052 (95%-conf.int. 0.03999 - 0.06212)
# 1 ROUGE-2 Average_F: 0.01851 (95%-conf.int. 0.01451 - 0.02287)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00238 (95%-conf.int. 0.00137 - 0.00364)
# 1 ROUGE-3 Average_P: 0.01084 (95%-conf.int. 0.00615 - 0.01651)
# 1 ROUGE-3 Average_F: 0.00387 (95%-conf.int. 0.00225 - 0.00593)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00077 (95%-conf.int. 0.00028 - 0.00141)
# 1 ROUGE-4 Average_P: 0.00351 (95%-conf.int. 0.00128 - 0.00630)
# 1 ROUGE-4 Average_F: 0.00125 (95%-conf.int. 0.00045 - 0.00229)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.07821 (95%-conf.int. 0.07088 - 0.08552)
# 1 ROUGE-L Average_P: 0.33795 (95%-conf.int. 0.30902 - 0.36897)
# 1 ROUGE-L Average_F: 0.12586 (95%-conf.int. 0.11494 - 0.13720)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.02581 (95%-conf.int. 0.02365 - 0.02789)
# 1 ROUGE-W-1.2 Average_P: 0.20811 (95%-conf.int. 0.19182 - 0.22539)
# 1 ROUGE-W-1.2 Average_F: 0.04567 (95%-conf.int. 0.04205 - 0.04924)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.00786 (95%-conf.int. 0.00657 - 0.00925)
# 1 ROUGE-S* Average_P: 0.14465 (95%-conf.int. 0.12276 - 0.16999)
# 1 ROUGE-S* Average_F: 0.01473 (95%-conf.int. 0.01238 - 0.01730)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.00847 (95%-conf.int. 0.00713 - 0.00991)
# 1 ROUGE-SU* Average_P: 0.15259 (95%-conf.int. 0.13010 - 0.17831)
# 1 ROUGE-SU* Average_F: 0.01585 (95%-conf.int. 0.01341 - 0.01855)
#
# 5
# <function count_score at 0x7f63d7e23488>
