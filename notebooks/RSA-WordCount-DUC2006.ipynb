# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 6
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = count_score

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-14 11:09:09,782 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 11:09:09,785 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpII4Iph/system and model files to /tmp/tmpII4Iph/model.
# 2019-02-14 11:09:09,786 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 11:09:09,787 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 11:09:09,789 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 11:09:09,792 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 11:09:09,793 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 11:09:09,796 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 11:09:09,798 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 11:09:09,800 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 11:09:09,802 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 11:09:09,804 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 11:09:09,806 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 11:09:09,808 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 11:09:09,810 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 11:09:09,812 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 11:09:09,814 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 11:09:09,816 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 11:09:09,818 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 11:09:09,820 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 11:09:09,822 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 11:09:09,824 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 11:09:09,826 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 11:09:09,828 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 11:09:09,831 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 11:09:09,833 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 11:09:09,835 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 11:09:09,837 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 11:09:09,839 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 11:09:09,841 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 11:09:09,843 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 11:09:09,845 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 11:09:09,847 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 11:09:09,849 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 11:09:09,852 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 11:09:09,854 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 11:09:09,856 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 11:09:09,858 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 11:09:09,860 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 11:09:09,862 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 11:09:09,864 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 11:09:09,866 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 11:09:09,868 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 11:09:09,870 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 11:09:09,872 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 11:09:09,874 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 11:09:09,876 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 11:09:09,879 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 11:09:09,881 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-14 11:09:09,882 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-14 11:09:09,885 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-14 11:09:09,887 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-14 11:09:09,889 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-14 11:09:09,891 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpII4Iph/system.
# 2019-02-14 11:09:09,892 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 11:09:09,893 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 11:09:09,896 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 11:09:09,898 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 11:09:09,900 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 11:09:09,902 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 11:09:09,905 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 11:09:09,907 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 11:09:09,909 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 11:09:09,911 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 11:09:09,913 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 11:09:09,916 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 11:09:09,918 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 11:09:09,920 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 11:09:09,922 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 11:09:09,924 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 11:09:09,927 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 11:09:09,929 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 11:09:09,931 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 11:09:09,933 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 11:09:09,936 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 11:09:09,938 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 11:09:09,940 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 11:09:09,942 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 11:09:09,944 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 11:09:09,946 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 11:09:09,948 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 11:09:09,950 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 11:09:09,953 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 11:09:09,955 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 11:09:09,957 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 11:09:09,959 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 11:09:09,961 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 11:09:09,963 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 11:09:09,965 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 11:09:09,967 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 11:09:09,970 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 11:09:09,972 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 11:09:09,974 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 11:09:09,976 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 11:09:09,978 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 11:09:09,981 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 11:09:09,983 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 11:09:09,985 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 11:09:09,987 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 11:09:09,989 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 11:09:09,991 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 11:09:09,994 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 11:09:09,996 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 11:09:09,998 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 11:09:10,000 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 11:09:10,002 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 11:09:10,004 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 11:09:10,007 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 11:09:10,009 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 11:09:10,011 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 11:09:10,013 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 11:09:10,015 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 11:09:10,017 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 11:09:10,019 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 11:09:10,022 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 11:09:10,024 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 11:09:10,026 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 11:09:10,028 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 11:09:10,030 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 11:09:10,032 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 11:09:10,034 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 11:09:10,037 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 11:09:10,039 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 11:09:10,041 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 11:09:10,043 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 11:09:10,046 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 11:09:10,048 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 11:09:10,050 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 11:09:10,052 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 11:09:10,054 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 11:09:10,056 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 11:09:10,058 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 11:09:10,061 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 11:09:10,063 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 11:09:10,065 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 11:09:10,067 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 11:09:10,070 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 11:09:10,072 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 11:09:10,074 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 11:09:10,076 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 11:09:10,078 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 11:09:10,080 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 11:09:10,083 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 11:09:10,085 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 11:09:10,087 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 11:09:10,089 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 11:09:10,091 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 11:09:10,093 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 11:09:10,096 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 11:09:10,098 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 11:09:10,100 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 11:09:10,102 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 11:09:10,104 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 11:09:10,106 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 11:09:10,108 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 11:09:10,111 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 11:09:10,113 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 11:09:10,115 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 11:09:10,117 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 11:09:10,119 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 11:09:10,121 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 11:09:10,124 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 11:09:10,126 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 11:09:10,128 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 11:09:10,130 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 11:09:10,132 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 11:09:10,134 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 11:09:10,137 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 11:09:10,139 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 11:09:10,141 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 11:09:10,143 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 11:09:10,145 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 11:09:10,147 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 11:09:10,149 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 11:09:10,152 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 11:09:10,154 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 11:09:10,156 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 11:09:10,158 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 11:09:10,160 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 11:09:10,162 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 11:09:10,164 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 11:09:10,167 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 11:09:10,169 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 11:09:10,171 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 11:09:10,173 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 11:09:10,176 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 11:09:10,178 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 11:09:10,180 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 11:09:10,183 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 11:09:10,185 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 11:09:10,187 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 11:09:10,189 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 11:09:10,191 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 11:09:10,194 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 11:09:10,196 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 11:09:10,198 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 11:09:10,200 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 11:09:10,202 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 11:09:10,205 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 11:09:10,208 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 11:09:10,210 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 11:09:10,212 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 11:09:10,214 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 11:09:10,216 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 11:09:10,219 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 11:09:10,221 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 11:09:10,223 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 11:09:10,225 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 11:09:10,227 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 11:09:10,229 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 11:09:10,231 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 11:09:10,234 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 11:09:10,236 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 11:09:10,238 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 11:09:10,240 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 11:09:10,242 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 11:09:10,244 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 11:09:10,246 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 11:09:10,248 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 11:09:10,251 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 11:09:10,253 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 11:09:10,255 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 11:09:10,257 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 11:09:10,259 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 11:09:10,261 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 11:09:10,263 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 11:09:10,265 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 11:09:10,267 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 11:09:10,270 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 11:09:10,272 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 11:09:10,274 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 11:09:10,276 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 11:09:10,278 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 11:09:10,281 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 11:09:10,283 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 11:09:10,285 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-14 11:09:10,287 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-14 11:09:10,289 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-14 11:09:10,292 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-14 11:09:10,294 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-14 11:09:10,296 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-14 11:09:10,298 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-14 11:09:10,300 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-14 11:09:10,302 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-14 11:09:10,304 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-14 11:09:10,307 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-14 11:09:10,309 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-14 11:09:10,312 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-14 11:09:10,314 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-14 11:09:10,316 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-14 11:09:10,319 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-14 11:09:10,321 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-14 11:09:10,323 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-14 11:09:10,325 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-14 11:09:10,327 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-14 11:09:10,330 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpII4Iph/model.
# 2019-02-14 11:09:10,349 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpY5aScx/rouge_conf.xml
# 2019-02-14 11:09:10,350 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpY5aScx/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.10800 (95%-conf.int. 0.09842 - 0.11710)
# 1 ROUGE-1 Average_P: 0.42609 (95%-conf.int. 0.39919 - 0.45371)
# 1 ROUGE-1 Average_F: 0.17059 (95%-conf.int. 0.15707 - 0.18339)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01674 (95%-conf.int. 0.01401 - 0.01938)
# 1 ROUGE-2 Average_P: 0.06685 (95%-conf.int. 0.05676 - 0.07760)
# 1 ROUGE-2 Average_F: 0.02651 (95%-conf.int. 0.02227 - 0.03058)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00386 (95%-conf.int. 0.00246 - 0.00542)
# 1 ROUGE-3 Average_P: 0.01496 (95%-conf.int. 0.00991 - 0.02094)
# 1 ROUGE-3 Average_F: 0.00609 (95%-conf.int. 0.00386 - 0.00847)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00159 (95%-conf.int. 0.00066 - 0.00282)
# 1 ROUGE-4 Average_P: 0.00604 (95%-conf.int. 0.00257 - 0.01105)
# 1 ROUGE-4 Average_F: 0.00250 (95%-conf.int. 0.00104 - 0.00449)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.09900 (95%-conf.int. 0.09046 - 0.10692)
# 1 ROUGE-L Average_P: 0.39184 (95%-conf.int. 0.36814 - 0.41653)
# 1 ROUGE-L Average_F: 0.15646 (95%-conf.int. 0.14415 - 0.16759)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.03222 (95%-conf.int. 0.02966 - 0.03454)
# 1 ROUGE-W-1.2 Average_P: 0.23430 (95%-conf.int. 0.22139 - 0.24845)
# 1 ROUGE-W-1.2 Average_F: 0.05625 (95%-conf.int. 0.05204 - 0.06001)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.01270 (95%-conf.int. 0.01054 - 0.01486)
# 1 ROUGE-S* Average_P: 0.18892 (95%-conf.int. 0.16595 - 0.21317)
# 1 ROUGE-S* Average_F: 0.02350 (95%-conf.int. 0.01954 - 0.02733)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.01344 (95%-conf.int. 0.01121 - 0.01566)
# 1 ROUGE-SU* Average_P: 0.19668 (95%-conf.int. 0.17381 - 0.22099)
# 1 ROUGE-SU* Average_F: 0.02485 (95%-conf.int. 0.02080 - 0.02874)
#
# 6
# <function count_score at 0x7f573ad676e0>
