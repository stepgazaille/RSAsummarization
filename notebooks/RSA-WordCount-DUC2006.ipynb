# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 6
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = count_score

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-12 08:30:39,102 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 08:30:39,105 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpR_7jXz/system and model files to /tmp/tmpR_7jXz/model.
# 2019-02-12 08:30:39,107 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 08:30:39,108 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 08:30:39,110 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 08:30:39,112 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 08:30:39,114 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 08:30:39,117 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 08:30:39,119 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 08:30:39,121 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 08:30:39,123 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 08:30:39,125 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 08:30:39,127 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 08:30:39,129 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 08:30:39,132 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 08:30:39,134 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 08:30:39,136 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 08:30:39,138 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 08:30:39,140 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 08:30:39,142 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 08:30:39,144 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 08:30:39,146 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 08:30:39,148 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 08:30:39,150 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 08:30:39,152 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 08:30:39,155 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 08:30:39,157 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 08:30:39,159 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 08:30:39,161 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 08:30:39,163 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 08:30:39,165 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 08:30:39,167 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 08:30:39,169 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 08:30:39,171 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 08:30:39,173 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 08:30:39,175 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 08:30:39,177 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 08:30:39,179 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 08:30:39,181 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 08:30:39,184 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 08:30:39,186 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 08:30:39,188 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 08:30:39,190 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 08:30:39,192 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 08:30:39,194 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 08:30:39,196 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 08:30:39,198 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 08:30:39,200 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 08:30:39,202 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-12 08:30:39,204 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-12 08:30:39,207 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-12 08:30:39,209 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-12 08:30:39,211 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-12 08:30:39,213 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpR_7jXz/system.
# 2019-02-12 08:30:39,214 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 08:30:39,216 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 08:30:39,218 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 08:30:39,220 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 08:30:39,222 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 08:30:39,224 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 08:30:39,226 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 08:30:39,228 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 08:30:39,231 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 08:30:39,233 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 08:30:39,235 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 08:30:39,237 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 08:30:39,239 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 08:30:39,241 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 08:30:39,244 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 08:30:39,246 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 08:30:39,248 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 08:30:39,250 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 08:30:39,252 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 08:30:39,255 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 08:30:39,257 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 08:30:39,259 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 08:30:39,261 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 08:30:39,264 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 08:30:39,266 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 08:30:39,268 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 08:30:39,270 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 08:30:39,272 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 08:30:39,274 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 08:30:39,277 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 08:30:39,279 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 08:30:39,281 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 08:30:39,283 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 08:30:39,285 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 08:30:39,287 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 08:30:39,289 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 08:30:39,292 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 08:30:39,294 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 08:30:39,296 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 08:30:39,298 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 08:30:39,301 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 08:30:39,303 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 08:30:39,305 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 08:30:39,308 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 08:30:39,310 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 08:30:39,312 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 08:30:39,315 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 08:30:39,317 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 08:30:39,319 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 08:30:39,321 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 08:30:39,323 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 08:30:39,325 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 08:30:39,328 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 08:30:39,330 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 08:30:39,332 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 08:30:39,334 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 08:30:39,337 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 08:30:39,339 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 08:30:39,341 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 08:30:39,343 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 08:30:39,346 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 08:30:39,348 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 08:30:39,350 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 08:30:39,352 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 08:30:39,354 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 08:30:39,357 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 08:30:39,359 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 08:30:39,361 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 08:30:39,363 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 08:30:39,365 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 08:30:39,368 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 08:30:39,370 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 08:30:39,372 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 08:30:39,375 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 08:30:39,377 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 08:30:39,379 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 08:30:39,381 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 08:30:39,383 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 08:30:39,386 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 08:30:39,388 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 08:30:39,390 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 08:30:39,392 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 08:30:39,394 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 08:30:39,397 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 08:30:39,399 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 08:30:39,401 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 08:30:39,403 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 08:30:39,405 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 08:30:39,408 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 08:30:39,410 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 08:30:39,412 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 08:30:39,414 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 08:30:39,417 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 08:30:39,419 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 08:30:39,421 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 08:30:39,423 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 08:30:39,425 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 08:30:39,428 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 08:30:39,430 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 08:30:39,432 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 08:30:39,434 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 08:30:39,436 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 08:30:39,439 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 08:30:39,441 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 08:30:39,443 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 08:30:39,445 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 08:30:39,448 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 08:30:39,450 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 08:30:39,452 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 08:30:39,454 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 08:30:39,457 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 08:30:39,459 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 08:30:39,461 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 08:30:39,463 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 08:30:39,465 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 08:30:39,467 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 08:30:39,469 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 08:30:39,471 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 08:30:39,474 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 08:30:39,476 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 08:30:39,478 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 08:30:39,480 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 08:30:39,482 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 08:30:39,485 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 08:30:39,487 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 08:30:39,489 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 08:30:39,492 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 08:30:39,494 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 08:30:39,496 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 08:30:39,498 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 08:30:39,500 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 08:30:39,503 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 08:30:39,505 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 08:30:39,507 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 08:30:39,509 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 08:30:39,511 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 08:30:39,514 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 08:30:39,516 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 08:30:39,518 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 08:30:39,520 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 08:30:39,523 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 08:30:39,525 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 08:30:39,527 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 08:30:39,529 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 08:30:39,531 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 08:30:39,534 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 08:30:39,536 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 08:30:39,538 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 08:30:39,540 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 08:30:39,542 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 08:30:39,544 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 08:30:39,547 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 08:30:39,549 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 08:30:39,551 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 08:30:39,553 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 08:30:39,555 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 08:30:39,557 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 08:30:39,560 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 08:30:39,562 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 08:30:39,564 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 08:30:39,566 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 08:30:39,569 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 08:30:39,571 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 08:30:39,573 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 08:30:39,575 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 08:30:39,577 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 08:30:39,579 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 08:30:39,582 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 08:30:39,584 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 08:30:39,586 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 08:30:39,589 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 08:30:39,591 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 08:30:39,593 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 08:30:39,595 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 08:30:39,597 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 08:30:39,600 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 08:30:39,602 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 08:30:39,604 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 08:30:39,607 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 08:30:39,609 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 08:30:39,611 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 08:30:39,613 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-12 08:30:39,615 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-12 08:30:39,617 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-12 08:30:39,619 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-12 08:30:39,622 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-12 08:30:39,624 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-12 08:30:39,626 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-12 08:30:39,629 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-12 08:30:39,631 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-12 08:30:39,633 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-12 08:30:39,635 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-12 08:30:39,637 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-12 08:30:39,639 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-12 08:30:39,642 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-12 08:30:39,644 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-12 08:30:39,646 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-12 08:30:39,648 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-12 08:30:39,651 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-12 08:30:39,653 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-12 08:30:39,655 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-12 08:30:39,658 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpR_7jXz/model.
# 2019-02-12 08:30:39,677 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmphFbtOo/rouge_conf.xml
# 2019-02-12 08:30:39,679 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmphFbtOo/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.10054 (95%-conf.int. 0.09203 - 0.10938)
# 1 ROUGE-1 Average_P: 0.41768 (95%-conf.int. 0.39131 - 0.44457)
# 1 ROUGE-1 Average_F: 0.16020 (95%-conf.int. 0.14753 - 0.17341)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01535 (95%-conf.int. 0.01275 - 0.01804)
# 1 ROUGE-2 Average_P: 0.06402 (95%-conf.int. 0.05442 - 0.07383)
# 1 ROUGE-2 Average_F: 0.02447 (95%-conf.int. 0.02048 - 0.02874)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00368 (95%-conf.int. 0.00234 - 0.00514)
# 1 ROUGE-3 Average_P: 0.01510 (95%-conf.int. 0.01002 - 0.02077)
# 1 ROUGE-3 Average_F: 0.00584 (95%-conf.int. 0.00377 - 0.00807)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00151 (95%-conf.int. 0.00062 - 0.00260)
# 1 ROUGE-4 Average_P: 0.00599 (95%-conf.int. 0.00267 - 0.01050)
# 1 ROUGE-4 Average_F: 0.00239 (95%-conf.int. 0.00100 - 0.00415)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.09176 (95%-conf.int. 0.08416 - 0.09983)
# 1 ROUGE-L Average_P: 0.38245 (95%-conf.int. 0.35958 - 0.40816)
# 1 ROUGE-L Average_F: 0.14631 (95%-conf.int. 0.13494 - 0.15800)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.03015 (95%-conf.int. 0.02787 - 0.03256)
# 1 ROUGE-W-1.2 Average_P: 0.23096 (95%-conf.int. 0.21757 - 0.24436)
# 1 ROUGE-W-1.2 Average_F: 0.05293 (95%-conf.int. 0.04911 - 0.05684)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.01122 (95%-conf.int. 0.00946 - 0.01327)
# 1 ROUGE-S* Average_P: 0.18197 (95%-conf.int. 0.16125 - 0.20461)
# 1 ROUGE-S* Average_F: 0.02084 (95%-conf.int. 0.01766 - 0.02458)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.01192 (95%-conf.int. 0.01010 - 0.01403)
# 1 ROUGE-SU* Average_P: 0.19015 (95%-conf.int. 0.16957 - 0.21284)
# 1 ROUGE-SU* Average_F: 0.02211 (95%-conf.int. 0.01883 - 0.02591)
#
# 6
# <function count_score at 0x7f2d903e66e0>
