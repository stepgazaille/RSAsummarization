# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 7
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = count_score

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-12 08:36:13,780 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 08:36:13,784 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpakU807/system and model files to /tmp/tmpakU807/model.
# 2019-02-12 08:36:13,785 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 08:36:13,786 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 08:36:13,788 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 08:36:13,791 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 08:36:13,793 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 08:36:13,795 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 08:36:13,797 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 08:36:13,799 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 08:36:13,802 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 08:36:13,804 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 08:36:13,806 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 08:36:13,808 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 08:36:13,810 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 08:36:13,812 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 08:36:13,814 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 08:36:13,816 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 08:36:13,818 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 08:36:13,820 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 08:36:13,823 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 08:36:13,825 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 08:36:13,827 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 08:36:13,828 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 08:36:13,831 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 08:36:13,833 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 08:36:13,835 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 08:36:13,837 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 08:36:13,839 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 08:36:13,841 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 08:36:13,843 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 08:36:13,845 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 08:36:13,847 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 08:36:13,849 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 08:36:13,851 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 08:36:13,853 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 08:36:13,855 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 08:36:13,857 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 08:36:13,859 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 08:36:13,861 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 08:36:13,863 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 08:36:13,865 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 08:36:13,867 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 08:36:13,869 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 08:36:13,871 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 08:36:13,873 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 08:36:13,875 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 08:36:13,877 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 08:36:13,879 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpakU807/system.
# 2019-02-12 08:36:13,881 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 08:36:13,882 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 08:36:13,884 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 08:36:13,886 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 08:36:13,888 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 08:36:13,891 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 08:36:13,893 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 08:36:13,895 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 08:36:13,897 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 08:36:13,899 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 08:36:13,901 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 08:36:13,903 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 08:36:13,906 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 08:36:13,908 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 08:36:13,910 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 08:36:13,912 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 08:36:13,914 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 08:36:13,916 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 08:36:13,918 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 08:36:13,920 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 08:36:13,923 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 08:36:13,925 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 08:36:13,927 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 08:36:13,929 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 08:36:13,932 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 08:36:13,934 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 08:36:13,936 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 08:36:13,938 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 08:36:13,940 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 08:36:13,943 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 08:36:13,945 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 08:36:13,947 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 08:36:13,949 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 08:36:13,951 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 08:36:13,953 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 08:36:13,956 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 08:36:13,958 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 08:36:13,960 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 08:36:13,962 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 08:36:13,964 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 08:36:13,966 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 08:36:13,969 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 08:36:13,971 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 08:36:13,973 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 08:36:13,975 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 08:36:13,977 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 08:36:13,979 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 08:36:13,981 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 08:36:13,984 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 08:36:13,986 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 08:36:13,988 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 08:36:13,990 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 08:36:13,992 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 08:36:13,994 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 08:36:13,996 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 08:36:13,998 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 08:36:14,001 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 08:36:14,003 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 08:36:14,005 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 08:36:14,007 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 08:36:14,009 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 08:36:14,012 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 08:36:14,014 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 08:36:14,017 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 08:36:14,019 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 08:36:14,021 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 08:36:14,023 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 08:36:14,025 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 08:36:14,027 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 08:36:14,029 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 08:36:14,031 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 08:36:14,034 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 08:36:14,036 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 08:36:14,038 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 08:36:14,040 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 08:36:14,042 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 08:36:14,044 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 08:36:14,047 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 08:36:14,049 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 08:36:14,051 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 08:36:14,053 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 08:36:14,055 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 08:36:14,057 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 08:36:14,060 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 08:36:14,062 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 08:36:14,064 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 08:36:14,066 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 08:36:14,069 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 08:36:14,071 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 08:36:14,073 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 08:36:14,075 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 08:36:14,077 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 08:36:14,080 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 08:36:14,082 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 08:36:14,084 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 08:36:14,087 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 08:36:14,089 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 08:36:14,091 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 08:36:14,093 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 08:36:14,095 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 08:36:14,098 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 08:36:14,100 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 08:36:14,102 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 08:36:14,104 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 08:36:14,106 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 08:36:14,108 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 08:36:14,110 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 08:36:14,113 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 08:36:14,115 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 08:36:14,117 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 08:36:14,119 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 08:36:14,121 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 08:36:14,123 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 08:36:14,125 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 08:36:14,128 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 08:36:14,130 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 08:36:14,132 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 08:36:14,134 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 08:36:14,136 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 08:36:14,138 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 08:36:14,140 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 08:36:14,143 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 08:36:14,145 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 08:36:14,147 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 08:36:14,149 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 08:36:14,152 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 08:36:14,154 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 08:36:14,156 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 08:36:14,159 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 08:36:14,161 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 08:36:14,163 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 08:36:14,165 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 08:36:14,167 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 08:36:14,169 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 08:36:14,171 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 08:36:14,173 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 08:36:14,176 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 08:36:14,178 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 08:36:14,180 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 08:36:14,182 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 08:36:14,184 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 08:36:14,186 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 08:36:14,188 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 08:36:14,190 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 08:36:14,192 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 08:36:14,195 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 08:36:14,197 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 08:36:14,199 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 08:36:14,201 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 08:36:14,203 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 08:36:14,205 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 08:36:14,207 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 08:36:14,210 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 08:36:14,212 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 08:36:14,214 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 08:36:14,216 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 08:36:14,219 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 08:36:14,221 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 08:36:14,223 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 08:36:14,225 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 08:36:14,228 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 08:36:14,230 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 08:36:14,232 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 08:36:14,234 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 08:36:14,236 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 08:36:14,238 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 08:36:14,240 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 08:36:14,243 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 08:36:14,245 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 08:36:14,247 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 08:36:14,249 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 08:36:14,251 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 08:36:14,254 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 08:36:14,256 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 08:36:14,258 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 08:36:14,260 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 08:36:14,262 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 08:36:14,264 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 08:36:14,267 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 08:36:14,269 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 08:36:14,271 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 08:36:14,273 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpakU807/model.
# 2019-02-12 08:36:14,290 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpjpAc6L/rouge_conf.xml
# 2019-02-12 08:36:14,291 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpjpAc6L/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.10781 (95%-conf.int. 0.09811 - 0.11785)
# 1 ROUGE-1 Average_P: 0.43409 (95%-conf.int. 0.40377 - 0.46077)
# 1 ROUGE-1 Average_F: 0.17150 (95%-conf.int. 0.15714 - 0.18658)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01983 (95%-conf.int. 0.01557 - 0.02456)
# 1 ROUGE-2 Average_P: 0.08053 (95%-conf.int. 0.06348 - 0.09858)
# 1 ROUGE-2 Average_F: 0.03160 (95%-conf.int. 0.02487 - 0.03894)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00608 (95%-conf.int. 0.00366 - 0.00869)
# 1 ROUGE-3 Average_P: 0.02486 (95%-conf.int. 0.01453 - 0.03624)
# 1 ROUGE-3 Average_F: 0.00971 (95%-conf.int. 0.00577 - 0.01386)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00290 (95%-conf.int. 0.00130 - 0.00493)
# 1 ROUGE-4 Average_P: 0.01192 (95%-conf.int. 0.00527 - 0.01969)
# 1 ROUGE-4 Average_F: 0.00464 (95%-conf.int. 0.00211 - 0.00783)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.09975 (95%-conf.int. 0.09056 - 0.10975)
# 1 ROUGE-L Average_P: 0.40227 (95%-conf.int. 0.37258 - 0.43010)
# 1 ROUGE-L Average_F: 0.15870 (95%-conf.int. 0.14485 - 0.17334)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.03222 (95%-conf.int. 0.02940 - 0.03521)
# 1 ROUGE-W-1.2 Average_P: 0.24361 (95%-conf.int. 0.22630 - 0.26070)
# 1 ROUGE-W-1.2 Average_F: 0.05665 (95%-conf.int. 0.05183 - 0.06161)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.01269 (95%-conf.int. 0.01056 - 0.01500)
# 1 ROUGE-S* Average_P: 0.19771 (95%-conf.int. 0.17209 - 0.22352)
# 1 ROUGE-S* Average_F: 0.02364 (95%-conf.int. 0.01975 - 0.02787)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.01343 (95%-conf.int. 0.01124 - 0.01581)
# 1 ROUGE-SU* Average_P: 0.20557 (95%-conf.int. 0.18030 - 0.23117)
# 1 ROUGE-SU* Average_F: 0.02499 (95%-conf.int. 0.02101 - 0.02931)
#
# 7
# <function count_score at 0x7f0c31fa5668>
