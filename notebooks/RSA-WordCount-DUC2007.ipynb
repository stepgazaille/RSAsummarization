# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 7
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = count_score

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-14 11:11:55,755 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 11:11:55,758 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpZAsR4U/system and model files to /tmp/tmpZAsR4U/model.
# 2019-02-14 11:11:55,759 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 11:11:55,761 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 11:11:55,763 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 11:11:55,765 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 11:11:55,767 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 11:11:55,769 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 11:11:55,771 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 11:11:55,773 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 11:11:55,775 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 11:11:55,777 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 11:11:55,779 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 11:11:55,781 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 11:11:55,784 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 11:11:55,786 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 11:11:55,788 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 11:11:55,790 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 11:11:55,792 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 11:11:55,794 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 11:11:55,796 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 11:11:55,798 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 11:11:55,800 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 11:11:55,802 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 11:11:55,804 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 11:11:55,806 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 11:11:55,808 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 11:11:55,810 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 11:11:55,812 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 11:11:55,814 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 11:11:55,816 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 11:11:55,818 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 11:11:55,820 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 11:11:55,822 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 11:11:55,824 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 11:11:55,826 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 11:11:55,828 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 11:11:55,830 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 11:11:55,832 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 11:11:55,834 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 11:11:55,837 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 11:11:55,839 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 11:11:55,841 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 11:11:55,843 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 11:11:55,845 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 11:11:55,847 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 11:11:55,849 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 11:11:55,851 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 11:11:55,853 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpZAsR4U/system.
# 2019-02-14 11:11:55,854 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 11:11:55,855 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 11:11:55,857 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 11:11:55,859 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 11:11:55,861 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 11:11:55,863 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 11:11:55,866 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 11:11:55,868 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 11:11:55,870 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 11:11:55,872 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 11:11:55,874 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 11:11:55,876 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 11:11:55,879 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 11:11:55,881 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 11:11:55,883 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 11:11:55,885 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 11:11:55,887 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 11:11:55,890 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 11:11:55,892 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 11:11:55,894 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 11:11:55,896 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 11:11:55,898 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 11:11:55,900 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 11:11:55,902 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 11:11:55,905 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 11:11:55,907 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 11:11:55,909 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 11:11:55,911 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 11:11:55,914 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 11:11:55,916 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 11:11:55,918 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 11:11:55,920 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 11:11:55,922 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 11:11:55,925 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 11:11:55,927 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 11:11:55,929 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 11:11:55,931 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 11:11:55,933 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 11:11:55,935 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 11:11:55,937 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 11:11:55,939 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 11:11:55,942 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 11:11:55,944 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 11:11:55,946 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 11:11:55,949 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 11:11:55,951 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 11:11:55,953 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 11:11:55,955 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 11:11:55,957 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 11:11:55,960 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 11:11:55,962 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 11:11:55,964 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 11:11:55,966 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 11:11:55,969 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 11:11:55,971 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 11:11:55,973 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 11:11:55,976 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 11:11:55,978 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 11:11:55,980 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 11:11:55,982 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 11:11:55,984 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 11:11:55,987 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 11:11:55,989 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 11:11:55,991 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 11:11:55,993 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 11:11:55,995 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 11:11:55,997 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 11:11:55,999 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 11:11:56,002 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 11:11:56,004 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 11:11:56,006 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 11:11:56,008 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 11:11:56,011 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 11:11:56,013 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 11:11:56,015 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 11:11:56,018 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 11:11:56,020 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 11:11:56,022 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 11:11:56,025 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 11:11:56,027 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 11:11:56,030 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 11:11:56,032 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 11:11:56,034 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 11:11:56,036 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 11:11:56,039 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 11:11:56,041 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 11:11:56,043 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 11:11:56,045 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 11:11:56,047 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 11:11:56,049 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 11:11:56,051 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 11:11:56,053 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 11:11:56,056 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 11:11:56,058 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 11:11:56,060 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 11:11:56,063 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 11:11:56,065 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 11:11:56,067 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 11:11:56,069 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 11:11:56,071 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 11:11:56,074 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 11:11:56,076 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 11:11:56,078 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 11:11:56,080 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 11:11:56,083 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 11:11:56,085 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 11:11:56,087 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 11:11:56,090 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 11:11:56,092 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 11:11:56,094 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 11:11:56,096 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 11:11:56,098 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 11:11:56,101 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 11:11:56,103 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 11:11:56,105 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 11:11:56,108 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 11:11:56,110 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 11:11:56,112 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 11:11:56,114 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 11:11:56,117 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 11:11:56,119 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 11:11:56,121 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 11:11:56,123 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 11:11:56,125 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 11:11:56,127 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 11:11:56,130 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 11:11:56,132 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 11:11:56,134 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 11:11:56,136 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 11:11:56,139 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 11:11:56,141 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 11:11:56,143 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 11:11:56,145 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 11:11:56,147 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 11:11:56,149 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 11:11:56,151 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 11:11:56,154 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 11:11:56,156 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 11:11:56,158 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 11:11:56,160 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 11:11:56,162 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 11:11:56,165 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 11:11:56,167 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 11:11:56,169 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 11:11:56,172 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 11:11:56,174 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 11:11:56,176 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 11:11:56,179 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 11:11:56,181 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 11:11:56,183 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 11:11:56,185 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 11:11:56,188 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 11:11:56,190 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 11:11:56,192 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 11:11:56,195 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 11:11:56,197 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 11:11:56,199 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 11:11:56,201 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 11:11:56,203 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 11:11:56,206 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 11:11:56,208 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 11:11:56,210 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 11:11:56,212 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 11:11:56,215 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 11:11:56,218 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 11:11:56,220 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 11:11:56,222 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 11:11:56,224 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 11:11:56,227 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 11:11:56,229 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 11:11:56,231 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 11:11:56,233 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 11:11:56,236 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 11:11:56,238 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 11:11:56,240 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 11:11:56,243 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 11:11:56,245 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 11:11:56,247 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 11:11:56,250 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 11:11:56,252 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 11:11:56,254 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 11:11:56,256 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpZAsR4U/model.
# 2019-02-14 11:11:56,273 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpIrQsXY/rouge_conf.xml
# 2019-02-14 11:11:56,274 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpIrQsXY/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.10866 (95%-conf.int. 0.09826 - 0.11975)
# 1 ROUGE-1 Average_P: 0.44180 (95%-conf.int. 0.41376 - 0.46934)
# 1 ROUGE-1 Average_F: 0.17256 (95%-conf.int. 0.15806 - 0.18850)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01991 (95%-conf.int. 0.01572 - 0.02455)
# 1 ROUGE-2 Average_P: 0.08216 (95%-conf.int. 0.06616 - 0.09934)
# 1 ROUGE-2 Average_F: 0.03172 (95%-conf.int. 0.02535 - 0.03881)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00612 (95%-conf.int. 0.00368 - 0.00899)
# 1 ROUGE-3 Average_P: 0.02433 (95%-conf.int. 0.01484 - 0.03429)
# 1 ROUGE-3 Average_F: 0.00969 (95%-conf.int. 0.00581 - 0.01410)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00308 (95%-conf.int. 0.00140 - 0.00524)
# 1 ROUGE-4 Average_P: 0.01195 (95%-conf.int. 0.00580 - 0.01963)
# 1 ROUGE-4 Average_F: 0.00485 (95%-conf.int. 0.00226 - 0.00814)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.10017 (95%-conf.int. 0.09074 - 0.11035)
# 1 ROUGE-L Average_P: 0.40871 (95%-conf.int. 0.38385 - 0.43497)
# 1 ROUGE-L Average_F: 0.15919 (95%-conf.int. 0.14602 - 0.17360)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.03232 (95%-conf.int. 0.02964 - 0.03540)
# 1 ROUGE-W-1.2 Average_P: 0.24743 (95%-conf.int. 0.23232 - 0.26356)
# 1 ROUGE-W-1.2 Average_F: 0.05680 (95%-conf.int. 0.05238 - 0.06189)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.01280 (95%-conf.int. 0.01044 - 0.01531)
# 1 ROUGE-S* Average_P: 0.20198 (95%-conf.int. 0.17802 - 0.22613)
# 1 ROUGE-S* Average_F: 0.02371 (95%-conf.int. 0.01950 - 0.02822)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.01354 (95%-conf.int. 0.01113 - 0.01612)
# 1 ROUGE-SU* Average_P: 0.20999 (95%-conf.int. 0.18579 - 0.23451)
# 1 ROUGE-SU* Average_F: 0.02507 (95%-conf.int. 0.02076 - 0.02966)
#
# 7
# <function count_score at 0x7fb42fc687d0>
