# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 5
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = get_w2v_score_func()

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-14 10:55:26,963 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 10:55:26,967 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmphzKp_L/system and model files to /tmp/tmphzKp_L/model.
# 2019-02-14 10:55:26,968 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 10:55:26,969 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 10:55:26,971 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 10:55:26,973 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 10:55:26,976 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 10:55:26,978 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 10:55:26,980 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 10:55:26,982 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 10:55:26,984 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 10:55:26,986 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 10:55:26,989 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 10:55:26,991 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 10:55:26,993 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 10:55:26,995 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 10:55:26,997 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 10:55:26,999 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 10:55:27,001 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 10:55:27,003 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 10:55:27,005 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 10:55:27,008 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 10:55:27,010 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 10:55:27,012 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 10:55:27,014 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 10:55:27,016 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 10:55:27,018 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 10:55:27,020 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 10:55:27,022 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 10:55:27,024 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 10:55:27,026 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 10:55:27,028 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 10:55:27,030 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 10:55:27,032 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 10:55:27,034 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 10:55:27,036 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 10:55:27,038 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 10:55:27,040 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 10:55:27,042 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 10:55:27,044 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 10:55:27,046 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 10:55:27,048 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 10:55:27,050 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 10:55:27,052 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 10:55:27,054 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 10:55:27,056 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 10:55:27,058 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 10:55:27,060 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 10:55:27,062 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-14 10:55:27,064 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-14 10:55:27,066 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-14 10:55:27,068 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-14 10:55:27,071 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-14 10:55:27,073 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmphzKp_L/system.
# 2019-02-14 10:55:27,074 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 10:55:27,075 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 10:55:27,077 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 10:55:27,080 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 10:55:27,082 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 10:55:27,084 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 10:55:27,086 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 10:55:27,088 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 10:55:27,090 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 10:55:27,092 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 10:55:27,094 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 10:55:27,096 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 10:55:27,098 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 10:55:27,101 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 10:55:27,103 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 10:55:27,105 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 10:55:27,107 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 10:55:27,109 [MainThread  ] [INFO ]  Processing 3_reference_4.txt.
# 2019-02-14 10:55:27,111 [MainThread  ] [INFO ]  Processing 3_reference_5.txt.
# 2019-02-14 10:55:27,113 [MainThread  ] [INFO ]  Processing 3_reference_6.txt.
# 2019-02-14 10:55:27,115 [MainThread  ] [INFO ]  Processing 3_reference_7.txt.
# 2019-02-14 10:55:27,118 [MainThread  ] [INFO ]  Processing 3_reference_8.txt.
# 2019-02-14 10:55:27,120 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 10:55:27,122 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 10:55:27,124 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 10:55:27,126 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 10:55:27,128 [MainThread  ] [INFO ]  Processing 4_reference_4.txt.
# 2019-02-14 10:55:27,131 [MainThread  ] [INFO ]  Processing 4_reference_5.txt.
# 2019-02-14 10:55:27,133 [MainThread  ] [INFO ]  Processing 4_reference_6.txt.
# 2019-02-14 10:55:27,135 [MainThread  ] [INFO ]  Processing 4_reference_7.txt.
# 2019-02-14 10:55:27,137 [MainThread  ] [INFO ]  Processing 4_reference_8.txt.
# 2019-02-14 10:55:27,139 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 10:55:27,141 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 10:55:27,144 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 10:55:27,146 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 10:55:27,148 [MainThread  ] [INFO ]  Processing 5_reference_4.txt.
# 2019-02-14 10:55:27,150 [MainThread  ] [INFO ]  Processing 5_reference_5.txt.
# 2019-02-14 10:55:27,152 [MainThread  ] [INFO ]  Processing 5_reference_6.txt.
# 2019-02-14 10:55:27,154 [MainThread  ] [INFO ]  Processing 5_reference_7.txt.
# 2019-02-14 10:55:27,157 [MainThread  ] [INFO ]  Processing 5_reference_8.txt.
# 2019-02-14 10:55:27,159 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 10:55:27,161 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 10:55:27,163 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 10:55:27,166 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 10:55:27,168 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 10:55:27,170 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 10:55:27,172 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 10:55:27,174 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 10:55:27,177 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 10:55:27,179 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 10:55:27,181 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 10:55:27,184 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 10:55:27,186 [MainThread  ] [INFO ]  Processing 8_reference_4.txt.
# 2019-02-14 10:55:27,188 [MainThread  ] [INFO ]  Processing 8_reference_5.txt.
# 2019-02-14 10:55:27,190 [MainThread  ] [INFO ]  Processing 8_reference_6.txt.
# 2019-02-14 10:55:27,192 [MainThread  ] [INFO ]  Processing 8_reference_7.txt.
# 2019-02-14 10:55:27,195 [MainThread  ] [INFO ]  Processing 8_reference_8.txt.
# 2019-02-14 10:55:27,197 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 10:55:27,199 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 10:55:27,201 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 10:55:27,204 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 10:55:27,206 [MainThread  ] [INFO ]  Processing 9_reference_4.txt.
# 2019-02-14 10:55:27,208 [MainThread  ] [INFO ]  Processing 9_reference_5.txt.
# 2019-02-14 10:55:27,210 [MainThread  ] [INFO ]  Processing 9_reference_6.txt.
# 2019-02-14 10:55:27,212 [MainThread  ] [INFO ]  Processing 9_reference_7.txt.
# 2019-02-14 10:55:27,214 [MainThread  ] [INFO ]  Processing 9_reference_8.txt.
# 2019-02-14 10:55:27,217 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 10:55:27,219 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 10:55:27,221 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 10:55:27,223 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 10:55:27,225 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 10:55:27,228 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 10:55:27,230 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 10:55:27,232 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 10:55:27,234 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 10:55:27,236 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 10:55:27,239 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 10:55:27,241 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 10:55:27,243 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 10:55:27,245 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 10:55:27,248 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 10:55:27,250 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 10:55:27,252 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 10:55:27,254 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 10:55:27,256 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 10:55:27,258 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 10:55:27,261 [MainThread  ] [INFO ]  Processing 14_reference_4.txt.
# 2019-02-14 10:55:27,263 [MainThread  ] [INFO ]  Processing 14_reference_5.txt.
# 2019-02-14 10:55:27,265 [MainThread  ] [INFO ]  Processing 14_reference_6.txt.
# 2019-02-14 10:55:27,267 [MainThread  ] [INFO ]  Processing 14_reference_7.txt.
# 2019-02-14 10:55:27,269 [MainThread  ] [INFO ]  Processing 14_reference_8.txt.
# 2019-02-14 10:55:27,272 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 10:55:27,274 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 10:55:27,276 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 10:55:27,278 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 10:55:27,280 [MainThread  ] [INFO ]  Processing 15_reference_4.txt.
# 2019-02-14 10:55:27,282 [MainThread  ] [INFO ]  Processing 15_reference_5.txt.
# 2019-02-14 10:55:27,284 [MainThread  ] [INFO ]  Processing 15_reference_6.txt.
# 2019-02-14 10:55:27,286 [MainThread  ] [INFO ]  Processing 15_reference_7.txt.
# 2019-02-14 10:55:27,289 [MainThread  ] [INFO ]  Processing 15_reference_8.txt.
# 2019-02-14 10:55:27,291 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 10:55:27,293 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 10:55:27,295 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 10:55:27,297 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 10:55:27,300 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 10:55:27,302 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 10:55:27,304 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 10:55:27,306 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 10:55:27,309 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 10:55:27,311 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 10:55:27,313 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 10:55:27,315 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 10:55:27,317 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 10:55:27,320 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 10:55:27,322 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 10:55:27,324 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 10:55:27,326 [MainThread  ] [INFO ]  Processing 19_reference_4.txt.
# 2019-02-14 10:55:27,328 [MainThread  ] [INFO ]  Processing 19_reference_5.txt.
# 2019-02-14 10:55:27,330 [MainThread  ] [INFO ]  Processing 19_reference_6.txt.
# 2019-02-14 10:55:27,333 [MainThread  ] [INFO ]  Processing 19_reference_7.txt.
# 2019-02-14 10:55:27,335 [MainThread  ] [INFO ]  Processing 19_reference_8.txt.
# 2019-02-14 10:55:27,338 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 10:55:27,340 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 10:55:27,342 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 10:55:27,344 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 10:55:27,347 [MainThread  ] [INFO ]  Processing 20_reference_4.txt.
# 2019-02-14 10:55:27,349 [MainThread  ] [INFO ]  Processing 20_reference_5.txt.
# 2019-02-14 10:55:27,351 [MainThread  ] [INFO ]  Processing 20_reference_6.txt.
# 2019-02-14 10:55:27,353 [MainThread  ] [INFO ]  Processing 20_reference_7.txt.
# 2019-02-14 10:55:27,356 [MainThread  ] [INFO ]  Processing 20_reference_8.txt.
# 2019-02-14 10:55:27,358 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 10:55:27,360 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 10:55:27,362 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 10:55:27,364 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 10:55:27,367 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 10:55:27,369 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 10:55:27,371 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 10:55:27,373 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 10:55:27,375 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 10:55:27,378 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 10:55:27,380 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 10:55:27,382 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 10:55:27,385 [MainThread  ] [INFO ]  Processing 23_reference_4.txt.
# 2019-02-14 10:55:27,387 [MainThread  ] [INFO ]  Processing 23_reference_5.txt.
# 2019-02-14 10:55:27,389 [MainThread  ] [INFO ]  Processing 23_reference_6.txt.
# 2019-02-14 10:55:27,391 [MainThread  ] [INFO ]  Processing 23_reference_7.txt.
# 2019-02-14 10:55:27,393 [MainThread  ] [INFO ]  Processing 23_reference_8.txt.
# 2019-02-14 10:55:27,396 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 10:55:27,398 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 10:55:27,400 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 10:55:27,402 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 10:55:27,405 [MainThread  ] [INFO ]  Processing 24_reference_4.txt.
# 2019-02-14 10:55:27,407 [MainThread  ] [INFO ]  Processing 24_reference_5.txt.
# 2019-02-14 10:55:27,409 [MainThread  ] [INFO ]  Processing 24_reference_6.txt.
# 2019-02-14 10:55:27,411 [MainThread  ] [INFO ]  Processing 24_reference_7.txt.
# 2019-02-14 10:55:27,413 [MainThread  ] [INFO ]  Processing 24_reference_8.txt.
# 2019-02-14 10:55:27,416 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 10:55:27,418 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 10:55:27,420 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 10:55:27,422 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 10:55:27,424 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 10:55:27,427 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 10:55:27,429 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 10:55:27,431 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 10:55:27,433 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 10:55:27,435 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 10:55:27,437 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 10:55:27,440 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 10:55:27,442 [MainThread  ] [INFO ]  Processing 27_reference_4.txt.
# 2019-02-14 10:55:27,444 [MainThread  ] [INFO ]  Processing 27_reference_5.txt.
# 2019-02-14 10:55:27,446 [MainThread  ] [INFO ]  Processing 27_reference_6.txt.
# 2019-02-14 10:55:27,449 [MainThread  ] [INFO ]  Processing 27_reference_7.txt.
# 2019-02-14 10:55:27,451 [MainThread  ] [INFO ]  Processing 27_reference_8.txt.
# 2019-02-14 10:55:27,453 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 10:55:27,455 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 10:55:27,457 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 10:55:27,460 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 10:55:27,462 [MainThread  ] [INFO ]  Processing 28_reference_4.txt.
# 2019-02-14 10:55:27,464 [MainThread  ] [INFO ]  Processing 28_reference_5.txt.
# 2019-02-14 10:55:27,466 [MainThread  ] [INFO ]  Processing 28_reference_6.txt.
# 2019-02-14 10:55:27,469 [MainThread  ] [INFO ]  Processing 28_reference_7.txt.
# 2019-02-14 10:55:27,471 [MainThread  ] [INFO ]  Processing 28_reference_8.txt.
# 2019-02-14 10:55:27,473 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 10:55:27,475 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 10:55:27,478 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 10:55:27,480 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 10:55:27,482 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 10:55:27,484 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 10:55:27,486 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 10:55:27,488 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 10:55:27,491 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 10:55:27,493 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 10:55:27,495 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 10:55:27,498 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 10:55:27,500 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 10:55:27,502 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 10:55:27,504 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 10:55:27,506 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 10:55:27,509 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 10:55:27,511 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 10:55:27,513 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 10:55:27,515 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 10:55:27,517 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 10:55:27,519 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 10:55:27,521 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 10:55:27,524 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 10:55:27,526 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 10:55:27,528 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 10:55:27,530 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 10:55:27,532 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 10:55:27,534 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 10:55:27,536 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 10:55:27,539 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 10:55:27,541 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 10:55:27,543 [MainThread  ] [INFO ]  Processing 36_reference_4.txt.
# 2019-02-14 10:55:27,545 [MainThread  ] [INFO ]  Processing 36_reference_5.txt.
# 2019-02-14 10:55:27,547 [MainThread  ] [INFO ]  Processing 36_reference_6.txt.
# 2019-02-14 10:55:27,550 [MainThread  ] [INFO ]  Processing 36_reference_7.txt.
# 2019-02-14 10:55:27,552 [MainThread  ] [INFO ]  Processing 36_reference_8.txt.
# 2019-02-14 10:55:27,554 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 10:55:27,556 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 10:55:27,558 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 10:55:27,560 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 10:55:27,562 [MainThread  ] [INFO ]  Processing 37_reference_4.txt.
# 2019-02-14 10:55:27,565 [MainThread  ] [INFO ]  Processing 37_reference_5.txt.
# 2019-02-14 10:55:27,567 [MainThread  ] [INFO ]  Processing 37_reference_6.txt.
# 2019-02-14 10:55:27,569 [MainThread  ] [INFO ]  Processing 37_reference_7.txt.
# 2019-02-14 10:55:27,571 [MainThread  ] [INFO ]  Processing 37_reference_8.txt.
# 2019-02-14 10:55:27,573 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 10:55:27,575 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 10:55:27,578 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 10:55:27,580 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 10:55:27,582 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 10:55:27,584 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 10:55:27,586 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 10:55:27,588 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 10:55:27,591 [MainThread  ] [INFO ]  Processing 39_reference_4.txt.
# 2019-02-14 10:55:27,593 [MainThread  ] [INFO ]  Processing 39_reference_5.txt.
# 2019-02-14 10:55:27,595 [MainThread  ] [INFO ]  Processing 39_reference_6.txt.
# 2019-02-14 10:55:27,597 [MainThread  ] [INFO ]  Processing 39_reference_7.txt.
# 2019-02-14 10:55:27,599 [MainThread  ] [INFO ]  Processing 39_reference_8.txt.
# 2019-02-14 10:55:27,601 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 10:55:27,604 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 10:55:27,606 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 10:55:27,608 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 10:55:27,610 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 10:55:27,613 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 10:55:27,615 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 10:55:27,617 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 10:55:27,619 [MainThread  ] [INFO ]  Processing 41_reference_4.txt.
# 2019-02-14 10:55:27,621 [MainThread  ] [INFO ]  Processing 41_reference_5.txt.
# 2019-02-14 10:55:27,623 [MainThread  ] [INFO ]  Processing 41_reference_6.txt.
# 2019-02-14 10:55:27,625 [MainThread  ] [INFO ]  Processing 41_reference_7.txt.
# 2019-02-14 10:55:27,628 [MainThread  ] [INFO ]  Processing 41_reference_8.txt.
# 2019-02-14 10:55:27,630 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 10:55:27,632 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 10:55:27,634 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 10:55:27,636 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 10:55:27,639 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 10:55:27,641 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 10:55:27,643 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 10:55:27,645 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 10:55:27,647 [MainThread  ] [INFO ]  Processing 43_reference_4.txt.
# 2019-02-14 10:55:27,650 [MainThread  ] [INFO ]  Processing 43_reference_5.txt.
# 2019-02-14 10:55:27,653 [MainThread  ] [INFO ]  Processing 43_reference_6.txt.
# 2019-02-14 10:55:27,655 [MainThread  ] [INFO ]  Processing 43_reference_7.txt.
# 2019-02-14 10:55:27,657 [MainThread  ] [INFO ]  Processing 43_reference_8.txt.
# 2019-02-14 10:55:27,659 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 10:55:27,661 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 10:55:27,664 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 10:55:27,666 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 10:55:27,668 [MainThread  ] [INFO ]  Processing 44_reference_4.txt.
# 2019-02-14 10:55:27,670 [MainThread  ] [INFO ]  Processing 44_reference_5.txt.
# 2019-02-14 10:55:27,672 [MainThread  ] [INFO ]  Processing 44_reference_6.txt.
# 2019-02-14 10:55:27,674 [MainThread  ] [INFO ]  Processing 44_reference_7.txt.
# 2019-02-14 10:55:27,676 [MainThread  ] [INFO ]  Processing 44_reference_8.txt.
# 2019-02-14 10:55:27,679 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-14 10:55:27,681 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-14 10:55:27,683 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-14 10:55:27,685 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-14 10:55:27,687 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-14 10:55:27,690 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-14 10:55:27,692 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-14 10:55:27,694 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-14 10:55:27,696 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-14 10:55:27,699 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-14 10:55:27,701 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-14 10:55:27,703 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-14 10:55:27,705 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-14 10:55:27,707 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-14 10:55:27,710 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-14 10:55:27,712 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-14 10:55:27,714 [MainThread  ] [INFO ]  Processing 48_reference_4.txt.
# 2019-02-14 10:55:27,716 [MainThread  ] [INFO ]  Processing 48_reference_5.txt.
# 2019-02-14 10:55:27,718 [MainThread  ] [INFO ]  Processing 48_reference_6.txt.
# 2019-02-14 10:55:27,720 [MainThread  ] [INFO ]  Processing 48_reference_7.txt.
# 2019-02-14 10:55:27,723 [MainThread  ] [INFO ]  Processing 48_reference_8.txt.
# 2019-02-14 10:55:27,725 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-14 10:55:27,727 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-14 10:55:27,729 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-14 10:55:27,731 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-14 10:55:27,733 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmphzKp_L/model.
# 2019-02-14 10:55:27,757 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpbKxIOr/rouge_conf.xml
# 2019-02-14 10:55:27,758 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpbKxIOr/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.09150 (95%-conf.int. 0.08353 - 0.10032)
# 1 ROUGE-1 Average_P: 0.36873 (95%-conf.int. 0.35060 - 0.38703)
# 1 ROUGE-1 Average_F: 0.14500 (95%-conf.int. 0.13371 - 0.15700)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01103 (95%-conf.int. 0.00888 - 0.01338)
# 1 ROUGE-2 Average_P: 0.04408 (95%-conf.int. 0.03653 - 0.05180)
# 1 ROUGE-2 Average_F: 0.01746 (95%-conf.int. 0.01417 - 0.02103)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00142 (95%-conf.int. 0.00080 - 0.00215)
# 1 ROUGE-3 Average_P: 0.00560 (95%-conf.int. 0.00325 - 0.00825)
# 1 ROUGE-3 Average_F: 0.00225 (95%-conf.int. 0.00129 - 0.00338)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00022 (95%-conf.int. 0.00007 - 0.00042)
# 1 ROUGE-4 Average_P: 0.00090 (95%-conf.int. 0.00027 - 0.00176)
# 1 ROUGE-4 Average_F: 0.00035 (95%-conf.int. 0.00012 - 0.00066)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.08342 (95%-conf.int. 0.07639 - 0.09111)
# 1 ROUGE-L Average_P: 0.33734 (95%-conf.int. 0.32079 - 0.35390)
# 1 ROUGE-L Average_F: 0.13229 (95%-conf.int. 0.12241 - 0.14312)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.02727 (95%-conf.int. 0.02519 - 0.02952)
# 1 ROUGE-W-1.2 Average_P: 0.20621 (95%-conf.int. 0.19751 - 0.21500)
# 1 ROUGE-W-1.2 Average_F: 0.04783 (95%-conf.int. 0.04447 - 0.05148)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.00875 (95%-conf.int. 0.00727 - 0.01054)
# 1 ROUGE-S* Average_P: 0.13217 (95%-conf.int. 0.11843 - 0.14656)
# 1 ROUGE-S* Average_F: 0.01620 (95%-conf.int. 0.01353 - 0.01940)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.00940 (95%-conf.int. 0.00787 - 0.01125)
# 1 ROUGE-SU* Average_P: 0.14018 (95%-conf.int. 0.12647 - 0.15438)
# 1 ROUGE-SU* Average_F: 0.01738 (95%-conf.int. 0.01463 - 0.02065)
#
# 5
# <function w2v_score at 0x7f47b1e99500>
