# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 6
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = get_w2v_score_func()

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-14 10:59:24,515 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 10:59:24,518 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpK6w2yW/system and model files to /tmp/tmpK6w2yW/model.
# 2019-02-14 10:59:24,520 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 10:59:24,521 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 10:59:24,523 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 10:59:24,525 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 10:59:24,527 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 10:59:24,529 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 10:59:24,532 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 10:59:24,534 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 10:59:24,536 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 10:59:24,538 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 10:59:24,540 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 10:59:24,542 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 10:59:24,544 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 10:59:24,546 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 10:59:24,548 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 10:59:24,550 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 10:59:24,552 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 10:59:24,554 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 10:59:24,556 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 10:59:24,558 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 10:59:24,560 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 10:59:24,562 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 10:59:24,564 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 10:59:24,566 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 10:59:24,568 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 10:59:24,571 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 10:59:24,573 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 10:59:24,575 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 10:59:24,577 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 10:59:24,579 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 10:59:24,581 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 10:59:24,583 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 10:59:24,585 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 10:59:24,587 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 10:59:24,589 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 10:59:24,591 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 10:59:24,593 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 10:59:24,595 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 10:59:24,597 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 10:59:24,599 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 10:59:24,602 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 10:59:24,604 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 10:59:24,606 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 10:59:24,608 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 10:59:24,610 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 10:59:24,612 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 10:59:24,614 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-14 10:59:24,616 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-14 10:59:24,618 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-14 10:59:24,619 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-14 10:59:24,622 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-14 10:59:24,623 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpK6w2yW/system.
# 2019-02-14 10:59:24,625 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 10:59:24,626 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 10:59:24,628 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 10:59:24,631 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 10:59:24,633 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 10:59:24,635 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 10:59:24,637 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 10:59:24,639 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 10:59:24,642 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 10:59:24,644 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 10:59:24,646 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 10:59:24,648 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 10:59:24,650 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 10:59:24,653 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 10:59:24,655 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 10:59:24,657 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 10:59:24,659 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 10:59:24,661 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 10:59:24,663 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 10:59:24,666 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 10:59:24,668 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 10:59:24,670 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 10:59:24,673 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 10:59:24,675 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 10:59:24,677 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 10:59:24,679 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 10:59:24,681 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 10:59:24,683 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 10:59:24,685 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 10:59:24,688 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 10:59:24,690 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 10:59:24,692 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 10:59:24,694 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 10:59:24,696 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 10:59:24,698 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 10:59:24,700 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 10:59:24,703 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 10:59:24,705 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 10:59:24,707 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 10:59:24,709 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 10:59:24,711 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 10:59:24,713 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 10:59:24,716 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 10:59:24,718 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 10:59:24,720 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 10:59:24,722 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 10:59:24,724 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 10:59:24,726 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 10:59:24,729 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 10:59:24,731 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 10:59:24,733 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 10:59:24,735 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 10:59:24,737 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 10:59:24,740 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 10:59:24,742 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 10:59:24,744 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 10:59:24,746 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 10:59:24,749 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 10:59:24,751 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 10:59:24,753 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 10:59:24,755 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 10:59:24,757 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 10:59:24,759 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 10:59:24,761 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 10:59:24,764 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 10:59:24,766 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 10:59:24,768 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 10:59:24,770 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 10:59:24,773 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 10:59:24,775 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 10:59:24,777 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 10:59:24,779 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 10:59:24,782 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 10:59:24,784 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 10:59:24,786 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 10:59:24,788 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 10:59:24,790 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 10:59:24,793 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 10:59:24,795 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 10:59:24,797 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 10:59:24,799 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 10:59:24,801 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 10:59:24,803 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 10:59:24,806 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 10:59:24,808 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 10:59:24,810 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 10:59:24,812 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 10:59:24,814 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 10:59:24,816 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 10:59:24,819 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 10:59:24,821 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 10:59:24,823 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 10:59:24,825 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 10:59:24,827 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 10:59:24,830 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 10:59:24,832 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 10:59:24,835 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 10:59:24,837 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 10:59:24,839 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 10:59:24,841 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 10:59:24,843 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 10:59:24,846 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 10:59:24,848 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 10:59:24,850 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 10:59:24,852 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 10:59:24,854 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 10:59:24,857 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 10:59:24,859 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 10:59:24,861 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 10:59:24,863 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 10:59:24,865 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 10:59:24,867 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 10:59:24,869 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 10:59:24,872 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 10:59:24,874 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 10:59:24,876 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 10:59:24,878 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 10:59:24,880 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 10:59:24,882 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 10:59:24,884 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 10:59:24,886 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 10:59:24,889 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 10:59:24,891 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 10:59:24,893 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 10:59:24,895 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 10:59:24,898 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 10:59:24,900 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 10:59:24,903 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 10:59:24,905 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 10:59:24,907 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 10:59:24,909 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 10:59:24,911 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 10:59:24,913 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 10:59:24,916 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 10:59:24,918 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 10:59:24,920 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 10:59:24,922 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 10:59:24,924 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 10:59:24,927 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 10:59:24,929 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 10:59:24,931 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 10:59:24,933 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 10:59:24,935 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 10:59:24,937 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 10:59:24,939 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 10:59:24,942 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 10:59:24,945 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 10:59:24,947 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 10:59:24,949 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 10:59:24,951 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 10:59:24,953 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 10:59:24,955 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 10:59:24,957 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 10:59:24,959 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 10:59:24,961 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 10:59:24,964 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 10:59:24,966 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 10:59:24,968 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 10:59:24,970 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 10:59:24,972 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 10:59:24,975 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 10:59:24,977 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 10:59:24,979 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 10:59:24,981 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 10:59:24,983 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 10:59:24,985 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 10:59:24,987 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 10:59:24,990 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 10:59:24,992 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 10:59:24,994 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 10:59:24,996 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 10:59:24,998 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 10:59:25,000 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 10:59:25,003 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 10:59:25,005 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 10:59:25,007 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 10:59:25,009 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 10:59:25,011 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 10:59:25,013 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 10:59:25,016 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 10:59:25,018 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 10:59:25,020 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-14 10:59:25,022 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-14 10:59:25,024 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-14 10:59:25,026 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-14 10:59:25,028 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-14 10:59:25,031 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-14 10:59:25,033 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-14 10:59:25,035 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-14 10:59:25,037 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-14 10:59:25,039 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-14 10:59:25,042 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-14 10:59:25,044 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-14 10:59:25,046 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-14 10:59:25,048 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-14 10:59:25,050 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-14 10:59:25,052 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-14 10:59:25,055 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-14 10:59:25,057 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-14 10:59:25,059 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-14 10:59:25,061 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-14 10:59:25,063 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpK6w2yW/model.
# 2019-02-14 10:59:25,083 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpsMlIMX/rouge_conf.xml
# 2019-02-14 10:59:25,084 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpsMlIMX/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.09635 (95%-conf.int. 0.08544 - 0.10708)
# 1 ROUGE-1 Average_P: 0.41875 (95%-conf.int. 0.39344 - 0.44472)
# 1 ROUGE-1 Average_F: 0.15454 (95%-conf.int. 0.13909 - 0.16998)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.01501 (95%-conf.int. 0.01189 - 0.01818)
# 1 ROUGE-2 Average_P: 0.06306 (95%-conf.int. 0.05277 - 0.07327)
# 1 ROUGE-2 Average_F: 0.02392 (95%-conf.int. 0.01915 - 0.02867)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00318 (95%-conf.int. 0.00212 - 0.00426)
# 1 ROUGE-3 Average_P: 0.01289 (95%-conf.int. 0.00899 - 0.01697)
# 1 ROUGE-3 Average_F: 0.00504 (95%-conf.int. 0.00339 - 0.00668)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00103 (95%-conf.int. 0.00054 - 0.00156)
# 1 ROUGE-4 Average_P: 0.00407 (95%-conf.int. 0.00221 - 0.00635)
# 1 ROUGE-4 Average_F: 0.00162 (95%-conf.int. 0.00086 - 0.00248)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.08822 (95%-conf.int. 0.07816 - 0.09795)
# 1 ROUGE-L Average_P: 0.38394 (95%-conf.int. 0.35964 - 0.40858)
# 1 ROUGE-L Average_F: 0.14152 (95%-conf.int. 0.12748 - 0.15559)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.02876 (95%-conf.int. 0.02590 - 0.03157)
# 1 ROUGE-W-1.2 Average_P: 0.23206 (95%-conf.int. 0.21964 - 0.24515)
# 1 ROUGE-W-1.2 Average_F: 0.05073 (95%-conf.int. 0.04607 - 0.05541)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.01027 (95%-conf.int. 0.00789 - 0.01267)
# 1 ROUGE-S* Average_P: 0.17290 (95%-conf.int. 0.15210 - 0.19549)
# 1 ROUGE-S* Average_F: 0.01904 (95%-conf.int. 0.01479 - 0.02332)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.01094 (95%-conf.int. 0.00848 - 0.01339)
# 1 ROUGE-SU* Average_P: 0.18189 (95%-conf.int. 0.16107 - 0.20415)
# 1 ROUGE-SU* Average_F: 0.02026 (95%-conf.int. 0.01590 - 0.02462)
#
# 6
# <function w2v_score at 0x7feb45457500>
