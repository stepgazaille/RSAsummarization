# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 7
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = get_w2v_score_func()

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-12 09:25:19,904 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 09:25:19,907 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpT1_8OQ/system and model files to /tmp/tmpT1_8OQ/model.
# 2019-02-12 09:25:19,908 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 09:25:19,910 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 09:25:19,912 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 09:25:19,914 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 09:25:19,916 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 09:25:19,918 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 09:25:19,920 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 09:25:19,922 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 09:25:19,924 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 09:25:19,927 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 09:25:19,929 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 09:25:19,931 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 09:25:19,933 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 09:25:19,935 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 09:25:19,937 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 09:25:19,939 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 09:25:19,941 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 09:25:19,944 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 09:25:19,946 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 09:25:19,948 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 09:25:19,950 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 09:25:19,952 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 09:25:19,954 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 09:25:19,956 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 09:25:19,958 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 09:25:19,960 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 09:25:19,962 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 09:25:19,964 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 09:25:19,966 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 09:25:19,968 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 09:25:19,970 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 09:25:19,972 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 09:25:19,974 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 09:25:19,976 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 09:25:19,978 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 09:25:19,981 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 09:25:19,983 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 09:25:19,985 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 09:25:19,987 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 09:25:19,989 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 09:25:19,991 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 09:25:19,993 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 09:25:19,995 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 09:25:19,997 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 09:25:19,999 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 09:25:20,001 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 09:25:20,004 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpT1_8OQ/system.
# 2019-02-12 09:25:20,005 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 09:25:20,006 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 09:25:20,009 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 09:25:20,011 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 09:25:20,013 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 09:25:20,015 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 09:25:20,018 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 09:25:20,020 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 09:25:20,022 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 09:25:20,024 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 09:25:20,027 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 09:25:20,029 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 09:25:20,031 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 09:25:20,033 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 09:25:20,035 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 09:25:20,038 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 09:25:20,040 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 09:25:20,042 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 09:25:20,045 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 09:25:20,047 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 09:25:20,049 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 09:25:20,051 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 09:25:20,054 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 09:25:20,056 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 09:25:20,058 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 09:25:20,060 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 09:25:20,063 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 09:25:20,065 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 09:25:20,067 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 09:25:20,070 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 09:25:20,072 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 09:25:20,074 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 09:25:20,077 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 09:25:20,079 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 09:25:20,081 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 09:25:20,083 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 09:25:20,086 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 09:25:20,088 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 09:25:20,090 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 09:25:20,093 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 09:25:20,095 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 09:25:20,097 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 09:25:20,100 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 09:25:20,102 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 09:25:20,104 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 09:25:20,106 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 09:25:20,109 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 09:25:20,111 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 09:25:20,113 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 09:25:20,115 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 09:25:20,118 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 09:25:20,120 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 09:25:20,122 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 09:25:20,124 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 09:25:20,127 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 09:25:20,129 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 09:25:20,131 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 09:25:20,133 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 09:25:20,136 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 09:25:20,138 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 09:25:20,140 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 09:25:20,143 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 09:25:20,145 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 09:25:20,147 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 09:25:20,149 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 09:25:20,152 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 09:25:20,154 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 09:25:20,156 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 09:25:20,159 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 09:25:20,161 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 09:25:20,163 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 09:25:20,165 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 09:25:20,167 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 09:25:20,170 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 09:25:20,172 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 09:25:20,174 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 09:25:20,176 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 09:25:20,178 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 09:25:20,180 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 09:25:20,183 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 09:25:20,185 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 09:25:20,187 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 09:25:20,189 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 09:25:20,191 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 09:25:20,194 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 09:25:20,196 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 09:25:20,198 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 09:25:20,200 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 09:25:20,203 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 09:25:20,205 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 09:25:20,207 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 09:25:20,209 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 09:25:20,212 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 09:25:20,214 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 09:25:20,216 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 09:25:20,219 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 09:25:20,221 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 09:25:20,223 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 09:25:20,225 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 09:25:20,228 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 09:25:20,230 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 09:25:20,232 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 09:25:20,234 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 09:25:20,236 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 09:25:20,238 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 09:25:20,240 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 09:25:20,242 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 09:25:20,245 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 09:25:20,247 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 09:25:20,249 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 09:25:20,251 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 09:25:20,253 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 09:25:20,255 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 09:25:20,257 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 09:25:20,259 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 09:25:20,262 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 09:25:20,264 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 09:25:20,266 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 09:25:20,268 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 09:25:20,270 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 09:25:20,272 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 09:25:20,274 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 09:25:20,276 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 09:25:20,278 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 09:25:20,280 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 09:25:20,283 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 09:25:20,285 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 09:25:20,287 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 09:25:20,289 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 09:25:20,291 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 09:25:20,293 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 09:25:20,296 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 09:25:20,298 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 09:25:20,300 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 09:25:20,302 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 09:25:20,304 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 09:25:20,306 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 09:25:20,309 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 09:25:20,311 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 09:25:20,313 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 09:25:20,316 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 09:25:20,318 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 09:25:20,320 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 09:25:20,323 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 09:25:20,325 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 09:25:20,327 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 09:25:20,329 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 09:25:20,331 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 09:25:20,334 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 09:25:20,336 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 09:25:20,338 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 09:25:20,341 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 09:25:20,343 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 09:25:20,345 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 09:25:20,347 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 09:25:20,350 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 09:25:20,352 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 09:25:20,354 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 09:25:20,356 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 09:25:20,359 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 09:25:20,361 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 09:25:20,363 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 09:25:20,366 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 09:25:20,368 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 09:25:20,370 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 09:25:20,372 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 09:25:20,375 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 09:25:20,377 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 09:25:20,379 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 09:25:20,382 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 09:25:20,384 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 09:25:20,386 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 09:25:20,389 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 09:25:20,391 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 09:25:20,393 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 09:25:20,395 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 09:25:20,398 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 09:25:20,400 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 09:25:20,402 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 09:25:20,405 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 09:25:20,407 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 09:25:20,409 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpT1_8OQ/model.
# 2019-02-12 09:25:20,426 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpAxJ_Df/rouge_conf.xml
# 2019-02-12 09:25:20,427 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpAxJ_Df/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.10846 (95%-conf.int. 0.09869 - 0.11835)
# 1 ROUGE-1 Average_P: 0.43337 (95%-conf.int. 0.41068 - 0.45644)
# 1 ROUGE-1 Average_F: 0.17191 (95%-conf.int. 0.15810 - 0.18549)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.02069 (95%-conf.int. 0.01639 - 0.02526)
# 1 ROUGE-2 Average_P: 0.08352 (95%-conf.int. 0.06702 - 0.10113)
# 1 ROUGE-2 Average_F: 0.03290 (95%-conf.int. 0.02627 - 0.04005)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00616 (95%-conf.int. 0.00393 - 0.00875)
# 1 ROUGE-3 Average_P: 0.02528 (95%-conf.int. 0.01616 - 0.03626)
# 1 ROUGE-3 Average_F: 0.00985 (95%-conf.int. 0.00625 - 0.01408)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00288 (95%-conf.int. 0.00148 - 0.00458)
# 1 ROUGE-4 Average_P: 0.01217 (95%-conf.int. 0.00599 - 0.01959)
# 1 ROUGE-4 Average_F: 0.00463 (95%-conf.int. 0.00236 - 0.00738)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.09836 (95%-conf.int. 0.08937 - 0.10749)
# 1 ROUGE-L Average_P: 0.39344 (95%-conf.int. 0.37022 - 0.41730)
# 1 ROUGE-L Average_F: 0.15595 (95%-conf.int. 0.14260 - 0.16886)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.03140 (95%-conf.int. 0.02875 - 0.03405)
# 1 ROUGE-W-1.2 Average_P: 0.23590 (95%-conf.int. 0.22369 - 0.24933)
# 1 ROUGE-W-1.2 Average_F: 0.05511 (95%-conf.int. 0.05075 - 0.05937)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.01183 (95%-conf.int. 0.00981 - 0.01392)
# 1 ROUGE-S* Average_P: 0.17952 (95%-conf.int. 0.16111 - 0.19912)
# 1 ROUGE-S* Average_F: 0.02194 (95%-conf.int. 0.01833 - 0.02569)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.01258 (95%-conf.int. 0.01049 - 0.01473)
# 1 ROUGE-SU* Average_P: 0.18786 (95%-conf.int. 0.16912 - 0.20747)
# 1 ROUGE-SU* Average_F: 0.02330 (95%-conf.int. 0.01960 - 0.02715)
#
# 7
# <function w2v_score at 0x7f24e7ed8500>
