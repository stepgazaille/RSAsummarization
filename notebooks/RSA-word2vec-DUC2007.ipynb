# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
ratio = 1
duc_num = 7
max_len = 250

#cmd = '/root/miniconda2/bin/python ../pointer-generator-master/run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file'
#cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
#cmd = cmd.split()
#generated_path = '/gttp/pointer-generator-master/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_120maxdec_ckpt-238410/'
#generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'


stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query

def ones(sent, ref): return 1.

def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_w2v_score_func(magic = 10):
    import gensim
    google = gensim.models.KeyedVectors.load_word2vec_format(
        'GoogleNews-vectors-negative300.bin', binary=True)
    def w2v_score(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        sent = [w for w in sent.split() if w in google]
        ref = [w for w in ref.split() if w in google]
        try:
            score = google.n_similarity(sent, ref)
        except:
            score = 0.
        return score * magic
    return w2v_score

def get_tfidf_score_func_glob(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        #ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        #v2s = [vectorizer.transform([r]) for r in ref]
        #return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]

    return tfidf_score_func

# %%
def get_tfidf_score_func(magic = 10):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [t.lower() for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = ref.lower()
        sent = sent.lower()
        v1 = vectorizer.transform([sent])
        v2 = vectorizer.transform([ref])
        return cosine_similarity(v1, v2)[0][0]*magic
    return tfidf_score_func


def just_relevant(text, query):
    text = text.split(' . ')
    score_per_sent = [count_score(sent, query) for sent in text]
    sents_gold = list(zip(*sorted(zip(score_per_sent, text), reverse=True)))[1]
    sents_gold = sents_gold[:int(len(sents_gold)*ratio)]

    filtered_sents = []
    for s in text:
        if not s: continue
        if s in sents_gold: filtered_sents.append(s)
    return ' . '.join(filtered_sents)

class Summary:
    def __init__(self, texts, abstracts, query):
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        #texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        #texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def add_sum(self, summ):
        for sent in summ:
            self.summary.append(sent)

    def get(self):
        text = max([(len(t.split()), t) for t in  self.texts])[1]
        #text = texts[0]
        if ratio < 1: text = just_relevant(text, self.query)

        sents = text.split(' . ')
        score_per_sent = [(score_func(sent, self.query), sent) for sent in sents]
        #score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
score_func = get_w2v_score_func()

summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(duc_num)]

with open('test/temp_file', 'wb') as writer:
    for summ in summaries:
        article, abstract, scores = summ.get()
        write_to_file(article, abstracts, scores, writer)
call(['rm', '-r', generated_path])
call(cmd)
generated_summaries = get_summaries(generated_path)

for i in range(len(summaries)):
    summaries[i].add_sum(generated_summaries[i])

# %%
evaluate(summaries)
print duc_num
print score_func
# Out:
# 2019-02-14 11:02:27,818 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 11:02:27,821 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpDzWYnt/system and model files to /tmp/tmpDzWYnt/model.
# 2019-02-14 11:02:27,822 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 11:02:27,824 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 11:02:27,826 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 11:02:27,828 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 11:02:27,830 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 11:02:27,832 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 11:02:27,835 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 11:02:27,837 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 11:02:27,839 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 11:02:27,841 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 11:02:27,843 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 11:02:27,846 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 11:02:27,848 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 11:02:27,850 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 11:02:27,852 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 11:02:27,854 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 11:02:27,856 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 11:02:27,858 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 11:02:27,860 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 11:02:27,862 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 11:02:27,864 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 11:02:27,867 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 11:02:27,869 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 11:02:27,871 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 11:02:27,873 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 11:02:27,875 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 11:02:27,877 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 11:02:27,879 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 11:02:27,881 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 11:02:27,883 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 11:02:27,885 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 11:02:27,887 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 11:02:27,889 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 11:02:27,891 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 11:02:27,893 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 11:02:27,895 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 11:02:27,897 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 11:02:27,899 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 11:02:27,901 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 11:02:27,903 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 11:02:27,905 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 11:02:27,908 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 11:02:27,910 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 11:02:27,912 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 11:02:27,914 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 11:02:27,916 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 11:02:27,918 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpDzWYnt/system.
# 2019-02-14 11:02:27,919 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 11:02:27,921 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 11:02:27,923 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 11:02:27,925 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 11:02:27,927 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 11:02:27,929 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 11:02:27,931 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 11:02:27,933 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 11:02:27,935 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 11:02:27,938 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 11:02:27,940 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 11:02:27,942 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 11:02:27,944 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 11:02:27,946 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 11:02:27,949 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 11:02:27,951 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 11:02:27,953 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 11:02:27,955 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 11:02:27,957 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 11:02:27,960 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 11:02:27,962 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 11:02:27,964 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 11:02:27,966 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 11:02:27,969 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 11:02:27,971 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 11:02:27,973 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 11:02:27,975 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 11:02:27,977 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 11:02:27,979 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 11:02:27,982 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 11:02:27,984 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 11:02:27,986 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 11:02:27,988 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 11:02:27,990 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 11:02:27,992 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 11:02:27,994 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 11:02:27,996 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 11:02:27,999 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 11:02:28,001 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 11:02:28,003 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 11:02:28,005 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 11:02:28,007 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 11:02:28,009 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 11:02:28,011 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 11:02:28,014 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 11:02:28,016 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 11:02:28,018 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 11:02:28,020 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 11:02:28,023 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 11:02:28,025 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 11:02:28,027 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 11:02:28,029 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 11:02:28,031 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 11:02:28,033 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 11:02:28,036 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 11:02:28,038 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 11:02:28,040 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 11:02:28,042 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 11:02:28,044 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 11:02:28,046 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 11:02:28,049 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 11:02:28,051 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 11:02:28,053 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 11:02:28,055 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 11:02:28,057 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 11:02:28,060 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 11:02:28,062 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 11:02:28,064 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 11:02:28,067 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 11:02:28,069 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 11:02:28,071 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 11:02:28,073 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 11:02:28,075 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 11:02:28,077 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 11:02:28,079 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 11:02:28,082 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 11:02:28,084 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 11:02:28,086 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 11:02:28,088 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 11:02:28,090 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 11:02:28,093 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 11:02:28,095 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 11:02:28,097 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 11:02:28,099 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 11:02:28,101 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 11:02:28,104 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 11:02:28,106 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 11:02:28,108 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 11:02:28,110 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 11:02:28,112 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 11:02:28,114 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 11:02:28,117 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 11:02:28,119 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 11:02:28,121 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 11:02:28,123 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 11:02:28,125 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 11:02:28,127 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 11:02:28,129 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 11:02:28,132 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 11:02:28,134 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 11:02:28,136 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 11:02:28,138 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 11:02:28,140 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 11:02:28,142 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 11:02:28,144 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 11:02:28,147 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 11:02:28,149 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 11:02:28,151 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 11:02:28,153 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 11:02:28,155 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 11:02:28,157 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 11:02:28,159 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 11:02:28,162 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 11:02:28,164 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 11:02:28,166 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 11:02:28,168 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 11:02:28,170 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 11:02:28,172 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 11:02:28,174 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 11:02:28,176 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 11:02:28,179 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 11:02:28,181 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 11:02:28,183 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 11:02:28,185 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 11:02:28,187 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 11:02:28,189 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 11:02:28,191 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 11:02:28,193 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 11:02:28,195 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 11:02:28,198 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 11:02:28,200 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 11:02:28,202 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 11:02:28,204 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 11:02:28,206 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 11:02:28,208 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 11:02:28,211 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 11:02:28,213 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 11:02:28,215 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 11:02:28,217 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 11:02:28,219 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 11:02:28,222 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 11:02:28,224 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 11:02:28,226 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 11:02:28,228 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 11:02:28,230 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 11:02:28,233 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 11:02:28,235 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 11:02:28,237 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 11:02:28,239 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 11:02:28,241 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 11:02:28,243 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 11:02:28,246 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 11:02:28,248 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 11:02:28,250 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 11:02:28,253 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 11:02:28,255 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 11:02:28,257 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 11:02:28,259 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 11:02:28,262 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 11:02:28,264 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 11:02:28,266 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 11:02:28,268 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 11:02:28,270 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 11:02:28,272 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 11:02:28,275 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 11:02:28,277 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 11:02:28,279 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 11:02:28,281 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 11:02:28,283 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 11:02:28,285 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 11:02:28,287 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 11:02:28,290 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 11:02:28,292 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 11:02:28,294 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 11:02:28,296 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 11:02:28,299 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 11:02:28,301 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 11:02:28,303 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 11:02:28,305 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 11:02:28,307 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 11:02:28,310 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 11:02:28,312 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpDzWYnt/model.
# 2019-02-14 11:02:28,328 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpGnHUt4/rouge_conf.xml
# 2019-02-14 11:02:28,329 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpGnHUt4/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.10595 (95%-conf.int. 0.09454 - 0.11863)
# 1 ROUGE-1 Average_P: 0.43555 (95%-conf.int. 0.40988 - 0.46134)
# 1 ROUGE-1 Average_F: 0.16901 (95%-conf.int. 0.15272 - 0.18610)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.02022 (95%-conf.int. 0.01569 - 0.02541)
# 1 ROUGE-2 Average_P: 0.08181 (95%-conf.int. 0.06538 - 0.09935)
# 1 ROUGE-2 Average_F: 0.03214 (95%-conf.int. 0.02520 - 0.04008)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.00606 (95%-conf.int. 0.00346 - 0.00929)
# 1 ROUGE-3 Average_P: 0.02434 (95%-conf.int. 0.01412 - 0.03641)
# 1 ROUGE-3 Average_F: 0.00961 (95%-conf.int. 0.00551 - 0.01482)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.00310 (95%-conf.int. 0.00137 - 0.00519)
# 1 ROUGE-4 Average_P: 0.01267 (95%-conf.int. 0.00531 - 0.02198)
# 1 ROUGE-4 Average_F: 0.00493 (95%-conf.int. 0.00216 - 0.00829)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.09580 (95%-conf.int. 0.08549 - 0.10715)
# 1 ROUGE-L Average_P: 0.39522 (95%-conf.int. 0.37210 - 0.41874)
# 1 ROUGE-L Average_F: 0.15294 (95%-conf.int. 0.13847 - 0.16862)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.03068 (95%-conf.int. 0.02779 - 0.03381)
# 1 ROUGE-W-1.2 Average_P: 0.23733 (95%-conf.int. 0.22434 - 0.25032)
# 1 ROUGE-W-1.2 Average_F: 0.05405 (95%-conf.int. 0.04921 - 0.05911)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.01165 (95%-conf.int. 0.00909 - 0.01453)
# 1 ROUGE-S* Average_P: 0.18316 (95%-conf.int. 0.16363 - 0.20372)
# 1 ROUGE-S* Average_F: 0.02161 (95%-conf.int. 0.01702 - 0.02660)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.01238 (95%-conf.int. 0.00974 - 0.01534)
# 1 ROUGE-SU* Average_P: 0.19161 (95%-conf.int. 0.17228 - 0.21203)
# 1 ROUGE-SU* Average_F: 0.02295 (95%-conf.int. 0.01824 - 0.02804)
#
# 7
# <function w2v_score at 0x7f64d8658500>
