# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
# cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
# generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
# cmd = cmd.split()

vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
max_len = 250
stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query


def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_tfidf_score_func(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        v2s = [vectorizer.transform([r]) for r in ref]
        return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func()

# %%
class Summary:
    def __init__(self, texts, abstracts, query):
        
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def most_similar(self, sent, text):
        return max([(count_score(s, sent), s) for s in text])[1]

    def add_sum(self, summ):
        text = self.texts.pop(0).split(' . ')
        if len(self.texts) == 0: return True
        found_sents = []
        for sent in summ:
            ms = self.most_similar(sent, text)
            if ms in found_sents:
                continue
            found_sents.append(sent)
            splitted = pp(sent).split()
            length = len(splitted) 
            splitted = set(splitted)       
            if self.length+length > max_len: return True
            if len(splitted - self.words) < int(len(splitted)*0.5): return False
            self.words |= splitted     
            self.summary.append(sent)
            self.length +=length
        return False

    def get(self):
        text = self.texts[0]
        sents = text.split(' . ')
        #score_per_sent = [(count_score(sent, self.query), sent) for sent in sents]
        score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
for i in [7]:
    duc_num = i
    done_summaries = []
    summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(i)]
    while summaries:
        with open('test/temp_file', 'wb') as writer:
            for summ in summaries:
                article, abstract, scores = summ.get()
                write_to_file(article, abstracts, scores, writer)
        call(['rm', '-r', generated_path])     
        call(cmd)
        generated_summaries = get_summaries(generated_path)
        should_remove = []
        for i in range(len(summaries)):
            if summaries[i].add_sum(generated_summaries[i]):
                should_remove.append(i)
        for i in should_remove[::-1]: 
            done_summaries.append(summaries.pop(i))
    evaluate(done_summaries)
    print duc_num
# Out:
# 2019-02-12 15:18:07,346 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 15:18:07,350 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpI7u8iT/system and model files to /tmp/tmpI7u8iT/model.
# 2019-02-12 15:18:07,351 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 15:18:07,353 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 15:18:07,355 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 15:18:07,357 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 15:18:07,360 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 15:18:07,362 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 15:18:07,364 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 15:18:07,367 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 15:18:07,369 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 15:18:07,371 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 15:18:07,373 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 15:18:07,375 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 15:18:07,378 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 15:18:07,380 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 15:18:07,382 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 15:18:07,384 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 15:18:07,386 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 15:18:07,389 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 15:18:07,391 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 15:18:07,393 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 15:18:07,395 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 15:18:07,397 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 15:18:07,400 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 15:18:07,402 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 15:18:07,404 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 15:18:07,406 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 15:18:07,408 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 15:18:07,411 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 15:18:07,413 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 15:18:07,415 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 15:18:07,417 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 15:18:07,420 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 15:18:07,422 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 15:18:07,424 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 15:18:07,426 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 15:18:07,428 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 15:18:07,431 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 15:18:07,433 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 15:18:07,435 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 15:18:07,437 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 15:18:07,439 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 15:18:07,442 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 15:18:07,444 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 15:18:07,446 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 15:18:07,448 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 15:18:07,450 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 15:18:07,453 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpI7u8iT/system.
# 2019-02-12 15:18:07,454 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 15:18:07,455 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 15:18:07,457 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 15:18:07,459 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 15:18:07,463 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 15:18:07,465 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 15:18:07,467 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 15:18:07,469 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 15:18:07,471 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 15:18:07,473 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 15:18:07,476 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 15:18:07,478 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 15:18:07,480 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 15:18:07,482 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 15:18:07,484 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 15:18:07,486 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 15:18:07,489 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 15:18:07,491 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 15:18:07,493 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 15:18:07,495 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 15:18:07,497 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 15:18:07,499 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 15:18:07,501 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 15:18:07,504 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 15:18:07,506 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 15:18:07,508 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 15:18:07,510 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 15:18:07,513 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 15:18:07,515 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 15:18:07,517 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 15:18:07,519 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 15:18:07,522 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 15:18:07,524 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 15:18:07,526 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 15:18:07,528 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 15:18:07,530 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 15:18:07,532 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 15:18:07,534 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 15:18:07,537 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 15:18:07,539 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 15:18:07,541 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 15:18:07,543 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 15:18:07,546 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 15:18:07,548 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 15:18:07,550 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 15:18:07,552 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 15:18:07,554 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 15:18:07,557 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 15:18:07,559 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 15:18:07,561 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 15:18:07,563 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 15:18:07,565 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 15:18:07,568 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 15:18:07,570 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 15:18:07,572 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 15:18:07,574 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 15:18:07,576 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 15:18:07,579 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 15:18:07,581 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 15:18:07,583 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 15:18:07,585 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 15:18:07,587 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 15:18:07,590 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 15:18:07,592 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 15:18:07,594 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 15:18:07,596 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 15:18:07,598 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 15:18:07,601 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 15:18:07,603 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 15:18:07,605 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 15:18:07,607 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 15:18:07,610 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 15:18:07,612 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 15:18:07,614 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 15:18:07,616 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 15:18:07,619 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 15:18:07,621 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 15:18:07,623 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 15:18:07,625 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 15:18:07,627 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 15:18:07,630 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 15:18:07,632 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 15:18:07,634 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 15:18:07,637 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 15:18:07,639 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 15:18:07,641 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 15:18:07,644 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 15:18:07,646 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 15:18:07,648 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 15:18:07,650 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 15:18:07,653 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 15:18:07,655 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 15:18:07,657 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 15:18:07,659 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 15:18:07,662 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 15:18:07,664 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 15:18:07,666 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 15:18:07,668 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 15:18:07,670 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 15:18:07,673 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 15:18:07,675 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 15:18:07,677 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 15:18:07,679 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 15:18:07,681 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 15:18:07,684 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 15:18:07,686 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 15:18:07,688 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 15:18:07,690 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 15:18:07,692 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 15:18:07,694 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 15:18:07,696 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 15:18:07,698 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 15:18:07,701 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 15:18:07,703 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 15:18:07,705 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 15:18:07,707 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 15:18:07,709 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 15:18:07,711 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 15:18:07,714 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 15:18:07,716 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 15:18:07,718 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 15:18:07,720 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 15:18:07,722 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 15:18:07,724 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 15:18:07,726 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 15:18:07,728 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 15:18:07,730 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 15:18:07,732 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 15:18:07,735 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 15:18:07,737 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 15:18:07,739 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 15:18:07,741 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 15:18:07,744 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 15:18:07,746 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 15:18:07,748 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 15:18:07,750 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 15:18:07,753 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 15:18:07,755 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 15:18:07,757 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 15:18:07,759 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 15:18:07,762 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 15:18:07,764 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 15:18:07,766 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 15:18:07,768 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 15:18:07,771 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 15:18:07,773 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 15:18:07,775 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 15:18:07,777 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 15:18:07,780 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 15:18:07,782 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 15:18:07,784 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 15:18:07,787 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 15:18:07,789 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 15:18:07,791 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 15:18:07,794 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 15:18:07,796 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 15:18:07,798 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 15:18:07,800 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 15:18:07,802 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 15:18:07,805 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 15:18:07,807 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 15:18:07,809 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 15:18:07,812 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 15:18:07,814 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 15:18:07,816 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 15:18:07,818 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 15:18:07,820 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 15:18:07,823 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 15:18:07,825 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 15:18:07,827 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 15:18:07,830 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 15:18:07,832 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 15:18:07,834 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 15:18:07,837 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 15:18:07,839 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 15:18:07,841 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 15:18:07,844 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 15:18:07,846 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 15:18:07,848 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 15:18:07,850 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 15:18:07,853 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 15:18:07,855 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpI7u8iT/model.
# 2019-02-12 15:18:07,871 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmplShfop/rouge_conf.xml
# 2019-02-12 15:18:07,873 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmplShfop/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.47530 (95%-conf.int. 0.46184 - 0.48849)
# 1 ROUGE-1 Average_P: 0.39062 (95%-conf.int. 0.37893 - 0.40256)
# 1 ROUGE-1 Average_F: 0.42841 (95%-conf.int. 0.41629 - 0.44031)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.12476 (95%-conf.int. 0.11508 - 0.13457)
# 1 ROUGE-2 Average_P: 0.10263 (95%-conf.int. 0.09476 - 0.11041)
# 1 ROUGE-2 Average_F: 0.11251 (95%-conf.int. 0.10394 - 0.12077)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.04692 (95%-conf.int. 0.04078 - 0.05318)
# 1 ROUGE-3 Average_P: 0.03856 (95%-conf.int. 0.03362 - 0.04334)
# 1 ROUGE-3 Average_F: 0.04229 (95%-conf.int. 0.03690 - 0.04768)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.02444 (95%-conf.int. 0.02046 - 0.02860)
# 1 ROUGE-4 Average_P: 0.02002 (95%-conf.int. 0.01677 - 0.02325)
# 1 ROUGE-4 Average_F: 0.02199 (95%-conf.int. 0.01844 - 0.02555)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.44100 (95%-conf.int. 0.42901 - 0.45312)
# 1 ROUGE-L Average_P: 0.36248 (95%-conf.int. 0.35170 - 0.37371)
# 1 ROUGE-L Average_F: 0.39753 (95%-conf.int. 0.38667 - 0.40859)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.12726 (95%-conf.int. 0.12381 - 0.13069)
# 1 ROUGE-W-1.2 Average_P: 0.19449 (95%-conf.int. 0.18869 - 0.20040)
# 1 ROUGE-W-1.2 Average_F: 0.15369 (95%-conf.int. 0.14961 - 0.15793)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.20723 (95%-conf.int. 0.19566 - 0.21893)
# 1 ROUGE-S* Average_P: 0.14041 (95%-conf.int. 0.13194 - 0.14864)
# 1 ROUGE-S* Average_F: 0.16678 (95%-conf.int. 0.15771 - 0.17596)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.20933 (95%-conf.int. 0.19776 - 0.22105)
# 1 ROUGE-SU* Average_P: 0.14203 (95%-conf.int. 0.13353 - 0.15032)
# 1 ROUGE-SU* Average_F: 0.16862 (95%-conf.int. 0.15953 - 0.17782)
#
# 7
