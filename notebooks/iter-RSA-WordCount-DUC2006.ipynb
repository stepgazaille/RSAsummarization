# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
# cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
# generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
# cmd = cmd.split()

vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
max_len = 250
stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query


def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_tfidf_score_func(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        v2s = [vectorizer.transform([r]) for r in ref]
        return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
    return tfidf_score_func

# %%
class Summary:
    def __init__(self, texts, abstracts, query):
        
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        texts = sorted([(count_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def most_similar(self, sent, text):
        return max([(count_score(s, sent), s) for s in text])[1]

    def add_sum(self, summ):
        text = self.texts.pop(0).split(' . ')
        if len(self.texts) == 0: return True
        found_sents = []
        for sent in summ:
            ms = self.most_similar(sent, text)
            if ms in found_sents:
                continue
            found_sents.append(sent)
            splitted = pp(sent).split()
            length = len(splitted) 
            splitted = set(splitted)       
            if self.length+length > max_len: return True
            if len(splitted - self.words) < int(len(splitted)*0.5): return False
            self.words |= splitted     
            self.summary.append(sent)
            self.length +=length
        return False

    def get(self):
        text = self.texts[0]
        sents = text.split(' . ')
        #score_per_sent = [(count_score(sent, self.query), sent) for sent in sents]
        score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
for i in [6]:
    duc_num = i
    done_summaries = []
    summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(i)]
    while summaries:
        with open('test/temp_file', 'wb') as writer:
            for summ in summaries:
                article, abstract, scores = summ.get()
                write_to_file(article, abstracts, scores, writer)
        call(['rm', '-r', generated_path])     
        call(cmd)
        generated_summaries = get_summaries(generated_path)
        should_remove = []
        for i in range(len(summaries)):
            if summaries[i].add_sum(generated_summaries[i]):
                should_remove.append(i)
        for i in should_remove[::-1]: 
            done_summaries.append(summaries.pop(i))
    evaluate(done_summaries)
    print duc_num
# Out:
# 2019-02-12 16:34:41,295 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 16:34:41,298 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpUu7EMI/system and model files to /tmp/tmpUu7EMI/model.
# 2019-02-12 16:34:41,300 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 16:34:41,301 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 16:34:41,303 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 16:34:41,305 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 16:34:41,308 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 16:34:41,310 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 16:34:41,312 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 16:34:41,314 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 16:34:41,317 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 16:34:41,319 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 16:34:41,321 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 16:34:41,323 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 16:34:41,325 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 16:34:41,327 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 16:34:41,330 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 16:34:41,332 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 16:34:41,334 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 16:34:41,336 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 16:34:41,339 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 16:34:41,341 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 16:34:41,343 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 16:34:41,345 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 16:34:41,347 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 16:34:41,349 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 16:34:41,351 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 16:34:41,354 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 16:34:41,356 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 16:34:41,358 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 16:34:41,360 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 16:34:41,362 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 16:34:41,365 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 16:34:41,367 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 16:34:41,369 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 16:34:41,371 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 16:34:41,373 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 16:34:41,376 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 16:34:41,378 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 16:34:41,380 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 16:34:41,382 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 16:34:41,385 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 16:34:41,387 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 16:34:41,389 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 16:34:41,391 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 16:34:41,394 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 16:34:41,396 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 16:34:41,397 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 16:34:41,399 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-12 16:34:41,402 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-12 16:34:41,404 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-12 16:34:41,406 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-12 16:34:41,408 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-12 16:34:41,410 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpUu7EMI/system.
# 2019-02-12 16:34:41,412 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 16:34:41,413 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 16:34:41,415 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 16:34:41,417 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 16:34:41,420 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 16:34:41,422 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 16:34:41,424 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 16:34:41,426 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 16:34:41,428 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 16:34:41,430 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 16:34:41,433 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 16:34:41,435 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 16:34:41,437 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 16:34:41,439 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 16:34:41,441 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 16:34:41,444 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 16:34:41,446 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 16:34:41,448 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 16:34:41,450 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 16:34:41,452 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 16:34:41,454 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 16:34:41,456 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 16:34:41,459 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 16:34:41,461 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 16:34:41,463 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 16:34:41,465 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 16:34:41,467 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 16:34:41,469 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 16:34:41,471 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 16:34:41,473 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 16:34:41,476 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 16:34:41,478 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 16:34:41,480 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 16:34:41,482 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 16:34:41,484 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 16:34:41,486 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 16:34:41,488 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 16:34:41,490 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 16:34:41,492 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 16:34:41,494 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 16:34:41,496 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 16:34:41,499 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 16:34:41,501 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 16:34:41,503 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 16:34:41,505 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 16:34:41,507 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 16:34:41,509 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 16:34:41,511 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 16:34:41,514 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 16:34:41,516 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 16:34:41,518 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 16:34:41,520 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 16:34:41,522 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 16:34:41,525 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 16:34:41,527 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 16:34:41,529 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 16:34:41,531 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 16:34:41,533 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 16:34:41,535 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 16:34:41,538 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 16:34:41,540 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 16:34:41,542 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 16:34:41,544 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 16:34:41,547 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 16:34:41,549 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 16:34:41,551 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 16:34:41,553 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 16:34:41,555 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 16:34:41,557 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 16:34:41,559 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 16:34:41,561 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 16:34:41,564 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 16:34:41,566 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 16:34:41,568 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 16:34:41,570 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 16:34:41,572 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 16:34:41,574 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 16:34:41,576 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 16:34:41,579 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 16:34:41,581 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 16:34:41,583 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 16:34:41,585 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 16:34:41,587 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 16:34:41,589 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 16:34:41,591 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 16:34:41,593 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 16:34:41,596 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 16:34:41,598 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 16:34:41,600 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 16:34:41,602 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 16:34:41,605 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 16:34:41,607 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 16:34:41,609 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 16:34:41,611 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 16:34:41,613 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 16:34:41,615 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 16:34:41,617 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 16:34:41,619 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 16:34:41,622 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 16:34:41,624 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 16:34:41,626 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 16:34:41,628 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 16:34:41,631 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 16:34:41,633 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 16:34:41,635 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 16:34:41,637 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 16:34:41,640 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 16:34:41,642 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 16:34:41,644 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 16:34:41,646 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 16:34:41,649 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 16:34:41,651 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 16:34:41,653 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 16:34:41,655 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 16:34:41,657 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 16:34:41,659 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 16:34:41,662 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 16:34:41,664 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 16:34:41,666 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 16:34:41,668 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 16:34:41,670 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 16:34:41,673 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 16:34:41,675 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 16:34:41,677 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 16:34:41,679 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 16:34:41,681 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 16:34:41,683 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 16:34:41,686 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 16:34:41,688 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 16:34:41,690 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 16:34:41,693 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 16:34:41,695 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 16:34:41,697 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 16:34:41,699 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 16:34:41,702 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 16:34:41,704 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 16:34:41,706 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 16:34:41,708 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 16:34:41,711 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 16:34:41,713 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 16:34:41,715 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 16:34:41,717 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 16:34:41,719 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 16:34:41,721 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 16:34:41,724 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 16:34:41,726 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 16:34:41,728 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 16:34:41,730 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 16:34:41,733 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 16:34:41,735 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 16:34:41,737 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 16:34:41,739 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 16:34:41,742 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 16:34:41,744 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 16:34:41,746 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 16:34:41,749 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 16:34:41,751 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 16:34:41,753 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 16:34:41,756 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 16:34:41,758 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 16:34:41,760 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 16:34:41,762 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 16:34:41,764 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 16:34:41,766 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 16:34:41,768 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 16:34:41,770 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 16:34:41,773 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 16:34:41,775 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 16:34:41,777 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 16:34:41,779 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 16:34:41,781 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 16:34:41,783 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 16:34:41,786 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 16:34:41,788 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 16:34:41,790 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 16:34:41,792 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 16:34:41,794 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 16:34:41,797 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 16:34:41,799 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 16:34:41,801 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 16:34:41,803 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 16:34:41,805 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-12 16:34:41,807 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-12 16:34:41,809 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-12 16:34:41,811 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-12 16:34:41,813 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-12 16:34:41,816 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-12 16:34:41,818 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-12 16:34:41,820 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-12 16:34:41,822 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-12 16:34:41,824 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-12 16:34:41,826 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-12 16:34:41,829 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-12 16:34:41,831 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-12 16:34:41,833 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-12 16:34:41,835 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-12 16:34:41,837 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-12 16:34:41,839 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-12 16:34:41,841 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-12 16:34:41,844 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-12 16:34:41,846 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-12 16:34:41,848 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpUu7EMI/model.
# 2019-02-12 16:34:41,867 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpssf6VC/rouge_conf.xml
# 2019-02-12 16:34:41,868 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpssf6VC/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.44152 (95%-conf.int. 0.42883 - 0.45341)
# 1 ROUGE-1 Average_P: 0.36064 (95%-conf.int. 0.34958 - 0.37110)
# 1 ROUGE-1 Average_F: 0.39650 (95%-conf.int. 0.38549 - 0.40682)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.09449 (95%-conf.int. 0.08680 - 0.10171)
# 1 ROUGE-2 Average_P: 0.07703 (95%-conf.int. 0.07107 - 0.08276)
# 1 ROUGE-2 Average_F: 0.08476 (95%-conf.int. 0.07824 - 0.09099)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.03259 (95%-conf.int. 0.02835 - 0.03680)
# 1 ROUGE-3 Average_P: 0.02649 (95%-conf.int. 0.02314 - 0.02976)
# 1 ROUGE-3 Average_F: 0.02919 (95%-conf.int. 0.02543 - 0.03293)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.01673 (95%-conf.int. 0.01388 - 0.01976)
# 1 ROUGE-4 Average_P: 0.01357 (95%-conf.int. 0.01131 - 0.01608)
# 1 ROUGE-4 Average_F: 0.01497 (95%-conf.int. 0.01243 - 0.01769)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.40779 (95%-conf.int. 0.39546 - 0.41917)
# 1 ROUGE-L Average_P: 0.33295 (95%-conf.int. 0.32285 - 0.34229)
# 1 ROUGE-L Average_F: 0.36613 (95%-conf.int. 0.35555 - 0.37552)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.11764 (95%-conf.int. 0.11414 - 0.12127)
# 1 ROUGE-W-1.2 Average_P: 0.17546 (95%-conf.int. 0.17045 - 0.18035)
# 1 ROUGE-W-1.2 Average_F: 0.14065 (95%-conf.int. 0.13688 - 0.14438)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.18005 (95%-conf.int. 0.17014 - 0.18983)
# 1 ROUGE-S* Average_P: 0.11999 (95%-conf.int. 0.11349 - 0.12659)
# 1 ROUGE-S* Average_F: 0.14330 (95%-conf.int. 0.13599 - 0.15011)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.18209 (95%-conf.int. 0.17216 - 0.19189)
# 1 ROUGE-SU* Average_P: 0.12154 (95%-conf.int. 0.11498 - 0.12817)
# 1 ROUGE-SU* Average_F: 0.14506 (95%-conf.int. 0.13775 - 0.15190)
#
# 6
