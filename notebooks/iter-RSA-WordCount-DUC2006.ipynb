# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
# cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
# generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
# cmd = cmd.split()

vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
max_len = 250
stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query


def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_tfidf_score_func(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        v2s = [vectorizer.transform([r]) for r in ref]
        return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func()

# %%
class Summary:
    def __init__(self, texts, abstracts, query):
        
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def most_similar(self, sent, text):
        return max([(count_score(s, sent), s) for s in text])[1]

    def add_sum(self, summ):
        text = self.texts.pop(0).split(' . ')
        if len(self.texts) == 0: return True
        found_sents = []
        for sent in summ:
            ms = self.most_similar(sent, text)
            if ms in found_sents:
                continue
            found_sents.append(sent)
            splitted = pp(sent).split()
            length = len(splitted) 
            splitted = set(splitted)       
            if self.length+length > max_len: return True
            if len(splitted - self.words) < int(len(splitted)*0.5): return False
            self.words |= splitted     
            self.summary.append(sent)
            self.length +=length
        return False

    def get(self):
        text = self.texts[0]
        sents = text.split(' . ')
        #score_per_sent = [(count_score(sent, self.query), sent) for sent in sents]
        score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
for i in [6]:
    duc_num = i
    done_summaries = []
    summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(i)]
    while summaries:
        with open('test/temp_file', 'wb') as writer:
            for summ in summaries:
                article, abstract, scores = summ.get()
                write_to_file(article, abstracts, scores, writer)
        call(['rm', '-r', generated_path])     
        call(cmd)
        generated_summaries = get_summaries(generated_path)
        should_remove = []
        for i in range(len(summaries)):
            if summaries[i].add_sum(generated_summaries[i]):
                should_remove.append(i)
        for i in should_remove[::-1]: 
            done_summaries.append(summaries.pop(i))
    evaluate(done_summaries)
    print duc_num
# Out:
# 2019-02-14 14:48:16,612 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 14:48:16,616 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpxvpdOz/system and model files to /tmp/tmpxvpdOz/model.
# 2019-02-14 14:48:16,617 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 14:48:16,618 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 14:48:16,621 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 14:48:16,623 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 14:48:16,625 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 14:48:16,628 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 14:48:16,630 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 14:48:16,632 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 14:48:16,634 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 14:48:16,637 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 14:48:16,639 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 14:48:16,641 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 14:48:16,643 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 14:48:16,645 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 14:48:16,647 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 14:48:16,650 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 14:48:16,652 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 14:48:16,654 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 14:48:16,656 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 14:48:16,658 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 14:48:16,660 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 14:48:16,663 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 14:48:16,665 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 14:48:16,667 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 14:48:16,669 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 14:48:16,672 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 14:48:16,674 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 14:48:16,676 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 14:48:16,678 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 14:48:16,680 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 14:48:16,682 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 14:48:16,684 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 14:48:16,687 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 14:48:16,689 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 14:48:16,691 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 14:48:16,693 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 14:48:16,695 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 14:48:16,698 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 14:48:16,700 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 14:48:16,702 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 14:48:16,704 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 14:48:16,706 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 14:48:16,709 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 14:48:16,711 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 14:48:16,713 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 14:48:16,715 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 14:48:16,718 [MainThread  ] [INFO ]  Processing 45_decoded.txt.
# 2019-02-14 14:48:16,720 [MainThread  ] [INFO ]  Processing 46_decoded.txt.
# 2019-02-14 14:48:16,722 [MainThread  ] [INFO ]  Processing 47_decoded.txt.
# 2019-02-14 14:48:16,724 [MainThread  ] [INFO ]  Processing 48_decoded.txt.
# 2019-02-14 14:48:16,726 [MainThread  ] [INFO ]  Processing 49_decoded.txt.
# 2019-02-14 14:48:16,729 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpxvpdOz/system.
# 2019-02-14 14:48:16,730 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 14:48:16,731 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 14:48:16,733 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 14:48:16,735 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 14:48:16,738 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 14:48:16,740 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 14:48:16,742 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 14:48:16,744 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 14:48:16,746 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 14:48:16,748 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 14:48:16,750 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 14:48:16,752 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 14:48:16,755 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 14:48:16,757 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 14:48:16,759 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 14:48:16,761 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 14:48:16,763 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 14:48:16,765 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 14:48:16,768 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 14:48:16,770 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 14:48:16,772 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 14:48:16,774 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 14:48:16,777 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 14:48:16,779 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 14:48:16,781 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 14:48:16,783 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 14:48:16,785 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 14:48:16,787 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 14:48:16,789 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 14:48:16,791 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 14:48:16,794 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 14:48:16,796 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 14:48:16,798 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 14:48:16,800 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 14:48:16,802 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 14:48:16,805 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 14:48:16,807 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 14:48:16,809 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 14:48:16,811 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 14:48:16,813 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 14:48:16,815 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 14:48:16,818 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 14:48:16,820 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 14:48:16,822 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 14:48:16,824 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 14:48:16,827 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 14:48:16,829 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 14:48:16,831 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 14:48:16,833 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 14:48:16,836 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 14:48:16,839 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 14:48:16,841 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 14:48:16,844 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 14:48:16,846 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 14:48:16,848 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 14:48:16,850 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 14:48:16,853 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 14:48:16,855 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 14:48:16,857 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 14:48:16,859 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 14:48:16,861 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 14:48:16,864 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 14:48:16,866 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 14:48:16,868 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 14:48:16,870 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 14:48:16,872 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 14:48:16,875 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 14:48:16,877 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 14:48:16,879 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 14:48:16,881 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 14:48:16,883 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 14:48:16,886 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 14:48:16,888 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 14:48:16,890 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 14:48:16,892 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 14:48:16,894 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 14:48:16,897 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 14:48:16,899 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 14:48:16,901 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 14:48:16,903 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 14:48:16,905 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 14:48:16,908 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 14:48:16,910 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 14:48:16,912 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 14:48:16,915 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 14:48:16,917 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 14:48:16,919 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 14:48:16,921 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 14:48:16,924 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 14:48:16,926 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 14:48:16,928 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 14:48:16,930 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 14:48:16,932 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 14:48:16,935 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 14:48:16,937 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 14:48:16,939 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 14:48:16,941 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 14:48:16,943 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 14:48:16,945 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 14:48:16,948 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 14:48:16,950 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 14:48:16,953 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 14:48:16,955 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 14:48:16,957 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 14:48:16,960 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 14:48:16,962 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 14:48:16,964 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 14:48:16,966 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 14:48:16,968 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 14:48:16,971 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 14:48:16,973 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 14:48:16,975 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 14:48:16,978 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 14:48:16,980 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 14:48:16,982 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 14:48:16,984 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 14:48:16,987 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 14:48:16,989 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 14:48:16,991 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 14:48:16,993 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 14:48:16,995 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 14:48:16,997 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 14:48:16,999 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 14:48:17,002 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 14:48:17,004 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 14:48:17,006 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 14:48:17,008 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 14:48:17,010 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 14:48:17,013 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 14:48:17,015 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 14:48:17,017 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 14:48:17,019 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 14:48:17,021 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 14:48:17,024 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 14:48:17,026 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 14:48:17,028 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 14:48:17,030 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 14:48:17,032 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 14:48:17,035 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 14:48:17,037 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 14:48:17,039 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 14:48:17,042 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 14:48:17,044 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 14:48:17,046 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 14:48:17,048 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 14:48:17,051 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 14:48:17,053 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 14:48:17,055 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 14:48:17,057 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 14:48:17,060 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 14:48:17,062 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 14:48:17,064 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 14:48:17,067 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 14:48:17,069 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 14:48:17,071 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 14:48:17,073 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 14:48:17,075 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 14:48:17,077 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 14:48:17,080 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 14:48:17,082 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 14:48:17,084 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 14:48:17,086 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 14:48:17,088 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 14:48:17,090 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 14:48:17,092 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 14:48:17,095 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 14:48:17,097 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 14:48:17,099 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 14:48:17,101 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 14:48:17,104 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 14:48:17,106 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 14:48:17,108 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 14:48:17,111 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 14:48:17,113 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 14:48:17,115 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 14:48:17,117 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 14:48:17,120 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 14:48:17,122 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 14:48:17,124 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 14:48:17,126 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 14:48:17,128 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 14:48:17,131 [MainThread  ] [INFO ]  Processing 45_reference_0.txt.
# 2019-02-14 14:48:17,133 [MainThread  ] [INFO ]  Processing 45_reference_1.txt.
# 2019-02-14 14:48:17,135 [MainThread  ] [INFO ]  Processing 45_reference_2.txt.
# 2019-02-14 14:48:17,137 [MainThread  ] [INFO ]  Processing 45_reference_3.txt.
# 2019-02-14 14:48:17,140 [MainThread  ] [INFO ]  Processing 46_reference_0.txt.
# 2019-02-14 14:48:17,142 [MainThread  ] [INFO ]  Processing 46_reference_1.txt.
# 2019-02-14 14:48:17,144 [MainThread  ] [INFO ]  Processing 46_reference_2.txt.
# 2019-02-14 14:48:17,146 [MainThread  ] [INFO ]  Processing 46_reference_3.txt.
# 2019-02-14 14:48:17,148 [MainThread  ] [INFO ]  Processing 47_reference_0.txt.
# 2019-02-14 14:48:17,151 [MainThread  ] [INFO ]  Processing 47_reference_1.txt.
# 2019-02-14 14:48:17,153 [MainThread  ] [INFO ]  Processing 47_reference_2.txt.
# 2019-02-14 14:48:17,155 [MainThread  ] [INFO ]  Processing 47_reference_3.txt.
# 2019-02-14 14:48:17,157 [MainThread  ] [INFO ]  Processing 48_reference_0.txt.
# 2019-02-14 14:48:17,160 [MainThread  ] [INFO ]  Processing 48_reference_1.txt.
# 2019-02-14 14:48:17,162 [MainThread  ] [INFO ]  Processing 48_reference_2.txt.
# 2019-02-14 14:48:17,164 [MainThread  ] [INFO ]  Processing 48_reference_3.txt.
# 2019-02-14 14:48:17,166 [MainThread  ] [INFO ]  Processing 49_reference_0.txt.
# 2019-02-14 14:48:17,169 [MainThread  ] [INFO ]  Processing 49_reference_1.txt.
# 2019-02-14 14:48:17,171 [MainThread  ] [INFO ]  Processing 49_reference_2.txt.
# 2019-02-14 14:48:17,173 [MainThread  ] [INFO ]  Processing 49_reference_3.txt.
# 2019-02-14 14:48:17,176 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpxvpdOz/model.
# 2019-02-14 14:48:17,195 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpJqhnMR/rouge_conf.xml
# 2019-02-14 14:48:17,196 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpJqhnMR/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.47198 (95%-conf.int. 0.45890 - 0.48434)
# 1 ROUGE-1 Average_P: 0.38112 (95%-conf.int. 0.37086 - 0.39029)
# 1 ROUGE-1 Average_F: 0.42130 (95%-conf.int. 0.41042 - 0.43125)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.11543 (95%-conf.int. 0.10668 - 0.12351)
# 1 ROUGE-2 Average_P: 0.09321 (95%-conf.int. 0.08555 - 0.09990)
# 1 ROUGE-2 Average_F: 0.10304 (95%-conf.int. 0.09480 - 0.11025)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.04331 (95%-conf.int. 0.03732 - 0.04918)
# 1 ROUGE-3 Average_P: 0.03493 (95%-conf.int. 0.03026 - 0.03938)
# 1 ROUGE-3 Average_F: 0.03863 (95%-conf.int. 0.03345 - 0.04370)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.02356 (95%-conf.int. 0.01941 - 0.02741)
# 1 ROUGE-4 Average_P: 0.01895 (95%-conf.int. 0.01572 - 0.02196)
# 1 ROUGE-4 Average_F: 0.02098 (95%-conf.int. 0.01742 - 0.02432)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.43724 (95%-conf.int. 0.42531 - 0.44835)
# 1 ROUGE-L Average_P: 0.35314 (95%-conf.int. 0.34368 - 0.36187)
# 1 ROUGE-L Average_F: 0.39034 (95%-conf.int. 0.38045 - 0.39953)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.12755 (95%-conf.int. 0.12396 - 0.13119)
# 1 ROUGE-W-1.2 Average_P: 0.18838 (95%-conf.int. 0.18281 - 0.19325)
# 1 ROUGE-W-1.2 Average_F: 0.15197 (95%-conf.int. 0.14782 - 0.15600)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.20399 (95%-conf.int. 0.19391 - 0.21439)
# 1 ROUGE-S* Average_P: 0.13260 (95%-conf.int. 0.12643 - 0.13831)
# 1 ROUGE-S* Average_F: 0.16014 (95%-conf.int. 0.15301 - 0.16723)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.20609 (95%-conf.int. 0.19601 - 0.21649)
# 1 ROUGE-SU* Average_P: 0.13418 (95%-conf.int. 0.12797 - 0.13990)
# 1 ROUGE-SU* Average_F: 0.16195 (95%-conf.int. 0.15475 - 0.16903)
#
# 6
