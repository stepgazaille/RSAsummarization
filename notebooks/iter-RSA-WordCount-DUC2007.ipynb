# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
# cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
# generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
# cmd = cmd.split()

vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
max_len = 250
stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query


def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_tfidf_score_func(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        v2s = [vectorizer.transform([r]) for r in ref]
        return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
    return tfidf_score_func

# %%
tfidf_score = get_tfidf_score_func()

# %%
class Summary:
    def __init__(self, texts, abstracts, query):
        
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        texts = sorted([(tfidf_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def most_similar(self, sent, text):
        return max([(count_score(s, sent), s) for s in text])[1]

    def add_sum(self, summ):
        text = self.texts.pop(0).split(' . ')
        if len(self.texts) == 0: return True
        found_sents = []
        for sent in summ:
            ms = self.most_similar(sent, text)
            if ms in found_sents:
                continue
            found_sents.append(sent)
            splitted = pp(sent).split()
            length = len(splitted) 
            splitted = set(splitted)       
            if self.length+length > max_len: return True
            if len(splitted - self.words) < int(len(splitted)*0.5): return False
            self.words |= splitted     
            self.summary.append(sent)
            self.length +=length
        return False

    def get(self):
        text = self.texts[0]
        sents = text.split(' . ')
        #score_per_sent = [(count_score(sent, self.query), sent) for sent in sents]
        score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
for i in [7]:
    duc_num = i
    done_summaries = []
    summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(i)]
    while summaries:
        with open('test/temp_file', 'wb') as writer:
            for summ in summaries:
                article, abstract, scores = summ.get()
                write_to_file(article, abstracts, scores, writer)
        call(['rm', '-r', generated_path])     
        call(cmd)
        generated_summaries = get_summaries(generated_path)
        should_remove = []
        for i in range(len(summaries)):
            if summaries[i].add_sum(generated_summaries[i]):
                should_remove.append(i)
        for i in should_remove[::-1]: 
            done_summaries.append(summaries.pop(i))
    evaluate(done_summaries)
    print duc_num
# Out:
# 2019-02-14 15:13:31,186 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-14 15:13:31,189 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpBCRSbu/system and model files to /tmp/tmpBCRSbu/model.
# 2019-02-14 15:13:31,191 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-14 15:13:31,192 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-14 15:13:31,194 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-14 15:13:31,197 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-14 15:13:31,199 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-14 15:13:31,201 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-14 15:13:31,203 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-14 15:13:31,206 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-14 15:13:31,208 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-14 15:13:31,210 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-14 15:13:31,212 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-14 15:13:31,215 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-14 15:13:31,217 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-14 15:13:31,219 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-14 15:13:31,221 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-14 15:13:31,223 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-14 15:13:31,226 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-14 15:13:31,228 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-14 15:13:31,230 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-14 15:13:31,232 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-14 15:13:31,235 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-14 15:13:31,237 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-14 15:13:31,239 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-14 15:13:31,241 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-14 15:13:31,243 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-14 15:13:31,245 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-14 15:13:31,248 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-14 15:13:31,250 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-14 15:13:31,253 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-14 15:13:31,255 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-14 15:13:31,257 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-14 15:13:31,259 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-14 15:13:31,262 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-14 15:13:31,264 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-14 15:13:31,266 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-14 15:13:31,268 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-14 15:13:31,270 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-14 15:13:31,273 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-14 15:13:31,275 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-14 15:13:31,277 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-14 15:13:31,279 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-14 15:13:31,281 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-14 15:13:31,284 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-14 15:13:31,286 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-14 15:13:31,288 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-14 15:13:31,290 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-14 15:13:31,293 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpBCRSbu/system.
# 2019-02-14 15:13:31,294 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-14 15:13:31,295 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-14 15:13:31,297 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-14 15:13:31,299 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-14 15:13:31,301 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-14 15:13:31,304 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-14 15:13:31,306 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-14 15:13:31,308 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-14 15:13:31,310 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-14 15:13:31,312 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-14 15:13:31,315 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-14 15:13:31,317 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-14 15:13:31,319 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-14 15:13:31,321 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-14 15:13:31,323 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-14 15:13:31,325 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-14 15:13:31,327 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-14 15:13:31,329 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-14 15:13:31,332 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-14 15:13:31,334 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-14 15:13:31,336 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-14 15:13:31,338 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-14 15:13:31,340 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-14 15:13:31,342 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-14 15:13:31,344 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-14 15:13:31,347 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-14 15:13:31,349 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-14 15:13:31,351 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-14 15:13:31,353 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-14 15:13:31,355 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-14 15:13:31,357 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-14 15:13:31,360 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-14 15:13:31,362 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-14 15:13:31,364 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-14 15:13:31,366 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-14 15:13:31,369 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-14 15:13:31,371 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-14 15:13:31,373 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-14 15:13:31,376 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-14 15:13:31,378 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-14 15:13:31,380 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-14 15:13:31,383 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-14 15:13:31,385 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-14 15:13:31,387 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-14 15:13:31,389 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-14 15:13:31,391 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-14 15:13:31,394 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-14 15:13:31,396 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-14 15:13:31,398 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-14 15:13:31,400 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-14 15:13:31,402 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-14 15:13:31,404 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-14 15:13:31,406 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-14 15:13:31,408 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-14 15:13:31,410 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-14 15:13:31,413 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-14 15:13:31,415 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-14 15:13:31,417 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-14 15:13:31,419 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-14 15:13:31,422 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-14 15:13:31,424 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-14 15:13:31,426 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-14 15:13:31,428 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-14 15:13:31,430 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-14 15:13:31,432 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-14 15:13:31,435 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-14 15:13:31,437 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-14 15:13:31,439 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-14 15:13:31,442 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-14 15:13:31,444 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-14 15:13:31,446 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-14 15:13:31,448 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-14 15:13:31,450 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-14 15:13:31,452 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-14 15:13:31,454 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-14 15:13:31,457 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-14 15:13:31,459 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-14 15:13:31,461 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-14 15:13:31,463 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-14 15:13:31,465 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-14 15:13:31,467 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-14 15:13:31,469 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-14 15:13:31,472 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-14 15:13:31,474 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-14 15:13:31,476 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-14 15:13:31,478 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-14 15:13:31,480 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-14 15:13:31,482 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-14 15:13:31,484 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-14 15:13:31,486 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-14 15:13:31,489 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-14 15:13:31,491 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-14 15:13:31,493 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-14 15:13:31,495 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-14 15:13:31,497 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-14 15:13:31,499 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-14 15:13:31,502 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-14 15:13:31,504 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-14 15:13:31,506 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-14 15:13:31,508 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-14 15:13:31,510 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-14 15:13:31,512 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-14 15:13:31,515 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-14 15:13:31,517 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-14 15:13:31,519 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-14 15:13:31,521 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-14 15:13:31,523 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-14 15:13:31,525 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-14 15:13:31,528 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-14 15:13:31,530 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-14 15:13:31,532 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-14 15:13:31,534 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-14 15:13:31,536 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-14 15:13:31,538 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-14 15:13:31,541 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-14 15:13:31,543 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-14 15:13:31,545 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-14 15:13:31,547 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-14 15:13:31,549 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-14 15:13:31,552 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-14 15:13:31,554 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-14 15:13:31,556 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-14 15:13:31,558 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-14 15:13:31,560 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-14 15:13:31,562 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-14 15:13:31,565 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-14 15:13:31,567 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-14 15:13:31,569 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-14 15:13:31,571 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-14 15:13:31,573 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-14 15:13:31,576 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-14 15:13:31,578 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-14 15:13:31,580 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-14 15:13:31,582 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-14 15:13:31,585 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-14 15:13:31,587 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-14 15:13:31,589 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-14 15:13:31,591 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-14 15:13:31,593 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-14 15:13:31,595 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-14 15:13:31,597 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-14 15:13:31,600 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-14 15:13:31,602 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-14 15:13:31,604 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-14 15:13:31,606 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-14 15:13:31,609 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-14 15:13:31,611 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-14 15:13:31,613 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-14 15:13:31,615 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-14 15:13:31,617 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-14 15:13:31,620 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-14 15:13:31,622 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-14 15:13:31,624 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-14 15:13:31,627 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-14 15:13:31,629 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-14 15:13:31,631 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-14 15:13:31,633 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-14 15:13:31,635 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-14 15:13:31,637 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-14 15:13:31,639 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-14 15:13:31,642 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-14 15:13:31,644 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-14 15:13:31,646 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-14 15:13:31,648 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-14 15:13:31,651 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-14 15:13:31,653 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-14 15:13:31,655 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-14 15:13:31,657 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-14 15:13:31,660 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-14 15:13:31,662 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-14 15:13:31,664 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-14 15:13:31,666 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-14 15:13:31,669 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-14 15:13:31,671 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-14 15:13:31,673 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-14 15:13:31,675 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-14 15:13:31,677 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-14 15:13:31,680 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-14 15:13:31,682 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-14 15:13:31,684 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-14 15:13:31,686 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-14 15:13:31,689 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpBCRSbu/model.
# 2019-02-14 15:13:31,705 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmpU4odpL/rouge_conf.xml
# 2019-02-14 15:13:31,706 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmpU4odpL/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.48118 (95%-conf.int. 0.46854 - 0.49389)
# 1 ROUGE-1 Average_P: 0.39503 (95%-conf.int. 0.38259 - 0.40703)
# 1 ROUGE-1 Average_F: 0.43303 (95%-conf.int. 0.42158 - 0.44413)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.12890 (95%-conf.int. 0.11950 - 0.13844)
# 1 ROUGE-2 Average_P: 0.10595 (95%-conf.int. 0.09753 - 0.11400)
# 1 ROUGE-2 Average_F: 0.11608 (95%-conf.int. 0.10733 - 0.12479)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.04880 (95%-conf.int. 0.04308 - 0.05439)
# 1 ROUGE-3 Average_P: 0.04020 (95%-conf.int. 0.03534 - 0.04482)
# 1 ROUGE-3 Average_F: 0.04400 (95%-conf.int. 0.03896 - 0.04900)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.02454 (95%-conf.int. 0.02073 - 0.02825)
# 1 ROUGE-4 Average_P: 0.02014 (95%-conf.int. 0.01698 - 0.02321)
# 1 ROUGE-4 Average_F: 0.02209 (95%-conf.int. 0.01868 - 0.02542)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.44722 (95%-conf.int. 0.43488 - 0.45925)
# 1 ROUGE-L Average_P: 0.36724 (95%-conf.int. 0.35539 - 0.37933)
# 1 ROUGE-L Average_F: 0.40252 (95%-conf.int. 0.39168 - 0.41305)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.12925 (95%-conf.int. 0.12570 - 0.13277)
# 1 ROUGE-W-1.2 Average_P: 0.19733 (95%-conf.int. 0.19080 - 0.20405)
# 1 ROUGE-W-1.2 Average_F: 0.15589 (95%-conf.int. 0.15169 - 0.16023)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.21320 (95%-conf.int. 0.20152 - 0.22548)
# 1 ROUGE-S* Average_P: 0.14440 (95%-conf.int. 0.13531 - 0.15380)
# 1 ROUGE-S* Average_F: 0.17082 (95%-conf.int. 0.16161 - 0.18006)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.21530 (95%-conf.int. 0.20362 - 0.22758)
# 1 ROUGE-SU* Average_P: 0.14602 (95%-conf.int. 0.13689 - 0.15546)
# 1 ROUGE-SU* Average_F: 0.17266 (95%-conf.int. 0.16344 - 0.18191)
#
# 7
