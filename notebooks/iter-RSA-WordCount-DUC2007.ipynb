# %%
from subprocess import call
from glob import glob
from nltk.corpus import stopwords
import os, struct
from tensorflow.core.example import example_pb2
import pyrouge
import shutil
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import *

# %%
# cmd = '/root/miniconda2/bin/python run_summarization.py --mode=decode --single_pass=1 --coverage=True --vocab_path=finished_files/vocab --log_root=log --exp_name=myexperiment --data_path=test/temp_file --max_enc_steps=4000'
# generated_path = '/gttp/pointer-generator-tal/log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
# cmd = cmd.split()

vocab_path = '../data/DMQA/finished_files/vocab'
log_root = 'log'
exp_name = 'myexperiment'
data_path= 'test/temp_file'
max_enc_steps = 4000

cmd = ['python',
       'run_summarization.py',
       '--mode=decode',
       '--single_pass=1',
       '--coverage=True',
       '--vocab_path=' + vocab_path,
       '--log_root=' + log_root,
       '--exp_name=' + exp_name,
       '--data_path=' + data_path,
       '--max_enc_steps=' + str(max_enc_steps)]

generated_path = 'log/myexperiment/decode_test_4000maxenc_4beam_35mindec_100maxdec_ckpt-238410/'
max_len = 250
stopwords = set(stopwords.words('english'))
stemmer = PorterStemmer()

# %%
def pp(string):
    return ' '.join([stemmer.stem(word.decode('utf8')) for word in string.lower().split() if not word in stopwords])
    
def write_to_file(article, abstract, rel, writer):
    abstract = '<s> '+' '.join(abstract)+' </s>'
    #abstract = abstract.encode('utf8', 'ignore')
    #rel = rel.encode('utf8', 'ignore')
    #article = article.encode('utf8', 'ignore')
    tf_example = example_pb2.Example()
    tf_example.features.feature['abstract'].bytes_list.value.extend([bytes(abstract)])
    tf_example.features.feature['relevancy'].bytes_list.value.extend([bytes(rel)])
    tf_example.features.feature['article'].bytes_list.value.extend([bytes(article)])
    tf_example_str = tf_example.SerializeToString()
    str_len = len(tf_example_str)
    writer.write(struct.pack('q', str_len))
    writer.write(struct.pack('%ds' % str_len, tf_example_str))


def duck_iterator(i):
    duc_folder = 'duc0' + str(i) + 'tokenized/'
    for topic in os.listdir(duc_folder + 'testdata/docs/'):
        topic_folder = duc_folder + 'testdata/docs/' + topic
        if not os.path.isdir(topic_folder):
            continue
        query = ' '.join(open(duc_folder + 'queries/' + topic).readlines())
        model_files = glob(duc_folder + 'models/' + topic[:-1].upper() + '.*')

        topic_texts = [' '.join(open(topic_folder + '/' + file).readlines()).replace('\n', '') for file in
                       os.listdir(topic_folder)]

        abstracts = [' '.join(open(f).readlines()) for f in model_files]
        yield topic_texts, abstracts, query


def count_score(sent, ref):
    ref = pp(ref).split()
    sent = ' '.join(pp(w) for w in sent.lower().split() if not w in stopwords)
    return sum([1. if w in ref else 0. for w in sent.split()])


def get_tfidf_score_func(magic = 1):
    corpus = []
    for i in range(5, 8):
        for topic_texts, _, _ in duck_iterator(i):
            corpus += [pp(t) for t in topic_texts]

    vectorizer = TfidfVectorizer()
    vectorizer.fit_transform(corpus)

    def tfidf_score_func(sent, ref):
        ref = [pp(s) for s in ref.split(' . ')]
        sent = pp(sent)
        v1 = vectorizer.transform([sent])
        v2s = [vectorizer.transform([r]) for r in ref]
        return max([cosine_similarity(v1, v2)[0][0] for v2 in v2s])
    return tfidf_score_func

# %%
class Summary:
    def __init__(self, texts, abstracts, query):
        
        #texts = sorted([(tfidf_score(query, text), text) for text in texts], reverse=True)
        texts = sorted([(count_score(text, ' '.join(abstracts)), text) for text in texts], reverse=True)

        texts = [text[1] for text in texts]
        self.texts = texts
        self.abstracts = abstracts
        self.query = query
        self.summary = []
        self.words = set()
        self.length = 0

    def most_similar(self, sent, text):
        return max([(count_score(s, sent), s) for s in text])[1]

    def add_sum(self, summ):
        text = self.texts.pop(0).split(' . ')
        if len(self.texts) == 0: return True
        found_sents = []
        for sent in summ:
            ms = self.most_similar(sent, text)
            if ms in found_sents:
                continue
            found_sents.append(sent)
            splitted = pp(sent).split()
            length = len(splitted) 
            splitted = set(splitted)       
            if self.length+length > max_len: return True
            if len(splitted - self.words) < int(len(splitted)*0.5): return False
            self.words |= splitted     
            self.summary.append(sent)
            self.length +=length
        return False

    def get(self):
        text = self.texts[0]
        sents = text.split(' . ')
        #score_per_sent = [(count_score(sent, self.query), sent) for sent in sents]
        score_per_sent = [(count_score(sent, ' '.join(self.abstracts)), sent) for sent in sents]

        scores = []
        for score, sent in score_per_sent:
            scores += [score] * (len(sent.split()) + 1)
        scores = str(scores[:-1])
        return text, 'a', scores

def get_summaries(path):
    path = path+'decoded/'
    out = {}
    for file_name in os.listdir(path):
        index = int(file_name.split('_')[0])
        out[index] = open(path+file_name).readlines()
    return out

def rouge_eval(ref_dir, dec_dir):
    """Evaluate the files in ref_dir and dec_dir with pyrouge, returning results_dict"""
    r = pyrouge.Rouge155()
    r.model_filename_pattern = '#ID#_reference_(\d+).txt'
    r.system_filename_pattern = '(\d+)_decoded.txt'
    r.model_dir = ref_dir
    r.system_dir = dec_dir
    return r.convert_and_evaluate()

def evaluate(summaries):
    for path in ['eval/ref', 'eval/dec']:
        if os.path.exists(path): shutil.rmtree(path, True)
        os.mkdir(path)
    for i, summ in enumerate(summaries):
        for j,abs in enumerate(summ.abstracts):
            with open('eval/ref/'+str(i)+'_reference_'+str(j)+'.txt', 'w') as f:
                f.write(abs)
        with open('eval/dec/'+str(i)+'_decoded.txt', 'w') as f:
            f.write(' '.join(summ.summary))
    print rouge_eval('eval/ref/', 'eval/dec/')

# %%
for i in [7]:
    duc_num = i
    done_summaries = []
    summaries = [Summary(texts, abstracts, query) for texts, abstracts, query in duck_iterator(i)]
    while summaries:
        with open('test/temp_file', 'wb') as writer:
            for summ in summaries:
                article, abstract, scores = summ.get()
                write_to_file(article, abstracts, scores, writer)
        call(['rm', '-r', generated_path])     
        call(cmd)
        generated_summaries = get_summaries(generated_path)
        should_remove = []
        for i in range(len(summaries)):
            if summaries[i].add_sum(generated_summaries[i]):
                should_remove.append(i)
        for i in should_remove[::-1]: 
            done_summaries.append(summaries.pop(i))
    evaluate(done_summaries)
    print duc_num
# Out:
# 2019-02-12 21:15:15,443 [MainThread  ] [INFO ]  Writing summaries.
# 2019-02-12 21:15:15,446 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpn5mhIK/system and model files to /tmp/tmpn5mhIK/model.
# 2019-02-12 21:15:15,447 [MainThread  ] [INFO ]  Processing files in eval/dec/.
# 2019-02-12 21:15:15,449 [MainThread  ] [INFO ]  Processing 0_decoded.txt.
# 2019-02-12 21:15:15,451 [MainThread  ] [INFO ]  Processing 1_decoded.txt.
# 2019-02-12 21:15:15,453 [MainThread  ] [INFO ]  Processing 2_decoded.txt.
# 2019-02-12 21:15:15,456 [MainThread  ] [INFO ]  Processing 3_decoded.txt.
# 2019-02-12 21:15:15,458 [MainThread  ] [INFO ]  Processing 4_decoded.txt.
# 2019-02-12 21:15:15,460 [MainThread  ] [INFO ]  Processing 5_decoded.txt.
# 2019-02-12 21:15:15,462 [MainThread  ] [INFO ]  Processing 6_decoded.txt.
# 2019-02-12 21:15:15,464 [MainThread  ] [INFO ]  Processing 7_decoded.txt.
# 2019-02-12 21:15:15,466 [MainThread  ] [INFO ]  Processing 8_decoded.txt.
# 2019-02-12 21:15:15,468 [MainThread  ] [INFO ]  Processing 9_decoded.txt.
# 2019-02-12 21:15:15,471 [MainThread  ] [INFO ]  Processing 10_decoded.txt.
# 2019-02-12 21:15:15,473 [MainThread  ] [INFO ]  Processing 11_decoded.txt.
# 2019-02-12 21:15:15,475 [MainThread  ] [INFO ]  Processing 12_decoded.txt.
# 2019-02-12 21:15:15,477 [MainThread  ] [INFO ]  Processing 13_decoded.txt.
# 2019-02-12 21:15:15,480 [MainThread  ] [INFO ]  Processing 14_decoded.txt.
# 2019-02-12 21:15:15,482 [MainThread  ] [INFO ]  Processing 15_decoded.txt.
# 2019-02-12 21:15:15,484 [MainThread  ] [INFO ]  Processing 16_decoded.txt.
# 2019-02-12 21:15:15,486 [MainThread  ] [INFO ]  Processing 17_decoded.txt.
# 2019-02-12 21:15:15,488 [MainThread  ] [INFO ]  Processing 18_decoded.txt.
# 2019-02-12 21:15:15,491 [MainThread  ] [INFO ]  Processing 19_decoded.txt.
# 2019-02-12 21:15:15,493 [MainThread  ] [INFO ]  Processing 20_decoded.txt.
# 2019-02-12 21:15:15,495 [MainThread  ] [INFO ]  Processing 21_decoded.txt.
# 2019-02-12 21:15:15,497 [MainThread  ] [INFO ]  Processing 22_decoded.txt.
# 2019-02-12 21:15:15,500 [MainThread  ] [INFO ]  Processing 23_decoded.txt.
# 2019-02-12 21:15:15,502 [MainThread  ] [INFO ]  Processing 24_decoded.txt.
# 2019-02-12 21:15:15,504 [MainThread  ] [INFO ]  Processing 25_decoded.txt.
# 2019-02-12 21:15:15,506 [MainThread  ] [INFO ]  Processing 26_decoded.txt.
# 2019-02-12 21:15:15,508 [MainThread  ] [INFO ]  Processing 27_decoded.txt.
# 2019-02-12 21:15:15,511 [MainThread  ] [INFO ]  Processing 28_decoded.txt.
# 2019-02-12 21:15:15,513 [MainThread  ] [INFO ]  Processing 29_decoded.txt.
# 2019-02-12 21:15:15,515 [MainThread  ] [INFO ]  Processing 30_decoded.txt.
# 2019-02-12 21:15:15,518 [MainThread  ] [INFO ]  Processing 31_decoded.txt.
# 2019-02-12 21:15:15,520 [MainThread  ] [INFO ]  Processing 32_decoded.txt.
# 2019-02-12 21:15:15,522 [MainThread  ] [INFO ]  Processing 33_decoded.txt.
# 2019-02-12 21:15:15,524 [MainThread  ] [INFO ]  Processing 34_decoded.txt.
# 2019-02-12 21:15:15,526 [MainThread  ] [INFO ]  Processing 35_decoded.txt.
# 2019-02-12 21:15:15,528 [MainThread  ] [INFO ]  Processing 36_decoded.txt.
# 2019-02-12 21:15:15,530 [MainThread  ] [INFO ]  Processing 37_decoded.txt.
# 2019-02-12 21:15:15,533 [MainThread  ] [INFO ]  Processing 38_decoded.txt.
# 2019-02-12 21:15:15,535 [MainThread  ] [INFO ]  Processing 39_decoded.txt.
# 2019-02-12 21:15:15,537 [MainThread  ] [INFO ]  Processing 40_decoded.txt.
# 2019-02-12 21:15:15,539 [MainThread  ] [INFO ]  Processing 41_decoded.txt.
# 2019-02-12 21:15:15,541 [MainThread  ] [INFO ]  Processing 42_decoded.txt.
# 2019-02-12 21:15:15,543 [MainThread  ] [INFO ]  Processing 43_decoded.txt.
# 2019-02-12 21:15:15,546 [MainThread  ] [INFO ]  Processing 44_decoded.txt.
# 2019-02-12 21:15:15,548 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpn5mhIK/system.
# 2019-02-12 21:15:15,549 [MainThread  ] [INFO ]  Processing files in eval/ref/.
# 2019-02-12 21:15:15,550 [MainThread  ] [INFO ]  Processing 0_reference_0.txt.
# 2019-02-12 21:15:15,553 [MainThread  ] [INFO ]  Processing 0_reference_1.txt.
# 2019-02-12 21:15:15,555 [MainThread  ] [INFO ]  Processing 0_reference_2.txt.
# 2019-02-12 21:15:15,557 [MainThread  ] [INFO ]  Processing 0_reference_3.txt.
# 2019-02-12 21:15:15,559 [MainThread  ] [INFO ]  Processing 1_reference_0.txt.
# 2019-02-12 21:15:15,561 [MainThread  ] [INFO ]  Processing 1_reference_1.txt.
# 2019-02-12 21:15:15,564 [MainThread  ] [INFO ]  Processing 1_reference_2.txt.
# 2019-02-12 21:15:15,566 [MainThread  ] [INFO ]  Processing 1_reference_3.txt.
# 2019-02-12 21:15:15,568 [MainThread  ] [INFO ]  Processing 2_reference_0.txt.
# 2019-02-12 21:15:15,570 [MainThread  ] [INFO ]  Processing 2_reference_1.txt.
# 2019-02-12 21:15:15,572 [MainThread  ] [INFO ]  Processing 2_reference_2.txt.
# 2019-02-12 21:15:15,575 [MainThread  ] [INFO ]  Processing 2_reference_3.txt.
# 2019-02-12 21:15:15,577 [MainThread  ] [INFO ]  Processing 3_reference_0.txt.
# 2019-02-12 21:15:15,579 [MainThread  ] [INFO ]  Processing 3_reference_1.txt.
# 2019-02-12 21:15:15,581 [MainThread  ] [INFO ]  Processing 3_reference_2.txt.
# 2019-02-12 21:15:15,583 [MainThread  ] [INFO ]  Processing 3_reference_3.txt.
# 2019-02-12 21:15:15,586 [MainThread  ] [INFO ]  Processing 4_reference_0.txt.
# 2019-02-12 21:15:15,588 [MainThread  ] [INFO ]  Processing 4_reference_1.txt.
# 2019-02-12 21:15:15,590 [MainThread  ] [INFO ]  Processing 4_reference_2.txt.
# 2019-02-12 21:15:15,592 [MainThread  ] [INFO ]  Processing 4_reference_3.txt.
# 2019-02-12 21:15:15,594 [MainThread  ] [INFO ]  Processing 5_reference_0.txt.
# 2019-02-12 21:15:15,596 [MainThread  ] [INFO ]  Processing 5_reference_1.txt.
# 2019-02-12 21:15:15,599 [MainThread  ] [INFO ]  Processing 5_reference_2.txt.
# 2019-02-12 21:15:15,601 [MainThread  ] [INFO ]  Processing 5_reference_3.txt.
# 2019-02-12 21:15:15,603 [MainThread  ] [INFO ]  Processing 6_reference_0.txt.
# 2019-02-12 21:15:15,605 [MainThread  ] [INFO ]  Processing 6_reference_1.txt.
# 2019-02-12 21:15:15,607 [MainThread  ] [INFO ]  Processing 6_reference_2.txt.
# 2019-02-12 21:15:15,610 [MainThread  ] [INFO ]  Processing 6_reference_3.txt.
# 2019-02-12 21:15:15,612 [MainThread  ] [INFO ]  Processing 7_reference_0.txt.
# 2019-02-12 21:15:15,614 [MainThread  ] [INFO ]  Processing 7_reference_1.txt.
# 2019-02-12 21:15:15,616 [MainThread  ] [INFO ]  Processing 7_reference_2.txt.
# 2019-02-12 21:15:15,618 [MainThread  ] [INFO ]  Processing 7_reference_3.txt.
# 2019-02-12 21:15:15,620 [MainThread  ] [INFO ]  Processing 8_reference_0.txt.
# 2019-02-12 21:15:15,623 [MainThread  ] [INFO ]  Processing 8_reference_1.txt.
# 2019-02-12 21:15:15,625 [MainThread  ] [INFO ]  Processing 8_reference_2.txt.
# 2019-02-12 21:15:15,627 [MainThread  ] [INFO ]  Processing 8_reference_3.txt.
# 2019-02-12 21:15:15,629 [MainThread  ] [INFO ]  Processing 9_reference_0.txt.
# 2019-02-12 21:15:15,631 [MainThread  ] [INFO ]  Processing 9_reference_1.txt.
# 2019-02-12 21:15:15,633 [MainThread  ] [INFO ]  Processing 9_reference_2.txt.
# 2019-02-12 21:15:15,635 [MainThread  ] [INFO ]  Processing 9_reference_3.txt.
# 2019-02-12 21:15:15,638 [MainThread  ] [INFO ]  Processing 10_reference_0.txt.
# 2019-02-12 21:15:15,640 [MainThread  ] [INFO ]  Processing 10_reference_1.txt.
# 2019-02-12 21:15:15,642 [MainThread  ] [INFO ]  Processing 10_reference_2.txt.
# 2019-02-12 21:15:15,644 [MainThread  ] [INFO ]  Processing 10_reference_3.txt.
# 2019-02-12 21:15:15,646 [MainThread  ] [INFO ]  Processing 11_reference_0.txt.
# 2019-02-12 21:15:15,648 [MainThread  ] [INFO ]  Processing 11_reference_1.txt.
# 2019-02-12 21:15:15,650 [MainThread  ] [INFO ]  Processing 11_reference_2.txt.
# 2019-02-12 21:15:15,652 [MainThread  ] [INFO ]  Processing 11_reference_3.txt.
# 2019-02-12 21:15:15,655 [MainThread  ] [INFO ]  Processing 12_reference_0.txt.
# 2019-02-12 21:15:15,657 [MainThread  ] [INFO ]  Processing 12_reference_1.txt.
# 2019-02-12 21:15:15,659 [MainThread  ] [INFO ]  Processing 12_reference_2.txt.
# 2019-02-12 21:15:15,661 [MainThread  ] [INFO ]  Processing 12_reference_3.txt.
# 2019-02-12 21:15:15,663 [MainThread  ] [INFO ]  Processing 13_reference_0.txt.
# 2019-02-12 21:15:15,665 [MainThread  ] [INFO ]  Processing 13_reference_1.txt.
# 2019-02-12 21:15:15,667 [MainThread  ] [INFO ]  Processing 13_reference_2.txt.
# 2019-02-12 21:15:15,670 [MainThread  ] [INFO ]  Processing 13_reference_3.txt.
# 2019-02-12 21:15:15,672 [MainThread  ] [INFO ]  Processing 14_reference_0.txt.
# 2019-02-12 21:15:15,674 [MainThread  ] [INFO ]  Processing 14_reference_1.txt.
# 2019-02-12 21:15:15,676 [MainThread  ] [INFO ]  Processing 14_reference_2.txt.
# 2019-02-12 21:15:15,678 [MainThread  ] [INFO ]  Processing 14_reference_3.txt.
# 2019-02-12 21:15:15,680 [MainThread  ] [INFO ]  Processing 15_reference_0.txt.
# 2019-02-12 21:15:15,683 [MainThread  ] [INFO ]  Processing 15_reference_1.txt.
# 2019-02-12 21:15:15,685 [MainThread  ] [INFO ]  Processing 15_reference_2.txt.
# 2019-02-12 21:15:15,687 [MainThread  ] [INFO ]  Processing 15_reference_3.txt.
# 2019-02-12 21:15:15,689 [MainThread  ] [INFO ]  Processing 16_reference_0.txt.
# 2019-02-12 21:15:15,691 [MainThread  ] [INFO ]  Processing 16_reference_1.txt.
# 2019-02-12 21:15:15,694 [MainThread  ] [INFO ]  Processing 16_reference_2.txt.
# 2019-02-12 21:15:15,696 [MainThread  ] [INFO ]  Processing 16_reference_3.txt.
# 2019-02-12 21:15:15,698 [MainThread  ] [INFO ]  Processing 17_reference_0.txt.
# 2019-02-12 21:15:15,700 [MainThread  ] [INFO ]  Processing 17_reference_1.txt.
# 2019-02-12 21:15:15,703 [MainThread  ] [INFO ]  Processing 17_reference_2.txt.
# 2019-02-12 21:15:15,705 [MainThread  ] [INFO ]  Processing 17_reference_3.txt.
# 2019-02-12 21:15:15,707 [MainThread  ] [INFO ]  Processing 18_reference_0.txt.
# 2019-02-12 21:15:15,709 [MainThread  ] [INFO ]  Processing 18_reference_1.txt.
# 2019-02-12 21:15:15,711 [MainThread  ] [INFO ]  Processing 18_reference_2.txt.
# 2019-02-12 21:15:15,713 [MainThread  ] [INFO ]  Processing 18_reference_3.txt.
# 2019-02-12 21:15:15,715 [MainThread  ] [INFO ]  Processing 19_reference_0.txt.
# 2019-02-12 21:15:15,718 [MainThread  ] [INFO ]  Processing 19_reference_1.txt.
# 2019-02-12 21:15:15,720 [MainThread  ] [INFO ]  Processing 19_reference_2.txt.
# 2019-02-12 21:15:15,722 [MainThread  ] [INFO ]  Processing 19_reference_3.txt.
# 2019-02-12 21:15:15,724 [MainThread  ] [INFO ]  Processing 20_reference_0.txt.
# 2019-02-12 21:15:15,726 [MainThread  ] [INFO ]  Processing 20_reference_1.txt.
# 2019-02-12 21:15:15,728 [MainThread  ] [INFO ]  Processing 20_reference_2.txt.
# 2019-02-12 21:15:15,731 [MainThread  ] [INFO ]  Processing 20_reference_3.txt.
# 2019-02-12 21:15:15,733 [MainThread  ] [INFO ]  Processing 21_reference_0.txt.
# 2019-02-12 21:15:15,735 [MainThread  ] [INFO ]  Processing 21_reference_1.txt.
# 2019-02-12 21:15:15,737 [MainThread  ] [INFO ]  Processing 21_reference_2.txt.
# 2019-02-12 21:15:15,740 [MainThread  ] [INFO ]  Processing 21_reference_3.txt.
# 2019-02-12 21:15:15,742 [MainThread  ] [INFO ]  Processing 22_reference_0.txt.
# 2019-02-12 21:15:15,744 [MainThread  ] [INFO ]  Processing 22_reference_1.txt.
# 2019-02-12 21:15:15,746 [MainThread  ] [INFO ]  Processing 22_reference_2.txt.
# 2019-02-12 21:15:15,748 [MainThread  ] [INFO ]  Processing 22_reference_3.txt.
# 2019-02-12 21:15:15,750 [MainThread  ] [INFO ]  Processing 23_reference_0.txt.
# 2019-02-12 21:15:15,752 [MainThread  ] [INFO ]  Processing 23_reference_1.txt.
# 2019-02-12 21:15:15,755 [MainThread  ] [INFO ]  Processing 23_reference_2.txt.
# 2019-02-12 21:15:15,757 [MainThread  ] [INFO ]  Processing 23_reference_3.txt.
# 2019-02-12 21:15:15,759 [MainThread  ] [INFO ]  Processing 24_reference_0.txt.
# 2019-02-12 21:15:15,761 [MainThread  ] [INFO ]  Processing 24_reference_1.txt.
# 2019-02-12 21:15:15,764 [MainThread  ] [INFO ]  Processing 24_reference_2.txt.
# 2019-02-12 21:15:15,766 [MainThread  ] [INFO ]  Processing 24_reference_3.txt.
# 2019-02-12 21:15:15,768 [MainThread  ] [INFO ]  Processing 25_reference_0.txt.
# 2019-02-12 21:15:15,770 [MainThread  ] [INFO ]  Processing 25_reference_1.txt.
# 2019-02-12 21:15:15,773 [MainThread  ] [INFO ]  Processing 25_reference_2.txt.
# 2019-02-12 21:15:15,775 [MainThread  ] [INFO ]  Processing 25_reference_3.txt.
# 2019-02-12 21:15:15,777 [MainThread  ] [INFO ]  Processing 26_reference_0.txt.
# 2019-02-12 21:15:15,779 [MainThread  ] [INFO ]  Processing 26_reference_1.txt.
# 2019-02-12 21:15:15,781 [MainThread  ] [INFO ]  Processing 26_reference_2.txt.
# 2019-02-12 21:15:15,784 [MainThread  ] [INFO ]  Processing 26_reference_3.txt.
# 2019-02-12 21:15:15,786 [MainThread  ] [INFO ]  Processing 27_reference_0.txt.
# 2019-02-12 21:15:15,788 [MainThread  ] [INFO ]  Processing 27_reference_1.txt.
# 2019-02-12 21:15:15,790 [MainThread  ] [INFO ]  Processing 27_reference_2.txt.
# 2019-02-12 21:15:15,792 [MainThread  ] [INFO ]  Processing 27_reference_3.txt.
# 2019-02-12 21:15:15,795 [MainThread  ] [INFO ]  Processing 28_reference_0.txt.
# 2019-02-12 21:15:15,797 [MainThread  ] [INFO ]  Processing 28_reference_1.txt.
# 2019-02-12 21:15:15,799 [MainThread  ] [INFO ]  Processing 28_reference_2.txt.
# 2019-02-12 21:15:15,801 [MainThread  ] [INFO ]  Processing 28_reference_3.txt.
# 2019-02-12 21:15:15,803 [MainThread  ] [INFO ]  Processing 29_reference_0.txt.
# 2019-02-12 21:15:15,805 [MainThread  ] [INFO ]  Processing 29_reference_1.txt.
# 2019-02-12 21:15:15,808 [MainThread  ] [INFO ]  Processing 29_reference_2.txt.
# 2019-02-12 21:15:15,810 [MainThread  ] [INFO ]  Processing 29_reference_3.txt.
# 2019-02-12 21:15:15,812 [MainThread  ] [INFO ]  Processing 30_reference_0.txt.
# 2019-02-12 21:15:15,814 [MainThread  ] [INFO ]  Processing 30_reference_1.txt.
# 2019-02-12 21:15:15,817 [MainThread  ] [INFO ]  Processing 30_reference_2.txt.
# 2019-02-12 21:15:15,819 [MainThread  ] [INFO ]  Processing 30_reference_3.txt.
# 2019-02-12 21:15:15,821 [MainThread  ] [INFO ]  Processing 31_reference_0.txt.
# 2019-02-12 21:15:15,823 [MainThread  ] [INFO ]  Processing 31_reference_1.txt.
# 2019-02-12 21:15:15,825 [MainThread  ] [INFO ]  Processing 31_reference_2.txt.
# 2019-02-12 21:15:15,828 [MainThread  ] [INFO ]  Processing 31_reference_3.txt.
# 2019-02-12 21:15:15,830 [MainThread  ] [INFO ]  Processing 32_reference_0.txt.
# 2019-02-12 21:15:15,832 [MainThread  ] [INFO ]  Processing 32_reference_1.txt.
# 2019-02-12 21:15:15,834 [MainThread  ] [INFO ]  Processing 32_reference_2.txt.
# 2019-02-12 21:15:15,836 [MainThread  ] [INFO ]  Processing 32_reference_3.txt.
# 2019-02-12 21:15:15,838 [MainThread  ] [INFO ]  Processing 33_reference_0.txt.
# 2019-02-12 21:15:15,841 [MainThread  ] [INFO ]  Processing 33_reference_1.txt.
# 2019-02-12 21:15:15,843 [MainThread  ] [INFO ]  Processing 33_reference_2.txt.
# 2019-02-12 21:15:15,845 [MainThread  ] [INFO ]  Processing 33_reference_3.txt.
# 2019-02-12 21:15:15,847 [MainThread  ] [INFO ]  Processing 34_reference_0.txt.
# 2019-02-12 21:15:15,850 [MainThread  ] [INFO ]  Processing 34_reference_1.txt.
# 2019-02-12 21:15:15,852 [MainThread  ] [INFO ]  Processing 34_reference_2.txt.
# 2019-02-12 21:15:15,854 [MainThread  ] [INFO ]  Processing 34_reference_3.txt.
# 2019-02-12 21:15:15,856 [MainThread  ] [INFO ]  Processing 35_reference_0.txt.
# 2019-02-12 21:15:15,858 [MainThread  ] [INFO ]  Processing 35_reference_1.txt.
# 2019-02-12 21:15:15,861 [MainThread  ] [INFO ]  Processing 35_reference_2.txt.
# 2019-02-12 21:15:15,863 [MainThread  ] [INFO ]  Processing 35_reference_3.txt.
# 2019-02-12 21:15:15,865 [MainThread  ] [INFO ]  Processing 36_reference_0.txt.
# 2019-02-12 21:15:15,867 [MainThread  ] [INFO ]  Processing 36_reference_1.txt.
# 2019-02-12 21:15:15,870 [MainThread  ] [INFO ]  Processing 36_reference_2.txt.
# 2019-02-12 21:15:15,872 [MainThread  ] [INFO ]  Processing 36_reference_3.txt.
# 2019-02-12 21:15:15,874 [MainThread  ] [INFO ]  Processing 37_reference_0.txt.
# 2019-02-12 21:15:15,877 [MainThread  ] [INFO ]  Processing 37_reference_1.txt.
# 2019-02-12 21:15:15,879 [MainThread  ] [INFO ]  Processing 37_reference_2.txt.
# 2019-02-12 21:15:15,881 [MainThread  ] [INFO ]  Processing 37_reference_3.txt.
# 2019-02-12 21:15:15,883 [MainThread  ] [INFO ]  Processing 38_reference_0.txt.
# 2019-02-12 21:15:15,886 [MainThread  ] [INFO ]  Processing 38_reference_1.txt.
# 2019-02-12 21:15:15,888 [MainThread  ] [INFO ]  Processing 38_reference_2.txt.
# 2019-02-12 21:15:15,890 [MainThread  ] [INFO ]  Processing 38_reference_3.txt.
# 2019-02-12 21:15:15,892 [MainThread  ] [INFO ]  Processing 39_reference_0.txt.
# 2019-02-12 21:15:15,894 [MainThread  ] [INFO ]  Processing 39_reference_1.txt.
# 2019-02-12 21:15:15,896 [MainThread  ] [INFO ]  Processing 39_reference_2.txt.
# 2019-02-12 21:15:15,899 [MainThread  ] [INFO ]  Processing 39_reference_3.txt.
# 2019-02-12 21:15:15,901 [MainThread  ] [INFO ]  Processing 40_reference_0.txt.
# 2019-02-12 21:15:15,903 [MainThread  ] [INFO ]  Processing 40_reference_1.txt.
# 2019-02-12 21:15:15,905 [MainThread  ] [INFO ]  Processing 40_reference_2.txt.
# 2019-02-12 21:15:15,907 [MainThread  ] [INFO ]  Processing 40_reference_3.txt.
# 2019-02-12 21:15:15,909 [MainThread  ] [INFO ]  Processing 41_reference_0.txt.
# 2019-02-12 21:15:15,912 [MainThread  ] [INFO ]  Processing 41_reference_1.txt.
# 2019-02-12 21:15:15,914 [MainThread  ] [INFO ]  Processing 41_reference_2.txt.
# 2019-02-12 21:15:15,916 [MainThread  ] [INFO ]  Processing 41_reference_3.txt.
# 2019-02-12 21:15:15,918 [MainThread  ] [INFO ]  Processing 42_reference_0.txt.
# 2019-02-12 21:15:15,920 [MainThread  ] [INFO ]  Processing 42_reference_1.txt.
# 2019-02-12 21:15:15,923 [MainThread  ] [INFO ]  Processing 42_reference_2.txt.
# 2019-02-12 21:15:15,925 [MainThread  ] [INFO ]  Processing 42_reference_3.txt.
# 2019-02-12 21:15:15,927 [MainThread  ] [INFO ]  Processing 43_reference_0.txt.
# 2019-02-12 21:15:15,929 [MainThread  ] [INFO ]  Processing 43_reference_1.txt.
# 2019-02-12 21:15:15,931 [MainThread  ] [INFO ]  Processing 43_reference_2.txt.
# 2019-02-12 21:15:15,934 [MainThread  ] [INFO ]  Processing 43_reference_3.txt.
# 2019-02-12 21:15:15,936 [MainThread  ] [INFO ]  Processing 44_reference_0.txt.
# 2019-02-12 21:15:15,938 [MainThread  ] [INFO ]  Processing 44_reference_1.txt.
# 2019-02-12 21:15:15,940 [MainThread  ] [INFO ]  Processing 44_reference_2.txt.
# 2019-02-12 21:15:15,942 [MainThread  ] [INFO ]  Processing 44_reference_3.txt.
# 2019-02-12 21:15:15,944 [MainThread  ] [INFO ]  Saved processed files to /tmp/tmpn5mhIK/model.
# 2019-02-12 21:15:15,962 [MainThread  ] [INFO ]  Written ROUGE configuration to /tmp/tmphtifwZ/rouge_conf.xml
# 2019-02-12 21:15:15,963 [MainThread  ] [INFO ]  Running ROUGE with command /home/stephaneg/ROUGE-1.5.5/ROUGE-1.5.5.pl -e /home/stephaneg/ROUGE-1.5.5/data -c 95 -2 -1 -U -r 1000 -n 4 -w 1.2 -a -m /tmp/tmphtifwZ/rouge_conf.xml
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.45518 (95%-conf.int. 0.44238 - 0.46901)
# 1 ROUGE-1 Average_P: 0.38144 (95%-conf.int. 0.37070 - 0.39268)
# 1 ROUGE-1 Average_F: 0.41429 (95%-conf.int. 0.40407 - 0.42534)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.10837 (95%-conf.int. 0.10033 - 0.11657)
# 1 ROUGE-2 Average_P: 0.09098 (95%-conf.int. 0.08402 - 0.09811)
# 1 ROUGE-2 Average_F: 0.09872 (95%-conf.int. 0.09133 - 0.10600)
# ---------------------------------------------
# 1 ROUGE-3 Average_R: 0.03880 (95%-conf.int. 0.03397 - 0.04393)
# 1 ROUGE-3 Average_P: 0.03272 (95%-conf.int. 0.02851 - 0.03729)
# 1 ROUGE-3 Average_F: 0.03542 (95%-conf.int. 0.03095 - 0.04016)
# ---------------------------------------------
# 1 ROUGE-4 Average_R: 0.02020 (95%-conf.int. 0.01660 - 0.02398)
# 1 ROUGE-4 Average_P: 0.01702 (95%-conf.int. 0.01397 - 0.02040)
# 1 ROUGE-4 Average_F: 0.01843 (95%-conf.int. 0.01513 - 0.02191)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.42008 (95%-conf.int. 0.40868 - 0.43241)
# 1 ROUGE-L Average_P: 0.35216 (95%-conf.int. 0.34216 - 0.36321)
# 1 ROUGE-L Average_F: 0.38242 (95%-conf.int. 0.37318 - 0.39254)
# ---------------------------------------------
# 1 ROUGE-W-1.2 Average_R: 0.12085 (95%-conf.int. 0.11734 - 0.12478)
# 1 ROUGE-W-1.2 Average_P: 0.18840 (95%-conf.int. 0.18261 - 0.19444)
# 1 ROUGE-W-1.2 Average_F: 0.14695 (95%-conf.int. 0.14314 - 0.15110)
# ---------------------------------------------
# 1 ROUGE-S* Average_R: 0.18940 (95%-conf.int. 0.17852 - 0.20109)
# 1 ROUGE-S* Average_P: 0.13326 (95%-conf.int. 0.12584 - 0.14120)
# 1 ROUGE-S* Average_F: 0.15529 (95%-conf.int. 0.14752 - 0.16353)
# ---------------------------------------------
# 1 ROUGE-SU* Average_R: 0.19148 (95%-conf.int. 0.18059 - 0.20319)
# 1 ROUGE-SU* Average_P: 0.13490 (95%-conf.int. 0.12745 - 0.14287)
# 1 ROUGE-SU* Average_F: 0.15713 (95%-conf.int. 0.14935 - 0.16538)
#
# 7
